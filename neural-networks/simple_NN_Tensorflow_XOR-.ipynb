# %% [markdown]
# # Building a Neural Network in Tensorflow
# ### Solving a simple XOR problem

# %%
import tensorflow as tf
import time

# %% [markdown]
# ## Model 1
#
# * This model is setup step-by-step and used as a baselin for models 2 - 4

# %% [markdown]
# ### Setup placeholders
#
# *   Tensorflow will automatically fill them with the data when we run the network
# *   In this XOR problem, we have four different training examples and each example has two features
# *   There are also four expected outputs, each with just one value (either 0 or 1)

# %%
x_ = tf.placeholder(tf.float32, shape=[4,2], name = 'x-input')
y_ = tf.placeholder(tf.float32, shape=[4,1], name = 'y-input')

# %% [markdown]
# ### Setup parameters for the network
#
# * These are called variables in Tensorflow
# * Variables will be modified by Tensorflow during the training steps
# * For our theta matrices, we want them initialized to random values between -1 and +1, so we use the built-in random_uniform function to do that

# %%
Theta1 = tf.Variable(tf.random_uniform([2,2], -1, 1), name = "Theta1")
Theta2 = tf.Variable(tf.random_uniform([2,1], -1, 1), name = "Theta2")

# %% [markdown]
# ### Setup bias nodes
#
# *  Bias nodes are setup separately, but still as Variables
# *  this lets the algorithms modify the values of the bias node
# * This is mathematically equivalent to having a signal value of 1 and initial weights of 0 on the links from the bias nodes

# %%
Bias1 = tf.Variable(tf.zeros([2]), name = "Bias1")
Bias2 = tf.Variable(tf.zeros([1]), name = "Bias2")

# %% [markdown]
# ### Tensorflow Model
#
# Tensorflow runs a model inside of a $session$, which it uses to maintain the state of the variables as they pass through the network
#
# *  Matmul is Tensorflow's matrix multiplication function
# *  Sigmoid is the sigmoid activation function
# *  The cost function is the average over all the training examples
# *  The training algorithm used is the gradient descent algorithm with a learning rate of 0.1
# * the training algorithm objective is to minimize the cost function

# %%
with tf.name_scope("layer2") as scope:
	A2 = tf.sigmoid(tf.matmul(x_, Theta1) + Bias1)

with tf.name_scope("layer3") as scope:
	Hypothesis = tf.sigmoid(tf.matmul(A2, Theta2) + Bias2)

with tf.name_scope("cost") as scope:
	cost = tf.reduce_mean(( (y_ * tf.log(Hypothesis)) + 
		((1 - y_) * tf.log(1.0 - Hypothesis)) ) * -1)

with tf.name_scope("train") as scope:
	train_step = tf.train.GradientDescentOptimizer(0.01).minimize(cost)
  
XOR_X = [[0,0],[0,1],[1,0],[1,1]]
XOR_Y = [[0],[1],[1],[0]]

init = tf.global_variables_initializer()
sess = tf.Session()

#writer = tf.summary.FileWriter("./logs/xor_logs", sess.graph)

sess.run(init)

# %% [markdown]
# ### Training steps
#
# *   Each time the training step is executed, the values in the dictionary "feed_dict" are loaded into the placeholders
# *   As the XOR problem is simple, each epoch will contain the entire training set
# *  To see what's going on inside the loop, just print the values of the Variables

# %%
t_start = time.clock()
for i in range(100000):
	sess.run(train_step, feed_dict={x_: XOR_X, y_: XOR_Y})
	if i % 1000 == 0:
		print('Epoch ', i)
		print('Hypothesis ', sess.run(Hypothesis, feed_dict={x_: XOR_X, y_: XOR_Y}))
		print('Theta1 ', sess.run(Theta1))
		print('Bias1 ', sess.run(Bias1))
		print('Theta2 ', sess.run(Theta2))
		print('Bias2 ', sess.run(Bias2))
		print('cost ', sess.run(cost, feed_dict={x_: XOR_X, y_: XOR_Y}))
t_end = time.clock()
print('Elapsed time ', t_end - t_start)
# Out:
# Epoch  0
# Hypothesis  [[0.43824816]
#  [0.3980671 ]
#  [0.4864669 ]
#  [0.44081098]]
# Theta1  [[ 0.75088984 -0.59059376]
#  [ 0.39410627  0.9964763 ]]
# Bias1  [ 6.3200285e-05 -4.6624002e-05]
# Theta2  [[ 0.38002536]
#  [-0.877795  ]]
# Bias2  [0.00059361]
# cost  0.699921
# Epoch  1000
# Hypothesis  [[0.49284208]
#  [0.46040598]
#  [0.5420136 ]
#  [0.50363797]]
# Theta1  [[ 0.766465   -0.57335395]
#  [ 0.44432032  1.0140898 ]]
# Bias1  [0.0284321  0.04139753]
# Theta2  [[ 0.47723562]
#  [-0.78650117]]
# Bias2  [0.1307458]
# cost  0.6918734
# Epoch  2000
# Hypothesis  [[0.49301705]
#  [0.46258795]
#  [0.5422611 ]
#  [0.504325  ]]
# Theta1  [[ 0.7806317  -0.55485165]
#  [ 0.4934432   1.0464029 ]]
# Bias1  [0.04629835 0.10360561]
# Theta2  [[ 0.49484852]
#  [-0.7767083 ]]
# Bias2  [0.1273696]
# cost  0.6910097
# Epoch  3000
# Hypothesis  [[0.49211153]
#  [0.46353695]
#  [0.5424705 ]
#  [0.50463533]]
# Theta1  [[ 0.7988815  -0.54680574]
#  [ 0.5464299   1.0815223 ]]
# Bias1  [0.06534696 0.16392256]
# Theta2  [[ 0.51686794]
#  [-0.7757771 ]]
# Bias2  [0.12117802]
# cost  0.6901113
# Epoch  4000
# Hypothesis  [[0.4907464 ]
#  [0.4640647 ]
#  [0.54328275]
#  [0.5052561 ]]
# Theta1  [[ 0.82184494 -0.54813045]
#  [ 0.6042234   1.1196035 ]]
# Bias1  [0.08579034 0.22324942]
# Theta2  [[ 0.5448276 ]
#  [-0.78237474]]
# Bias2  [0.11356265]
# cost  0.6890952
# Epoch  5000
# Hypothesis  [[0.48888445]
#  [0.4642454 ]
#  [0.54473215]
#  [0.5061602 ]]
# Theta1  [[ 0.850262  -0.5580355]
#  [ 0.6678     1.1611739]]
# Bias1  [0.10759906 0.28262684]
# Theta2  [[ 0.5794897]
#  [-0.7964948]]
# Bias2  [0.10436586]
# cost  0.6878767
# Epoch  6000
# Hypothesis  [[0.48645177]
#  [0.46412385]
#  [0.54688597]
#  [0.5073223 ]]
# Theta1  [[ 0.8850317  -0.5761123 ]
#  [ 0.73822236  1.2069596 ]]
# Bias1  [0.13058656 0.34300575]
# Theta2  [[ 0.62182146]
#  [-0.818518  ]]
# Bias2  [0.0933793]
# cost  0.68635756
# Epoch  7000
# Hypothesis  [[0.48334083]
#  [0.46372956]
#  [0.54985195]
#  [0.5087189 ]]
# Theta1  [[ 0.9271836  -0.60229677]
#  [ 0.8166124   1.2578583 ]]
# Bias1  [0.15431985 0.40526095]
# Theta2  [[ 0.6729986]
#  [-0.8491408]]
# Bias2  [0.08036918]
# cost  0.68441767
# Epoch  8000
# Hypothesis  [[0.47940525]
#  [0.46308148]
#  [0.5537805 ]
#  [0.510321  ]]
# Theta1  [[ 0.9778138  -0.63683903]
#  [ 0.90410066  1.3149321 ]]
# Bias1  [0.17800562 0.47019252]
# Theta2  [[ 0.7343832]
#  [-0.8893187]]
# Bias2  [0.06510033]
# cost  0.681907
# Epoch  9000
# Hypothesis  [[0.47445226]
#  [0.4621905 ]
#  [0.55886525]
#  [0.5120888 ]]
# Theta1  [[ 1.0379831 -0.6802768]
#  [ 1.0017385  1.3793966]]
# Bias1  [0.20036358 0.53850484]
# Theta2  [[ 0.80747473]
#  [-0.94020885]]
# Bias2  [0.04737868]
# cost  0.67864025
# Epoch  10000
# Hypothesis  [[0.46823475]
#  [0.46106473]
#  [0.5653426 ]
#  [0.5139712 ]]
# Theta1  [[ 1.1085768 -0.7333951]
#  [ 1.110401   1.4525968]]
# Bias1  [0.2195303 0.6107564]
# Theta2  [[ 0.8938207]
#  [-1.0030859]]
# Bias2  [0.02711136]
# cost  0.6743952
# Epoch  11000
# Hypothesis  [[0.460443  ]
#  [0.45971647]
#  [0.5734868 ]
#  [0.51591265]]
# Theta1  [[ 1.1901567 -0.797151 ]
#  [ 1.2306905  1.5359553]]
# Bias1  [0.23305379 0.687283  ]
# Theta2  [[ 0.9948883]
#  [-1.0792333]]
# Bias2  [0.00437275]
# cost  0.6689156
# Epoch  12000
# Hypothesis  [[0.45070097]
#  [0.45817435]
#  [0.5836002 ]
#  [0.5178653 ]]
# Theta1  [[ 1.2828366 -0.8725407]
#  [ 1.3628887  1.6308836]]
# Bias1  [0.23804353 0.7681021 ]
# Theta2  [[ 1.1118995]
#  [-1.1698012]]
# Bias2  [-0.02054487]
# cost  0.66192216
# Epoch  13000
# Hypothesis  [[0.4385758]
#  [0.4564998]
#  [0.5959947]
#  [0.5198018]]
# Theta1  [[ 1.386226  -0.9603859]
#  [ 1.5069605  1.7386516]]
# Bias1  [0.23151845 0.8528292 ]
# Theta2  [[ 1.2456509]
#  [-1.275637 ]]
# Bias2  [-0.04712081]
# cost  0.6531313
# Epoch  14000
# Hypothesis  [[0.42361504]
#  [0.45480168]
#  [0.6109566 ]
#  [0.5217197 ]]
# Theta1  [[ 1.4994434 -1.0610366]
#  [ 1.6626017  1.8602128]]
# Bias1  [0.21093474 0.9406374 ]
# Theta2  [[ 1.3963224]
#  [-1.3970908]]
# Bias2  [-0.07464594]
# cost  0.64229023
# Epoch  15000
# Hypothesis  [[0.40542752]
#  [0.45324257]
#  [0.6286812 ]
#  [0.523629  ]]
# Theta1  [[ 1.6211646 -1.1740369]
#  [ 1.829265   1.9959983]]
# Bias1  [0.17480667 1.0302999 ]
# Theta2  [[ 1.5632688]
#  [-1.5338013]]
# Bias2  [-0.10230723]
# cost  0.6292324
# Epoch  16000
# Hypothesis  [[0.38381955]
#  [0.4520285 ]
#  [0.649181  ]
#  [0.5255276 ]]
# Theta1  [[ 1.7496562 -1.2978472]
#  [ 2.0061033  2.1457   ]]
# Bias1  [0.12326335 1.1203116 ]
# Theta2  [[ 1.7448337]
#  [-1.6845043]]
# Bias2  [-0.12929009]
# cost  0.61395526
# Epoch  17000
# Hypothesis  [[0.3589541 ]
#  [0.45137167]
#  [0.67218125]
#  [0.5273692 ]]
# Theta1  [[ 1.8827975 -1.4297714]
#  [ 2.1918256  2.3080935]]
# Bias1  [0.05832608 1.2090926 ]
# Theta2  [[ 1.9382225]
#  [-1.846934 ]]
# Bias2  [-0.15487735]
# cost  0.59669656
# Epoch  18000
# Hypothesis  [[0.33146784]
#  [0.4514355 ]
#  [0.69706714]
#  [0.52905047]]
# Theta1  [[ 2.0181272 -1.5662007]
#  [ 2.3845208  2.4809783]]
# Bias1  [-0.016298   1.2951523]
# Theta2  [[ 2.1395817]
#  [-2.017917 ]]
# Bias2  [-0.17852603]
# cost  0.5779679
# Epoch  19000
# Hypothesis  [[0.30244094]
#  [0.45227936]
#  [0.7229311 ]
#  [0.5304265 ]]
# Theta1  [[ 2.1529608 -1.7031513]
#  [ 2.5816214  2.6613135]]
# Bias1  [-0.09596863  1.3772402 ]
# Theta2  [[ 2.3443587]
#  [-2.1936953]]
# Bias2  [-0.19990769]
# cost  0.5584988
# Epoch  20000
# Hypothesis  [[0.27318954]
#  [0.45383805]
#  [0.7487405 ]
#  [0.5313623 ]]
# Theta1  [[ 2.284709  -1.836963 ]
#  [ 2.7800715  2.845572 ]]
# Bias1  [-0.1761499  1.4544353]
# Theta2  [[ 2.5479126]
#  [-2.3703861]]
# Bias2  [-0.218917]
# cost  0.53909814
# Epoch  21000
# Hypothesis  [[0.2449636 ]
#  [0.45594335]
#  [0.77354467]
#  [0.5317775 ]]
# Theta1  [[ 2.4111183 -1.9647534]
#  [ 2.9766698  3.030196 ]]
# Bias1  [-0.253261   1.5261688]
# Theta2  [[ 2.7462027]
#  [-2.544543 ]]
# Bias2  [-0.23560224]
# cost  0.5204899
# Epoch  22000
# Hypothesis  [[0.21871063]
#  [0.45839083]
#  [0.79663086]
#  [0.53167623]]
# Theta1  [[ 2.5305393 -2.0846648]
#  [ 3.1685846  3.2120411]]
# Bias1  [-0.3250539  1.592221 ]
# Theta2  [[ 2.9361782]
#  [-2.713385 ]]
# Bias2  [-0.25013143]
# cost  0.50320053
# Epoch  23000
# Hypothesis  [[0.19497888]
#  [0.4609873 ]
#  [0.81758505]
#  [0.5311279 ]]
# Theta1  [[ 2.6420002 -2.1957934]
#  [ 3.3535995  3.388668 ]]
# Bias1  [-0.3905011  1.6526598]
# Theta2  [[ 3.115933 ]
#  [-2.8749895]]
# Bias2  [-0.26272196]
# cost  0.48752433
# Epoch  24000
# Hypothesis  [[0.17395902]
#  [0.4635843 ]
#  [0.83626   ]
#  [0.53024   ]]
# Theta1  [[ 2.7451396 -2.2979672]
#  [ 3.5302398  3.55839  ]]
# Bias1  [-0.44944835  1.7077626 ]
# Theta2  [[ 3.2845685]
#  [-3.0282247]]
# Bias2  [-0.27360663]
# cost  0.47355673
# Epoch  25000
# Hypothesis  [[0.1555872 ]
#  [0.46608287]
#  [0.85270137]
#  [0.52912337]]
# Theta1  [[ 2.8400602 -2.3914979]
#  [ 3.6977186  3.7202177]]
# Bias1  [-0.5022493  1.7579335]
# Theta2  [[ 3.4419363]
#  [-3.1726043]]
# Bias2  [-0.28301215]
# cost  0.4612527
# Epoch  26000
# Hypothesis  [[0.13965313]
#  [0.4684274 ]
#  [0.8670706 ]
#  [0.5278751 ]]
# Theta1  [[ 2.9271674 -2.4769692]
#  [ 3.8557894  3.8737133]]
# Bias1  [-0.549493   1.8036306]
# Theta2  [[ 3.5883842]
#  [-3.3081088]]
# Bias2  [-0.29114783]
# cost  0.4504851
# Epoch  27000
# Hypothesis  [[0.12588124]
#  [0.47059214]
#  [0.87958384]
#  [0.5265706 ]]
# Theta1  [[ 3.0070376 -2.555087 ]
#  [ 4.0045905  4.018838 ]]
# Bias1  [-0.59183604  1.8453208 ]
# Theta2  [[ 3.7245455]
#  [-3.4350271]]
# Bias2  [-0.29820156]
# cost  0.44109038
# Epoch  28000
# Hypothesis  [[0.11398408]
#  [0.47257107]
#  [0.89047164]
#  [0.5252631 ]]
# Theta1  [[ 3.0803146 -2.6265867]
#  [ 4.1444955  4.1558104]]
# Bias1  [-0.62991196  1.8834475 ]
# Theta2  [[ 3.8511858]
#  [-3.5538254]]
# Bias2  [-0.30433652]
# cost  0.4328965
# Epoch  29000
# Hypothesis  [[0.10369022]
#  [0.47436967]
#  [0.89995545]
#  [0.52398765]]
# Theta1  [[ 3.1476445 -2.6921766]
#  [ 4.2760243  4.2850127]]
# Bias1  [-0.6642929  1.9184175]
# Theta2  [[ 3.9691145]
#  [-3.665063 ]]
# Bias2  [-0.30969265]
# cost  0.42573977
# Epoch  30000
# Hypothesis  [[0.09475771]
#  [0.4759995 ]
#  [0.90823585]
#  [0.5227655 ]]
# Theta1  [[ 3.2096467 -2.7525082]
#  [ 4.3997464  4.4069104]]
# Bias1  [-0.69547874  1.950593  ]
# Theta2  [[ 4.07912  ]
#  [-3.7693238]]
# Bias2  [-0.31438783]
# cost  0.41947243
# Epoch  31000
# Hypothesis  [[0.08697741]
#  [0.47747657]
#  [0.9154895 ]
#  [0.5216102 ]]
# Theta1  [[ 3.2668886 -2.8081706]
#  [ 4.5162582  4.521998 ]]
# Bias1  [-0.72389746  1.9802959 ]
# Theta2  [[ 4.181954 ]
#  [-3.8671868]]
# Bias2  [-0.31852144]
# cost  0.41396517
# Epoch  32000
# Hypothesis  [[0.0801715 ]
#  [0.47881308]
#  [0.921867  ]
#  [0.5205246 ]]
# Theta1  [[ 3.3198824 -2.8596807]
#  [ 4.6261344  4.6307716]]
# Bias1  [-0.74991196  2.0078018 ]
# Theta2  [[ 4.278294 ]
#  [-3.9592066]]
# Bias2  [-0.32217777]
# cost  0.4091075
# Epoch  33000
# Hypothesis  [[0.074191  ]
#  [0.48002437]
#  [0.92749697]
#  [0.51951   ]]
# Theta1  [[ 3.3690825 -2.9075   ]
#  [ 4.729922   4.73372  ]]
# Bias1  [-0.77382976  2.0333626 ]
# Theta2  [[ 4.3687606]
#  [-4.0458937]]
# Bias2  [-0.32542545]
# cost  0.40480506
# Epoch  34000
# Hypothesis  [[0.06891254]
#  [0.48112804]
#  [0.9324883 ]
#  [0.5185688 ]]
# Theta1  [[ 3.4148915 -2.9520235]
#  [ 4.828122   4.831299 ]]
# Bias1  [-0.7959102  2.0571842]
# Theta2  [[ 4.453915 ]
#  [-4.1277065]]
# Bias2  [-0.32832223]
# cost  0.40097862
# Epoch  35000
# Hypothesis  [[0.06423163]
#  [0.48213002]
#  [0.93693125]
#  [0.5176919 ]]
# Theta1  [[ 3.4576588 -2.9936018]
#  [ 4.921194   4.9239283]]
# Bias1  [-0.816373  2.079447]
# Theta2  [[ 4.5342426]
#  [-4.205084 ]]
# Bias2  [-0.33091775]
# cost  0.39756155
# Epoch  36000
# Hypothesis  [[0.06006242]
#  [0.48304346]
#  [0.9409023 ]
#  [0.51687706]]
# Theta1  [[ 3.497695 -3.032538]
#  [ 5.009572  5.011997]]
# Bias1  [-0.83540475  2.100314  ]
# Theta2  [[ 4.6101866]
#  [-4.2784014]]
# Bias2  [-0.33325508]
# cost  0.39449763
# Epoch  37000
# Hypothesis  [[0.05633299]
#  [0.48387957]
#  [0.9444664 ]
#  [0.51612127]]
# Theta1  [[ 3.53527   -3.0690985]
#  [ 5.0936265  5.0958667]]
# Bias1  [-0.8531655  2.1199265]
# Theta2  [[ 4.682145 ]
#  [-4.3480096]]
# Bias2  [-0.33536264]
# cost  0.3917393
# Epoch  38000
# Hypothesis  [[0.05298328]
#  [0.48464584]
#  [0.94767696]
#  [0.5154194 ]]
# Theta1  [[ 3.570624  -3.1035113]
#  [ 5.1737103  5.1758547]]
# Bias1  [-0.8697921  2.138405 ]
# Theta2  [[ 4.7504587]
#  [-4.414212 ]]
# Bias2  [-0.33727223]
# cost  0.38924712
# Epoch  39000
# Hypothesis  [[0.04996303]
#  [0.48535097]
#  [0.95058024]
#  [0.51476794]]
# Theta1  [[ 3.6039655 -3.1359847]
#  [ 5.250137   5.252264 ]]
# Bias1  [-0.885402   2.1558533]
# Theta2  [[ 4.8154373]
#  [-4.4772825]]
# Bias2  [-0.33900678]
# cost  0.38698703
# Epoch  40000
# Hypothesis  [[0.04722911]
#  [0.48599893]
#  [0.95321417]
#  [0.5141605 ]]
# Theta1  [[ 3.6354804 -3.166691 ]
#  [ 5.3231754  5.3253493]]
# Bias1  [-0.90009713  2.1723723 ]
# Theta2  [[ 4.877355]
#  [-4.537477]]
# Bias2  [-0.3405897]
# cost  0.38493058
# Epoch  41000
# Hypothesis  [[0.0447464 ]
#  [0.48659918]
#  [0.9556126 ]
#  [0.51359606]]
# Theta1  [[ 3.6653233 -3.1957889]
#  [ 5.393099   5.3953657]]
# Bias1  [-0.91396534  2.1880276 ]
# Theta2  [[ 4.9364595]
#  [-4.5950065]]
# Bias2  [-0.34203845]
# cost  0.3830529
# Epoch  42000
# Hypothesis  [[0.0424833 ]
#  [0.48715338]
#  [0.9578032 ]
#  [0.5130691 ]]
# Theta1  [[ 3.693647  -3.2234194]
#  [ 5.460111   5.462523 ]]
# Bias1  [-0.9270845  2.2029104]
# Theta2  [[ 4.9929776]
#  [-4.6500955]]
# Bias2  [-0.34336397]
# cost  0.3813336
# Epoch  43000
# Hypothesis  [[0.04041401]
#  [0.48766458]
#  [0.9598099 ]
#  [0.5125737 ]]
# Theta1  [[ 3.7205746 -3.249709 ]
#  [ 5.524434   5.5270333]]
# Bias1  [-0.93952173  2.2170768 ]
# Theta2  [[ 5.0470934]
#  [-4.7029123]]
# Bias2  [-0.3445859]
# cost  0.37975425
# Epoch  44000
# Hypothesis  [[0.03851735]
#  [0.48814717]
#  [0.9616536 ]
#  [0.512118  ]]
# Theta1  [[ 3.74622   -3.2747586]
#  [ 5.5862556  5.589063 ]]
# Bias1  [-0.95133626  2.2305925 ]
# Theta2  [[ 5.0989933]
#  [-4.7535934]]
# Bias2  [-0.34570947]
# cost  0.37829995
# Epoch  45000
# Hypothesis  [[0.03677282]
#  [0.48859286]
#  [0.9633521 ]
#  [0.5116871 ]]
# Theta1  [[ 3.7706878 -3.298666 ]
#  [ 5.6457534  5.6487756]]
# Bias1  [-0.96258116  2.2434907 ]
# Theta2  [[ 5.1488314]
#  [-4.802324 ]]
# Bias2  [-0.34674913]
# cost  0.37695676
# Epoch  46000
# Hypothesis  [[0.03516355]
#  [0.48900506]
#  [0.9649204 ]
#  [0.5112792 ]]
# Theta1  [[ 3.794063  -3.321527 ]
#  [ 5.703056   5.7063475]]
# Bias1  [-0.97330284  2.25584   ]
# Theta2  [[ 5.1967545]
#  [-4.849241 ]]
# Bias2  [-0.3477108]
# cost  0.37571317
# Epoch  47000
# Hypothesis  [[0.03367647]
#  [0.4893942 ]
#  [0.9663727 ]
#  [0.51090014]]
# Theta1  [[ 3.8164325 -3.3434122]
#  [ 5.758332   5.7618856]]
# Bias1  [-0.98354155  2.2676709 ]
# Theta2  [[ 5.24289  ]
#  [-4.8944325]]
# Bias2  [-0.34860128]
# cost  0.37455946
# Epoch  48000
# Hypothesis  [[0.0322984 ]
#  [0.4897605 ]
#  [0.967721  ]
#  [0.51054525]]
# Theta1  [[ 3.8378654 -3.3643966]
#  [ 5.811698   5.8155265]]
# Bias1  [-0.993336   2.2790117]
# Theta2  [[ 5.2873726]
#  [-4.938032 ]]
# Bias2  [-0.34943128]
# cost  0.37348628
# Epoch  49000
# Hypothesis  [[0.0310185]
#  [0.4901014]
#  [0.9689746]
#  [0.510208 ]]
# Theta1  [[ 3.8584385 -3.3845417]
#  [ 5.8632817  5.8673763]]
# Bias1  [-1.0027186  2.2899003]
# Theta2  [[ 5.330278 ]
#  [-4.9801283]]
# Bias2  [-0.35020542]
# cost  0.37248605
# Epoch  50000
# Hypothesis  [[0.02982748]
#  [0.49042368]
#  [0.9701431 ]
#  [0.5098923 ]]
# Theta1  [[ 3.8781888 -3.4039106]
#  [ 5.9131646  5.9175744]]
# Bias1  [-1.0117179  2.3003745]
# Theta2  [[ 5.3717184]
#  [-5.020809 ]]
# Bias2  [-0.35092527]
# cost  0.37155217
# Epoch  51000
# Hypothesis  [[0.02871616]
#  [0.49072418]
#  [0.9712334 ]
#  [0.5095905 ]]
# Theta1  [[ 3.8971908 -3.4225447]
#  [ 5.9614778  5.966175 ]]
# Bias1  [-1.020362   2.3104792]
# Theta2  [[ 5.411779]
#  [-5.060176]]
# Bias2  [-0.3515964]
# cost  0.37067813
# Epoch  52000
# Hypothesis  [[0.02767765]
#  [0.4910044 ]
#  [0.97225404]
#  [0.5093028 ]]
# Theta1  [[ 3.9154916 -3.4404936]
#  [ 6.008293   6.013289 ]]
# Bias1  [-1.0286802  2.3201842]
# Theta2  [[ 5.450543]
#  [-5.098301]]
# Bias2  [-0.35222754]
# cost  0.36985904
# Epoch  53000
# Hypothesis  [[0.02670553]
#  [0.49127787]
#  [0.97321135]
#  [0.50903904]]
# Theta1  [[ 3.9331298 -3.457814 ]
#  [ 6.0536904  6.059006 ]]
# Bias1  [-1.036682   2.3295734]
# Theta2  [[ 5.488126]
#  [-5.135254]]
# Bias2  [-0.35281554]
# cost  0.36908966
# Epoch  54000
# Hypothesis  [[0.02579348]
#  [0.49153078]
#  [0.97410923]
#  [0.5087832 ]]
# Theta1  [[ 3.950143  -3.4745257]
#  [ 6.097757   6.103374 ]]
# Bias1  [-1.0444032  2.338635 ]
# Theta2  [[ 5.524534]
#  [-5.171094]]
# Bias2  [-0.35336962]
# cost  0.36836606
# Epoch  55000
# Hypothesis  [[0.02493665]
#  [0.49177036]
#  [0.9749546 ]
#  [0.5085407 ]]
# Theta1  [[ 3.9665818 -3.490686 ]
#  [ 6.1405873  6.146486 ]]
# Bias1  [-1.051848   2.3473823]
# Theta2  [[ 5.5598745]
#  [-5.205903 ]]
# Bias2  [-0.3538878]
# cost  0.3676842
# Epoch  56000
# Hypothesis  [[0.02413018]
#  [0.4919984 ]
#  [0.97575086]
#  [0.50831187]]
# Theta1  [[ 3.98248   -3.5063121]
#  [ 6.1821756  6.188413 ]]
# Bias1  [-1.0590384  2.3558547]
# Theta2  [[ 5.5942044]
#  [-5.2397294]]
# Bias2  [-0.35437497]
# cost  0.3670411
# Epoch  57000
# Hypothesis  [[0.02336998]
#  [0.49221492]
#  [0.9765019 ]
#  [0.50809354]]
# Theta1  [[ 3.9978542 -3.5214338]
#  [ 6.2226596  6.2292056]]
# Bias1  [-1.0659904  2.3640618]
# Theta2  [[ 5.627569]
#  [-5.272621]]
# Bias2  [-0.3548339]
# cost  0.36643314
# Epoch  58000
# Hypothesis  [[0.02265233]
#  [0.49241948]
#  [0.977211  ]
#  [0.50788486]]
# Theta1  [[ 4.0127068 -3.5360897]
#  [ 6.262075   6.268899 ]]
# Bias1  [-1.0727202  2.3720145]
# Theta2  [[ 5.6600122]
#  [-5.3046184]]
# Bias2  [-0.35527223]
# cost  0.3658581
# Epoch  59000
# Hypothesis  [[0.02197413]
#  [0.49261206]
#  [0.97788185]
#  [0.5076837 ]]
# Theta1  [[ 4.0271273 -3.5502856]
#  [ 6.300447   6.3075747]]
# Bias1  [-1.0792273  2.379726 ]
# Theta2  [[ 5.6915836]
#  [-5.3357797]]
# Bias2  [-0.3556841]
# cost  0.3653132
# Epoch  60000
# Hypothesis  [[0.02133308]
#  [0.49280676]
#  [0.97851735]
#  [0.5075032 ]]
# Theta1  [[ 4.0411105 -3.5640614]
#  [ 6.337845   6.3452754]]
# Bias1  [-1.0855395  2.3872092]
# Theta2  [[ 5.7223215]
#  [-5.3660865]]
# Bias2  [-0.3560725]
# cost  0.36479655
# Epoch  61000
# Hypothesis  [[0.02072502]
#  [0.49297938]
#  [0.9791196 ]
#  [0.5073177 ]]
# Theta1  [[ 4.05469   -3.5774531]
#  [ 6.3743157  6.3820457]]
# Bias1  [-1.091669   2.3944788]
# Theta2  [[ 5.752227]
#  [-5.395638]]
# Bias2  [-0.35643813]
# cost  0.36430573
# Epoch  62000
# Hypothesis  [[0.0201482]
#  [0.4931514]
#  [0.9796918]
#  [0.507148 ]]
# Theta1  [[ 4.0679    -3.590454 ]
#  [ 6.4098783  6.4179354]]
# Bias1  [-1.0976083  2.4015512]
# Theta2  [[ 5.781426 ]
#  [-5.4244647]]
# Bias2  [-0.35679263]
# cost  0.36383915
# Epoch  63000
# Hypothesis  [[0.01960039]
#  [0.49330997]
#  [0.980235  ]
#  [0.5069799 ]]
# Theta1  [[ 4.080775  -3.6031032]
#  [ 6.4445987  6.452971 ]]
# Bias1  [-1.1033846  2.4084432]
# Theta2  [[ 5.8098507]
#  [-5.4525733]]
# Bias2  [-0.35711464]
# cost  0.3633952
# Epoch  64000
# Hypothesis  [[0.01907967]
#  [0.49347493]
#  [0.9807525 ]
#  [0.506832  ]]
# Theta1  [[ 4.09318   -3.6153984]
#  [ 6.4785333  6.4871626]]
# Bias1  [-1.1090062  2.415119 ]
# Theta2  [[ 5.837651 ]
#  [-5.4800096]]
# Bias2  [-0.3574329]
# cost  0.36297196
# Epoch  65000
# Hypothesis  [[0.01858342]
#  [0.49360612]
#  [0.98124516]
#  [0.5066641 ]]
# Theta1  [[ 4.1053   -3.627393]
#  [ 6.511676  6.520613]]
# Bias1  [-1.1144602  2.4216099]
# Theta2  [[ 5.864721]
#  [-5.506846]]
# Bias2  [-0.35772988]
# cost  0.3625684
# Epoch  66000
# Hypothesis  [[0.01811135]
#  [0.49375382]
#  [0.9817152 ]
#  [0.506525  ]]
# Theta1  [[ 4.117184  -3.6390517]
#  [ 6.544073   6.5532937]]
# Bias1  [-1.1197735  2.4279633]
# Theta2  [[ 5.891195 ]
#  [-5.5330186]]
# Bias2  [-0.358003]
# cost  0.36218315
# Epoch  67000
# Hypothesis  [[0.01766085]
#  [0.49389842]
#  [0.98216325]
#  [0.5063944 ]]
# Theta1  [[ 4.1286283 -3.650414 ]
#  [ 6.57577    6.585281 ]]
# Bias1  [-1.1249512  2.4341621]
# Theta2  [[ 5.9170904]
#  [-5.5586066]]
# Bias2  [-0.35827163]
# cost  0.36181507
# Epoch  68000
# Hypothesis  [[0.01723073]
#  [0.4940327 ]
#  [0.98259234]
#  [0.50626457]]
# Theta1  [[ 4.139855  -3.661502 ]
#  [ 6.6067867  6.6165543]]
# Bias1  [-1.1299957  2.4401643]
# Theta2  [[ 5.9424105]
#  [-5.583648 ]]
# Bias2  [-0.35853207]
# cost  0.3614627
# Epoch  69000
# Hypothesis  [[0.01681908]
#  [0.4941505 ]
#  [0.98300123]
#  [0.5061285 ]]
# Theta1  [[ 4.150822  -3.6723237]
#  [ 6.6371217  6.6472187]]
# Bias1  [-1.1349134  2.446079 ]
# Theta2  [[ 5.967137 ]
#  [-5.6081567]]
# Bias2  [-0.35877594]
# cost  0.36112553
# Epoch  70000
# Hypothesis  [[0.01642574]
#  [0.49426627]
#  [0.98339325]
#  [0.5060006 ]]
# Theta1  [[ 4.1614532 -3.6828852]
#  [ 6.6668644  6.6771984]]
# Bias1  [-1.1397094  2.451801 ]
# Theta2  [[ 5.991344 ]
#  [-5.6321497]]
# Bias2  [-0.35900632]
# cost  0.36080253
# Epoch  71000
# Hypothesis  [[0.01604917]
#  [0.49438056]
#  [0.983769  ]
#  [0.50588036]]
# Theta1  [[ 4.1719437 -3.6932008]
#  [ 6.696008   6.7065763]]
# Bias1  [-1.144388  2.457417]
# Theta2  [[ 6.0150495]
#  [-5.6556425]]
# Bias2  [-0.35922277]
# cost  0.3604927
# Epoch  72000
# Hypothesis  [[0.01568839]
#  [0.49449167]
#  [0.9841286 ]
#  [0.50576586]]
# Theta1  [[ 4.182049  -3.7032743]
#  [ 6.7245197  6.73539  ]]
# Bias1  [-1.1489578  2.4629006]
# Theta2  [[ 6.0382705]
#  [-5.6786556]]
# Bias2  [-0.35942963]
# cost  0.36019558
# Epoch  73000
# Hypothesis  [[0.01534256]
#  [0.49460083]
#  [0.9844744 ]
#  [0.5056575 ]]
# Theta1  [[ 4.1920624 -3.713124 ]
#  [ 6.752487   6.763652 ]]
# Bias1  [-1.1534232  2.4682539]
# Theta2  [[ 6.0610266]
#  [-5.7012053]]
# Bias2  [-0.35962555]
# cost  0.35990992
# Epoch  74000
# Hypothesis  [[0.0150105 ]
#  [0.49470794]
#  [0.98480576]
#  [0.50555503]]
# Theta1  [[ 4.201723  -3.7227492]
#  [ 6.7799253  6.7913747]]
# Bias1  [-1.1577952  2.473499 ]
# Theta2  [[ 6.0833397]
#  [-5.7233157]]
# Bias2  [-0.35981128]
# cost  0.35963553
# Epoch  75000
# Hypothesis  [[0.01469158]
#  [0.49481416]
#  [0.9851248 ]
#  [0.50545925]]
# Theta1  [[ 4.21126   -3.732175 ]
#  [ 6.8068476  6.818557 ]]
# Bias1  [-1.1620759  2.4786282]
# Theta2  [[ 6.10523 ]
#  [-5.745007]]
# Bias2  [-0.35998166]
# cost  0.35937157
# Epoch  76000
# Hypothesis  [[0.01438522]
#  [0.49491107]
#  [0.98543173]
#  [0.5053612 ]]
# Theta1  [[ 4.220566  -3.7414012]
#  [ 6.833268   6.8452253]]
# Bias1  [-1.1662482  2.483635 ]
# Theta2  [[ 6.1266875]
#  [-5.766306 ]]
# Bias2  [-0.36013642]
# cost  0.35911745
# Epoch  77000
# Hypothesis  [[0.01408993]
#  [0.49498758]
#  [0.9857259 ]
#  [0.50524944]]
# Theta1  [[ 4.2296257 -3.7504542]
#  [ 6.8592033  6.871413 ]]
# Bias1  [-1.1703261  2.488579 ]
# Theta2  [[ 6.1477036]
#  [-5.7872357]]
# Bias2  [-0.3602863]
# cost  0.35887283
# Epoch  78000
# Hypothesis  [[0.01380627]
#  [0.4950703 ]
#  [0.9860102 ]
#  [0.5051504 ]]
# Theta1  [[ 4.2386837 -3.7592757]
#  [ 6.8846703  6.897139 ]]
# Bias1  [-1.1743312  2.4933474]
# Theta2  [[ 6.168346]
#  [-5.807743]]
# Bias2  [-0.3604479]
# cost  0.35863698
# Epoch  79000
# Hypothesis  [[0.01353287]
#  [0.4951648 ]
#  [0.98628217]
#  [0.5050687 ]]
# Theta1  [[ 4.247267  -3.7679183]
#  [ 6.9096866  6.9224114]]
# Bias1  [-1.1782651  2.4981158]
# Theta2  [[ 6.1886435]
#  [-5.827859 ]]
# Bias2  [-0.3605964]
# cost  0.35840976
# Epoch  80000
# Hypothesis  [[0.01327032]
#  [0.4952611 ]
#  [0.9865476 ]
#  [0.50499535]]
# Theta1  [[ 4.25585   -3.7764146]
#  [ 6.9342713  6.9472136]]
# Bias1  [-1.1820815  2.5026913]
# Theta2  [[ 6.2086253]
#  [-5.847669 ]]
# Bias2  [-0.3607173]
# cost  0.3581903
# Epoch  81000
# Hypothesis  [[0.01301592]
#  [0.49532568]
#  [0.98680216]
#  [0.50489575]]
# Theta1  [[ 4.264306  -3.7847593]
#  [ 6.9584446  6.9715924]]
# Bias1  [-1.1858472  2.5072212]
# Theta2  [[ 6.2281756]
#  [-5.867179 ]]
# Bias2  [-0.3608228]
# cost  0.35797846
# Epoch  82000
# Hypothesis  [[0.01277066]
#  [0.49540222]
#  [0.9870455 ]
#  [0.5048122 ]]
# Theta1  [[ 4.2724123 -3.7928834]
#  [ 6.9822264  6.995567 ]]
# Bias1  [-1.1895427  2.511727 ]
# Theta2  [[ 6.2473965]
#  [-5.8862724]]
# Bias2  [-0.36095798]
# cost  0.35777387
# Epoch  83000
# Hypothesis  [[0.01253497]
#  [0.4954901 ]
#  [0.98728454]
#  [0.50474626]]
# Theta1  [[ 4.2805185 -3.8008966]
#  [ 7.0055914  7.019155 ]]
# Bias1  [-1.1931399  2.5160186]
# Theta2  [[ 6.266365 ]
#  [-5.9050846]]
# Bias2  [-0.36106613]
# cost  0.35757604
# Epoch  84000
# Hypothesis  [[0.01230582]
#  [0.49555212]
#  [0.98751384]
#  [0.5046591 ]]
# Theta1  [[ 4.288515  -3.8087645]
#  [ 7.0285273  7.0423813]]
# Bias1  [-1.1967093  2.5203102]
# Theta2  [[ 6.2849617]
#  [-5.9236465]]
# Bias2  [-0.3611452]
# cost  0.35738468
# Epoch  85000
# Hypothesis  [[0.01208531]
#  [0.49562368]
#  [0.9877335 ]
#  [0.504585  ]]
# Theta1  [[ 4.2961445 -3.816444 ]
#  [ 7.051118   7.065267 ]]
# Bias1  [-1.2001663  2.5245745]
# Theta2  [[ 6.303237]
#  [-5.941804]]
# Bias2  [-0.36126226]
# cost  0.3571998
# Epoch  86000
# Hypothesis  [[0.01187197]
#  [0.49570867]
#  [0.9879501 ]
#  [0.5045303 ]]
# Theta1  [[ 4.303774  -3.8240511]
#  [ 7.073388   7.0876784]]
# Bias1  [-1.2036016  2.5286276]
# Theta2  [[ 6.321333 ]
#  [-5.9597597]]
# Bias2  [-0.36133826]
# cost  0.35702053
# Epoch  87000
# Hypothesis  [[0.01166542]
#  [0.49575496]
#  [0.98815656]
#  [0.50443995]]
# Theta1  [[ 4.3114033 -3.831442 ]
#  [ 7.0953226  7.109777 ]]
# Bias1  [-1.2069395  2.5326807]
# Theta2  [[ 6.338976 ]
#  [-5.9774027]]
# Bias2  [-0.36142287]
# cost  0.3568471
# Epoch  88000
# Hypothesis  [[0.01146527]
#  [0.4958316 ]
#  [0.98835677]
#  [0.5043843 ]]
# Theta1  [[ 4.318633  -3.8387737]
#  [ 7.1168237  7.131591 ]]
# Bias1  [-1.210249   2.5367339]
# Theta2  [[ 6.3564568]
#  [-5.994747 ]]
# Bias2  [-0.36151055]
# cost  0.35667908
# Epoch  89000
# Hypothesis  [[0.01127172]
#  [0.49588197]
#  [0.9885513 ]
#  [0.50430626]]
# Theta1  [[ 4.3257856 -3.8459263]
#  [ 7.1380596  7.1530485]]
# Bias1  [-1.2134676  2.5406053]
# Theta2  [[ 6.373623 ]
#  [-6.0119133]]
# Bias2  [-0.36156204]
# cost  0.35651618
# Epoch  90000
# Hypothesis  [[0.01108443]
#  [0.4959518 ]
#  [0.98874027]
#  [0.5042513 ]]
# Theta1  [[ 4.332938  -3.8529928]
#  [ 7.1590405  7.1741276]]
# Bias1  [-1.2166715  2.54442  ]
# Theta2  [[ 6.390533]
#  [-6.0287  ]]
# Bias2  [-0.36165273]
# cost  0.35635817
# Epoch  91000
# Hypothesis  [[0.01090249]
#  [0.4960061 ]
#  [0.9889234 ]
#  [0.50418437]]
# Theta1  [[ 4.3400846 -3.859907 ]
#  [ 7.179567   7.194979 ]]
# Bias1  [-1.2197709  2.5482347]
# Theta2  [[ 6.4072223]
#  [-6.04537  ]]
# Bias2  [-0.36169177]
# cost  0.35620475
# Epoch  92000
# Hypothesis  [[0.01072592]
#  [0.49606818]
#  [0.989099  ]
#  [0.5041282 ]]
# Theta1  [[ 4.3467603 -3.8667574]
#  [ 7.1998906  7.215483 ]]
# Bias1  [-1.2228703  2.5520418]
# Theta2  [[ 6.42361  ]
#  [-6.0616565]]
# Bias2  [-0.36177728]
# cost  0.3560561
# Epoch  93000
# Hypothesis  [[0.01055531]
#  [0.49611968]
#  [0.989272  ]
#  [0.5040654 ]]
# Theta1  [[ 4.353436  -3.873433 ]
#  [ 7.219918   7.2356634]]
# Bias1  [-1.2258582  2.555618 ]
# Theta2  [[ 6.4398227]
#  [-6.077856 ]]
# Bias2  [-0.3618101]
# cost  0.35591167
# Epoch  94000
# Hypothesis  [[0.01038977]
#  [0.49617884]
#  [0.9894394 ]
#  [0.50401294]]
# Theta1  [[ 4.3601117 -3.8800802]
#  [ 7.2395988  7.25569  ]]
# Bias1  [-1.2288384  2.5591943]
# Theta2  [[ 6.45574  ]
#  [-6.0936766]]
# Bias2  [-0.36188877]
# cost  0.35577127
# Epoch  95000
# Hypothesis  [[0.01022818]
#  [0.49622557]
#  [0.9896013 ]
#  [0.5039508 ]]
# Theta1  [[ 4.3667874 -3.8865175]
#  [ 7.259149   7.2752404]]
# Bias1  [-1.2317635  2.5627706]
# Theta2  [[ 6.4714756]
#  [-6.109412 ]]
# Bias2  [-0.3619172]
# cost  0.3556347
# Epoch  96000
# Hypothesis  [[0.01007188]
#  [0.49628675]
#  [0.98975825]
#  [0.50390595]]
# Theta1  [[ 4.3731384 -3.8929548]
#  [ 7.2782245  7.2946663]]
# Bias1  [-1.2346245  2.566347 ]
# Theta2  [[ 6.486979]
#  [-6.124813]]
# Bias2  [-0.36198205]
# cost  0.3555022
# Epoch  97000
# Hypothesis  [[0.00991964]
#  [0.49632934]
#  [0.989911  ]
#  [0.5038457 ]]
# Theta1  [[ 4.3793373 -3.8992198]
#  [ 7.297212   7.31374  ]]
# Bias1  [-1.2374855  2.5697324]
# Theta2  [[ 6.502238]
#  [-6.140072]]
# Bias2  [-0.3620144]
# cost  0.35537332
# Epoch  98000
# Hypothesis  [[0.00977233]
#  [0.49638978]
#  [0.99006104]
#  [0.5038063 ]]
# Theta1  [[ 4.385536  -3.9054186]
#  [ 7.315809   7.332612 ]]
# Bias1  [-1.2402396  2.5730703]
# Theta2  [[ 6.5173893]
#  [-6.155135 ]]
# Bias2  [-0.3620576]
# cost  0.35524794
# Epoch  99000
# Hypothesis  [[0.00962894]
#  [0.49642774]
#  [0.99020535]
#  [0.5037462 ]]
# Theta1  [[ 4.391735  -3.9115462]
#  [ 7.334273   7.3512087]]
# Bias1  [-1.2429814  2.5764081]
# Theta2  [[ 6.5321712]
#  [-6.169917 ]]
# Bias2  [-0.3620992]
# cost  0.3551259
# Elapsed time  51.973546

# %% [markdown]
# ## Model 2
#
# Substitute hyperbolic (tanh) activation function for the sigmoid activation in layer 2

# %%
x_ = tf.placeholder(tf.float32, shape=[4,2], name = 'x-input')
y_ = tf.placeholder(tf.float32, shape=[4,1], name = 'y-input')

Theta1 = tf.Variable(tf.random_uniform([2,2], -1, 1), name = "Theta1")
Theta2 = tf.Variable(tf.random_uniform([2,1], -1, 1), name = "Theta2")

Bias1 = tf.Variable(tf.zeros([2]), name = "Bias1")
Bias2 = tf.Variable(tf.zeros([1]), name = "Bias2")

with tf.name_scope("layer2") as scope:
	A2 = tf.tanh(tf.matmul(x_, Theta1) + Bias1)

with tf.name_scope("layer3") as scope:
	Hypothesis = tf.sigmoid(tf.matmul(A2, Theta2) + Bias2)

with tf.name_scope("cost") as scope:
	cost = tf.reduce_mean(( (y_ * tf.log(Hypothesis)) + 
		((1 - y_) * tf.log(1.0 - Hypothesis)) ) * -1)

with tf.name_scope("train") as scope:
	train_step = tf.train.GradientDescentOptimizer(0.01).minimize(cost)
  
XOR_X = [[0,0],[0,1],[1,0],[1,1]]
XOR_Y = [[0],[1],[1],[0]]

init = tf.global_variables_initializer()
sess = tf.Session()

#writer = tf.summary.FileWriter("./logs/xor_logs", sess.graph)

sess.run(init)

t_start = time.clock()
for i in range(100000):
	sess.run(train_step, feed_dict={x_: XOR_X, y_: XOR_Y})
	if i % 1000 == 0:
		print('Epoch ', i)
		print('Hypothesis ', sess.run(Hypothesis, feed_dict={x_: XOR_X, y_: XOR_Y}))
		print('Theta1 ', sess.run(Theta1))
		print('Bias1 ', sess.run(Bias1))
		print('Theta2 ', sess.run(Theta2))
		print('Bias2 ', sess.run(Bias2))
		print('cost ', sess.run(cost, feed_dict={x_: XOR_X, y_: XOR_Y}))
t_end = time.clock()
print('Elapsed time ', t_end - t_start)
# Out:
# Epoch  0
# Hypothesis  [[0.49984598]
#  [0.5847971 ]
#  [0.5301093 ]
#  [0.5923024 ]]
# Theta1  [[ 0.44006395  0.1013131 ]
#  [ 0.818389   -0.22679135]]
# Bias1  [-4.6198442e-05  2.1032672e-04]
# Theta2  [[ 0.38464987]
#  [-0.37569836]]
# Bias2  [-0.00051929]
# cost  0.6903078
# Epoch  1000
# Hypothesis  [[0.43973786]
#  [0.54971534]
#  [0.50675505]
#  [0.55955416]]
# Theta1  [[ 0.7096743   0.1781341 ]
#  [ 0.94072783 -0.11885826]]
# Bias1  [0.01005977 0.09657937]
# Theta2  [[ 0.54627657]
#  [-0.36203325]]
# Bias2  [-0.21286458]
# cost  0.6693501
# Epoch  2000
# Hypothesis  [[0.38000372]
#  [0.57151604]
#  [0.53289914]
#  [0.58267474]]
# Theta1  [[ 1.0552616   0.2753368 ]
#  [ 1.1653717  -0.03517294]]
# Bias1  [-0.06056732  0.16268046]
# Theta2  [[ 0.8847472 ]
#  [-0.41493675]]
# Bias2  [-0.36909828]
# cost  0.63520426
# Epoch  3000
# Hypothesis  [[0.2867806 ]
#  [0.60667664]
#  [0.5624128 ]
#  [0.6062222 ]]
# Theta1  [[1.434809   0.4039786 ]
#  [1.4660288  0.03358523]]
# Bias1  [-0.2114637  0.2018269]
# Theta2  [[ 1.2875129 ]
#  [-0.55133176]]
# Bias2  [-0.5330094]
# cost  0.5863033
# Epoch  4000
# Hypothesis  [[0.20397511]
#  [0.6509115 ]
#  [0.5828612 ]
#  [0.615749  ]]
# Theta1  [[1.7915092  0.55968493]
#  [1.7715205  0.07451563]]
# Bias1  [-0.34854615  0.1668017 ]
# Theta2  [[ 1.6645806]
#  [-0.7686705]]
# Bias2  [-0.6768161]
# cost  0.53844297
# Epoch  5000
# Hypothesis  [[0.15512967]
#  [0.7038652 ]
#  [0.5865075 ]
#  [0.6065042 ]]
# Theta1  [[2.096383   0.73496985]
#  [2.0275831  0.10344443]]
# Bias1  [-0.46126795  0.03279285]
# Theta2  [[ 1.9803586]
#  [-1.0519261]]
# Bias2  [-0.80667204]
# cost  0.49649882
# Epoch  6000
# Hypothesis  [[0.1361464 ]
#  [0.75828475]
#  [0.59027714]
#  [0.58117664]]
# Theta1  [[2.3580709  0.87696964]
#  [2.229852   0.20127752]]
# Bias1  [-0.57772565 -0.20100643]
# Theta2  [[ 2.251746 ]
#  [-1.3816735]]
# Bias2  [-0.9485337]
# cost  0.45512936
# Epoch  7000
# Hypothesis  [[0.14657222]
#  [0.78752905]
#  [0.6651378 ]
#  [0.5307671 ]]
# Theta1  [[2.5796328  0.88340724]
#  [2.4025822  0.50093406]]
# Bias1  [-0.7328049 -0.6027064]
# Theta2  [[ 2.4785576]
#  [-1.7953215]]
# Bias2  [-1.1808225]
# cost  0.3904416
# Epoch  8000
# Hypothesis  [[0.16223705]
#  [0.8073424 ]
#  [0.78944755]
#  [0.4084711 ]]
# Theta1  [[2.7438657  0.97898203]
#  [2.5792067  0.9060048 ]]
# Bias1  [-0.92866683 -1.1320437 ]
# Theta2  [[ 2.6774123]
#  [-2.3192046]]
# Bias2  [-1.5697805]
# cost  0.28812355
# Epoch  9000
# Hypothesis  [[0.14918187]
#  [0.85956573]
#  [0.8593401 ]
#  [0.2844012 ]]
# Theta1  [[2.86846   1.2243398]
#  [2.7386434 1.2038563]]
# Bias1  [-1.095384  -1.6156651]
# Theta2  [[ 2.915472 ]
#  [-2.7746174]]
# Bias2  [-1.975778]
# cost  0.19977775
# Epoch  10000
# Hypothesis  [[0.12432822]
#  [0.8995711 ]
#  [0.900405  ]
#  [0.20026448]]
# Theta1  [[2.967322  1.443663 ]
#  [2.8624887 1.4300039]]
# Bias1  [-1.21237   -1.9889996]
# Theta2  [[ 3.153485 ]
#  [-3.1256967]]
# Bias2  [-2.3221748]
# cost  0.14174646
# Epoch  11000
# Hypothesis  [[0.10216965]
#  [0.92465156]
#  [0.9253818 ]
#  [0.1485268 ]]
# Theta1  [[3.0462093 1.6127814]
#  [2.957944  1.6012603]]
# Bias1  [-1.2935888 -2.2660384]
# Theta2  [[ 3.3670924]
#  [-3.397386 ]]
# Bias2  [-2.602497]
# cost  0.10611214
# Epoch  12000
# Hypothesis  [[0.08510286]
#  [0.9407299 ]
#  [0.9413062 ]
#  [0.11585649]]
# Theta1  [[3.1103547 1.7436527]
#  [3.0335958 1.7333635]]
# Bias1  [-1.3527102 -2.4764085]
# Theta2  [[ 3.5529957]
#  [-3.6145554]]
# Bias2  [-2.8310268]
# cost  0.08341638
# Epoch  13000
# Hypothesis  [[0.07223396]
#  [0.95159817]
#  [0.9520543 ]
#  [0.09406035]]
# Theta1  [[3.163726  1.8478059]
#  [3.095374  1.8383992]]
# Bias1  [-1.3979574 -2.6418388]
# Theta2  [[ 3.7145743]
#  [-3.793907 ]]
# Bias2  [-3.0214107]
# cost  0.06812598
# Epoch  14000
# Hypothesis  [[0.06241377]
#  [0.9593201 ]
#  [0.959688  ]
#  [0.07873634]]
# Theta1  [[3.2090783 1.9330753]
#  [3.1471357 1.9243567]]
# Bias1  [-1.4340475 -2.776143 ]
# Theta2  [[ 3.8561516]
#  [-3.9460526]]
# Bias2  [-3.1834948]
# cost  0.057283264
# Epoch  15000
# Hypothesis  [[0.05476785]
#  [0.96503943]
#  [0.96534204]
#  [0.0674782 ]]
# Theta1  [[3.2483153 2.0045953]
#  [3.1914246 1.9964366]]
# Bias1  [-1.4637818 -2.8880913]
# Theta2  [[ 3.98149  ]
#  [-4.0778856]]
# Bias2  [-3.324095]
# cost  0.049261637
# Epoch  16000
# Hypothesis  [[0.04868944]
#  [0.96942127]
#  [0.96967477]
#  [0.05890632]]
# Theta1  [[3.2827718 2.0657897]
#  [3.2299747 2.058099 ]]
# Bias1  [-1.4889073 -2.983418 ]
# Theta2  [[ 4.0935874]
#  [-4.1940465]]
# Bias2  [-3.4479718]
# cost  0.043119464
# Epoch  17000
# Hypothesis  [[0.04376368]
#  [0.97287285]
#  [0.97308856]
#  [0.05218688]]
# Theta1  [[3.3134127 2.1190135]
#  [3.2640028 2.1117227]]
# Bias1  [-1.5105691 -3.0660152]
# Theta2  [[ 4.194774]
#  [-4.297785]]
# Bias2  [-3.5585275]
# cost  0.038282543
# Epoch  18000
# Hypothesis  [[0.03970338]
#  [0.9756547 ]
#  [0.9758406 ]
#  [0.04679184]]
# Theta1  [[3.3409426 2.1659393]
#  [3.2943907 2.158991 ]]
# Bias1  [-1.5295467 -3.1386116]
# Theta2  [[ 4.2868667]
#  [-4.3914547]]
# Bias2  [-3.6582558]
# cost  0.03438439
# Epoch  19000
# Hypothesis  [[0.03630619]
#  [0.9779399 ]
#  [0.97810215]
#  [0.04237268]]
# Theta1  [[3.3659017 2.20778  ]
#  [3.321799  2.2011344]]
# Bias1  [-1.5463933 -3.2031775]
# Theta2  [[ 4.371283 ]
#  [-4.4768085]]
# Bias2  [-3.74903]
# cost  0.03118163
# Epoch  20000
# Hypothesis  [[0.0334262]
#  [0.9798478]
#  [0.9799907]
#  [0.0386919]]
# Theta1  [[3.3887048 2.2454479]
#  [3.3467193 2.2390685]]
# Bias1  [-1.5615114 -3.2611797]
# Theta2  [[ 4.449156]
#  [-4.555181]]
# Bias2  [-3.8322878]
# cost  0.028507039
# Epoch  21000
# Hypothesis  [[0.0309566 ]
#  [0.9814627 ]
#  [0.98158985]
#  [0.03558183]]
# Theta1  [[3.4096713 2.2796361]
#  [3.3695452 2.2734954]]
# Bias1  [-1.575203 -3.313729]
# Theta2  [[ 4.5213895]
#  [-4.627616 ]]
# Bias2  [-3.9091516]
# cost  0.026242292
# Epoch  22000
# Hypothesis  [[0.02881715]
#  [0.9828462 ]
#  [0.9829601 ]
#  [0.0329216 ]]
# Theta1  [[3.4290578 2.3108895]
#  [3.3905797 2.3049617]]
# Bias1  [-1.5876988 -3.3616881]
# Theta2  [[ 4.5887275]
#  [-4.6949396]]
# Bias2  [-3.9805136]
# cost  0.02430141
# Epoch  23000
# Hypothesis  [[0.02694761]
#  [0.98404366]
#  [0.98414654]
#  [0.03062155]]
# Theta1  [[3.4470751 2.3396292]
#  [3.410069  2.3338978]]
# Bias1  [-1.5991817 -3.4057345]
# Theta2  [[ 4.6517563]
#  [-4.7578197]]
# Bias2  [-4.047093]
# cost  0.022620754
# Epoch  24000
# Hypothesis  [[0.02530005]
#  [0.98508966]
#  [0.98518306]
#  [0.02861459]]
# Theta1  [[3.4638987 2.3662066]
#  [3.4282165 2.3606482]]
# Bias1  [-1.6097916 -3.4464135]
# Theta2  [[ 4.7110023]
#  [-4.816796 ]]
# Bias2  [-4.109487]
# cost  0.02115199
# Epoch  25000
# Hypothesis  [[0.02383833]
#  [0.98601055]
#  [0.98609585]
#  [0.02684803]]
# Theta1  [[3.479663  2.3908966]
#  [3.445172  2.3855033]]
# Bias1  [-1.6196471 -3.4841685]
# Theta2  [[ 4.7668624]
#  [-4.8723283]]
# Bias2  [-4.1681867]
# cost  0.019858006
# Epoch  26000
# Hypothesis  [[0.02253321]
#  [0.98682773]
#  [0.98690575]
#  [0.02528271]]
# Theta1  [[3.4944954 2.4139378]
#  [3.4610891 2.408685 ]]
# Bias1  [-1.6288445 -3.5193613]
# Theta2  [[ 4.81971  ]
#  [-4.9247913]]
# Bias2  [-4.2235785]
# cost  0.018709809
# Epoch  27000
# Hypothesis  [[0.02136087]
#  [0.9875572 ]
#  [0.98762906]
#  [0.02388595]]
# Theta1  [[3.508481  2.4355114]
#  [3.4760716 2.4303977]]
# Bias1  [-1.6374567 -3.5522914]
# Theta2  [[ 4.869853 ]
#  [-4.9745135]]
# Bias2  [-4.276032]
# cost  0.017684292
# Epoch  28000
# Hypothesis  [[0.02030241]
#  [0.9882119 ]
#  [0.9882783 ]
#  [0.02263222]]
# Theta1  [[3.521719  2.4557903]
#  [3.4902256 2.450798 ]]
# Bias1  [-1.6455542 -3.583214 ]
# Theta2  [[ 4.9175305]
#  [-5.0217485]]
# Bias2  [-4.325832]
# cost  0.016763158
# Epoch  29000
# Hypothesis  [[0.01934223]
#  [0.98880273]
#  [0.98886454]
#  [0.02150105]]
# Theta1  [[3.5342827 2.4748967]
#  [3.5036268 2.470031 ]]
# Bias1  [-1.6531918 -3.6123443]
# Theta2  [[ 4.9629726]
#  [-5.0667367]]
# Bias2  [-4.3732314]
# cost  0.015931422
# Epoch  30000
# Hypothesis  [[0.01846724]
#  [0.98933864]
#  [0.98939615]
#  [0.02047541]]
# Theta1  [[3.5462203 2.4929636]
#  [3.5163467 2.4882045]]
# Bias1  [-1.6604131 -3.639861 ]
# Theta2  [[ 5.00639 ]
#  [-5.109687]]
# Bias2  [-4.4184556]
# cost  0.015176719
# Epoch  31000
# Hypothesis  [[0.01766694]
#  [0.9898269 ]
#  [0.9898808 ]
#  [0.01954146]]
# Theta1  [[3.5576081 2.5100813]
#  [3.5284624 2.5054324]]
# Bias1  [-1.667262 -3.665927]
# Theta2  [[ 5.047953 ]
#  [-5.1507807]]
# Bias2  [-4.4616823]
# cost  0.0144889215
# Epoch  32000
# Hypothesis  [[0.01693219]
#  [0.9902732 ]
#  [0.99032354]
#  [0.01868743]]
# Theta1  [[3.5684793 2.5263522]
#  [3.5400019 2.5217876]]
# Bias1  [-1.673774 -3.690667]
# Theta2  [[ 5.0877953]
#  [-5.1901517]]
# Bias2  [-4.503078]
# cost  0.013859859
# Epoch  33000
# Hypothesis  [[0.01625512]
#  [0.99068296]
#  [0.99073035]
#  [0.01790361]]
# Theta1  [[3.5788717 2.5418308]
#  [3.5510285 2.5373614]]
# Bias1  [-1.6799744 -3.7142136]
# Theta2  [[ 5.1260724]
#  [-5.2279606]]
# Bias2  [-4.542812]
# cost  0.013282035
# Epoch  34000
# Hypothesis  [[0.01562935]
#  [0.9910602 ]
#  [0.99110466]
#  [0.01718158]]
# Theta1  [[3.588828  2.5566006]
#  [3.5615876 2.5522113]]
# Bias1  [-1.6858987 -3.7366557]
# Theta2  [[ 5.1628833]
#  [-5.264308 ]]
# Bias2  [-4.5809965]
# cost  0.012749703
# Epoch  35000
# Hypothesis  [[0.0150497 ]
#  [0.99140877]
#  [0.99145085]
#  [0.01651507]]
# Theta1  [[3.5983973 2.5707004]
#  [3.571712  2.5664036]]
# Bias1  [-1.6915594 -3.7580953]
# Theta2  [[ 5.198338 ]
#  [-5.2993073]]
# Bias2  [-4.617732]
# cost  0.012257831
# Epoch  36000
# Hypothesis  [[0.01451106]
#  [0.991732  ]
#  [0.99177176]
#  [0.01589737]]
# Theta1  [[3.6075842 2.5842166]
#  [3.5814154 2.5799863]]
# Bias1  [-1.6969821 -3.77861  ]
# Theta2  [[ 5.2325635]
#  [-5.333081 ]]
# Bias2  [-4.653132]
# cost  0.011801781
# Epoch  37000
# Hypothesis  [[0.01400891]
#  [0.9920317 ]
#  [0.9920696 ]
#  [0.01532311]]
# Theta1  [[3.6164439 2.5971565]
#  [3.5907726 2.5930147]]
# Bias1  [-1.7021791 -3.7982697]
# Theta2  [[ 5.2655745]
#  [-5.365652 ]]
# Bias2  [-4.687323]
# cost  0.01137797
# Epoch  38000
# Hypothesis  [[0.0135403 ]
#  [0.9923113 ]
#  [0.99234724]
#  [0.01478908]]
# Theta1  [[3.6249557 2.6095848]
#  [3.5997512 2.6055095]]
# Bias1  [-1.7071766 -3.817143 ]
# Theta2  [[ 5.2975116]
#  [-5.3971515]]
# Bias2  [-4.7203245]
# cost  0.010983247
# Epoch  39000
# Hypothesis  [[0.01310145]
#  [0.99257225]
#  [0.9926064 ]
#  [0.01428995]]
# Theta1  [[3.633182  2.6215358]
#  [3.6084292 2.6175294]]
# Bias1  [-1.7119924 -3.8352761]
# Theta2  [[ 5.328426]
#  [-5.427638]]
# Bias2  [-4.752265]
# cost  0.010614411
# Epoch  40000
# Hypothesis  [[0.01268998]
#  [0.9928163 ]
#  [0.99284863]
#  [0.01382276]]
# Theta1  [[3.6411338 2.6330476]
#  [3.6168144 2.629094 ]]
# Bias1  [-1.7166203 -3.8527224]
# Theta2  [[ 5.3583736]
#  [-5.45717  ]]
# Bias2  [-4.7831955]
# cost  0.010269241
# Epoch  41000
# Hypothesis  [[0.01230337]
#  [0.9930453 ]
#  [0.9930761 ]
#  [0.01338506]]
# Theta1  [[3.6488228 2.644135 ]
#  [3.6248875 2.6402316]]
# Bias1  [-1.7210894 -3.8695395]
# Theta2  [[ 5.3874164]
#  [-5.48581  ]]
# Bias2  [-4.8131714]
# cost  0.009945533
# Epoch  42000
# Hypothesis  [[0.01193944]
#  [0.9932603 ]
#  [0.99328995]
#  [0.01297357]]
# Theta1  [[3.6562622 2.6548264]
#  [3.6327026 2.650996 ]]
# Bias1  [-1.7254117 -3.8857598]
# Theta2  [[ 5.415621 ]
#  [-5.5136275]]
# Bias2  [-4.842255]
# cost  0.009641227
# Epoch  43000
# Hypothesis  [[0.01159554]
#  [0.99346256]
#  [0.9934908 ]
#  [0.0125866 ]]
# Theta1  [[3.6634657 2.6651716]
#  [3.6402726 2.6613796]]
# Bias1  [-1.7295836 -3.901431 ]
# Theta2  [[ 5.443022]
#  [-5.540603]]
# Bias2  [-4.8705153]
# cost  0.009354784
# Epoch  44000
# Hypothesis  [[0.01127168]
#  [0.9936532 ]
#  [0.99368036]
#  [0.01222137]]
# Theta1  [[3.670449  2.6751568]
#  [3.6476119 2.6714382]]
# Bias1  [-1.7336177 -3.9165776]
# Theta2  [[ 5.469634 ]
#  [-5.5668592]]
# Bias2  [-4.8979506]
# cost  0.009084774
# Epoch  45000
# Hypothesis  [[0.01096458]
#  [0.99383366]
#  [0.99385947]
#  [0.0118773 ]]
# Theta1  [[3.6772292 2.6848238]
#  [3.6547368 2.6811414]]
# Bias1  [-1.7375257 -3.9312274]
# Theta2  [[ 5.4955697]
#  [-5.592388 ]]
# Bias2  [-4.924644]
# cost  0.008829603
# Epoch  46000
# Hypothesis  [[0.01067441]
#  [0.9940041 ]
#  [0.9940288 ]
#  [0.01155059]]
# Theta1  [[3.6838257 2.6941993]
#  [3.661651  2.6905563]]
# Bias1  [-1.7413175 -3.9454172]
# Theta2  [[ 5.5207844]
#  [-5.6172876]]
# Bias2  [-4.9506273]
# cost  0.008588174
# Epoch  47000
# Hypothesis  [[0.01039817]
#  [0.9941649 ]
#  [0.99418867]
#  [0.01124141]]
# Theta1  [[3.6902602 2.703294 ]
#  [3.6683397 2.6996908]]
# Bias1  [-1.7449982 -3.9591599]
# Theta2  [[ 5.5453615]
#  [-5.641481 ]]
# Bias2  [-4.9759526]
# cost  0.008359545
# Epoch  48000
# Hypothesis  [[0.01013614]
#  [0.99431795]
#  [0.994341  ]
#  [0.01094894]]
# Theta1  [[3.696459  2.7120993]
#  [3.6748505 2.7085586]]
# Bias1  [-1.7485745 -3.9725032]
# Theta2  [[ 5.5693545]
#  [-5.665098 ]]
# Bias2  [-5.0005946]
# cost  0.008142624
# Epoch  49000
# Hypothesis  [[0.00988688]
#  [0.9944635 ]
#  [0.9944858 ]
#  [0.0106708 ]]
# Theta1  [[3.7025146 2.720654 ]
#  [3.681205  2.7171643]]
# Bias1  [-1.7520342 -3.985471 ]
# Theta2  [[ 5.5927606]
#  [-5.6881547]]
# Bias2  [-5.024658]
# cost  0.007936382
# Epoch  50000
# Hypothesis  [[0.00964974]
#  [0.9946016 ]
#  [0.99462295]
#  [0.01040534]]
# Theta1  [[3.7084575 2.7289712]
#  [3.687404  2.7255225]]
# Bias1  [-1.7554015 -3.9980412]
# Theta2  [[ 5.61557 ]
#  [-5.710668]]
# Bias2  [-5.0481563]
# cost  0.007740267
# Epoch  51000
# Hypothesis  [[0.00942343]
#  [0.9947331 ]
#  [0.9947536 ]
#  [0.01015296]]
# Theta1  [[3.7141795 2.7370641]
#  [3.6933875 2.73364  ]]
# Bias1  [-1.7586873 -4.010288 ]
# Theta2  [[ 5.637856 ]
#  [-5.7326546]]
# Bias2  [-5.0711064]
# cost  0.0075534955
# Epoch  52000
# Hypothesis  [[0.0092075 ]
#  [0.99485874]
#  [0.9948784 ]
#  [0.00991305]]
# Theta1  [[3.7198005 2.744932 ]
#  [3.6992648 2.7415328]]
# Bias1  [-1.7619004 -4.0222087]
# Theta2  [[ 5.6596456]
#  [-5.7541337]]
# Bias2  [-5.093497]
# cost  0.007375474
# Epoch  53000
# Hypothesis  [[0.0090012 ]
#  [0.994978  ]
#  [0.99499714]
#  [0.00968349]]
# Theta1  [[3.725284  2.7525804]
#  [3.7049868 2.7492268]]
# Bias1  [-1.7649999 -4.033742 ]
# Theta2  [[ 5.680956 ]
#  [-5.7751255]]
# Bias2  [-5.1153846]
# cost  0.007205671
# Epoch  54000
# Hypothesis  [[0.00880361]
#  [0.99509263]
#  [0.99511117]
#  [0.00946517]]
# Theta1  [[3.730617  2.7600265]
#  [3.7105503 2.7567222]]
# Bias1  [-1.7680354 -4.045068 ]
# Theta2  [[ 5.701803]
#  [-5.795651]]
# Bias2  [-5.136803]
# cost  0.007043274
# Epoch  55000
# Hypothesis  [[0.00861413]
#  [0.9952016 ]
#  [0.99521965]
#  [0.00925561]]
# Theta1  [[3.7358623 2.7672937]
#  [3.716034  2.764035 ]]
# Bias1  [-1.7710156 -4.056035 ]
# Theta2  [[ 5.7222223]
#  [-5.8157334]]
# Bias2  [-5.1577673]
# cost  0.006887975
# Epoch  56000
# Hypothesis  [[0.00843278]
#  [0.99530596]
#  [0.9953235 ]
#  [0.00905509]]
# Theta1  [[3.7409432 2.77441  ]
#  [3.7213166 2.7711875]]
# Bias1  [-1.7738866 -4.066752 ]
# Theta2  [[ 5.742232 ]
#  [-5.8353972]]
# Bias2  [-5.1782713]
# cost  0.006739368
# Epoch  57000
# Hypothesis  [[0.00825933]
#  [0.99540675]
#  [0.9954234 ]
#  [0.00886386]]
# Theta1  [[3.74595   2.7813241]
#  [3.7265618 2.7781065]]
# Bias1  [-1.7767265 -4.0772424]
# Theta2  [[ 5.761782 ]
#  [-5.8546696]]
# Bias2  [-5.198329]
# cost  0.006597
# Epoch  58000
# Hypothesis  [[0.00809322]
#  [0.99550253]
#  [0.9955188 ]
#  [0.00867927]]
# Theta1  [[3.7508237 2.7880747]
#  [3.7316022 2.7849014]]
# Bias1  [-1.7794683 -4.0874343]
# Theta2  [[ 5.7809267]
#  [-5.873577 ]]
# Bias2  [-5.2179894]
# cost  0.0064605502
# Epoch  59000
# Hypothesis  [[0.00793352]
#  [0.9955949 ]
#  [0.9956108 ]
#  [0.00850189]]
# Theta1  [[3.755592  2.7946968]
#  [3.736609  2.791577 ]]
# Bias1  [-1.7821755 -4.097448 ]
# Theta2  [[ 5.7997212]
#  [-5.8921523]]
# Bias2  [-5.2372704]
# cost  0.0063292678
# Epoch  60000
# Hypothesis  [[0.00777882]
#  [0.9956833 ]
#  [0.9956987 ]
#  [0.00833271]]
# Theta1  [[3.7603087 2.801134 ]
#  [3.7414503 2.7980146]]
# Bias1  [-1.7847981 -4.107165 ]
# Theta2  [[ 5.818187]
#  [-5.910272]]
# Bias2  [-5.2562113]
# cost  0.006203374
# Epoch  61000
# Hypothesis  [[0.00762988]
#  [0.9957682 ]
#  [0.9957832 ]
#  [0.00816975]]
# Theta1  [[3.7648387 2.8074253]
#  [3.7462187 2.8043547]]
# Bias1  [-1.7873925 -4.1167016]
# Theta2  [[ 5.836307]
#  [-5.928071]]
# Bias2  [-5.274808]
# cost  0.006082237
# Epoch  62000
# Hypothesis  [[0.00748848]
#  [0.99585044]
#  [0.99586487]
#  [0.00801244]]
# Theta1  [[3.7693686 2.8136241]
#  [3.7509115 2.8105536]]
# Bias1  [-1.7898959 -4.1260467]
# Theta2  [[ 5.854007 ]
#  [-5.9456053]]
# Bias2  [-5.292955]
# cost  0.0059658275
# Epoch  63000
# Hypothesis  [[0.00735077]
#  [0.9959288 ]
#  [0.995943  ]
#  [0.00786158]]
# Theta1  [[3.7737482 2.8196244]
#  [3.7554414 2.816599 ]]
# Bias1  [-1.7923993 -4.1351066]
# Theta2  [[ 5.8714566]
#  [-5.9627714]]
# Bias2  [-5.310817]
# cost  0.00585381
# Epoch  64000
# Hypothesis  [[0.00721728]
#  [0.99600536]
#  [0.9960188 ]
#  [0.00771645]]
# Theta1  [[3.7780397 2.825585 ]
#  [3.7599714 2.8225594]]
# Bias1  [-1.7947891 -4.1441665]
# Theta2  [[ 5.8886228]
#  [-5.979606 ]]
# Bias2  [-5.3284435]
# cost  0.005745391
# Epoch  65000
# Hypothesis  [[0.00709092]
#  [0.9960781 ]
#  [0.9960914 ]
#  [0.00757503]]
# Theta1  [[3.7823312 2.831342 ]
#  [3.764338  2.8283596]]
# Bias1  [-1.7971733 -4.1527953]
# Theta2  [[ 5.905373 ]
#  [-5.9962573]]
# Bias2  [-5.3456097]
# cost  0.005641482
# Epoch  66000
# Hypothesis  [[0.00696662]
#  [0.99614847]
#  [0.99616134]
#  [0.00744012]]
# Theta1  [[3.7864397 2.837064 ]
#  [3.7686296 2.8340816]]
# Bias1  [-1.7994953 -4.1613784]
# Theta2  [[ 5.92196]
#  [-6.01247]]
# Bias2  [-5.362547]
# cost  0.0055409726
# Epoch  67000
# Hypothesis  [[0.00684759]
#  [0.9962171 ]
#  [0.9962297 ]
#  [0.00731   ]]
# Theta1  [[3.7904928 2.842567 ]
#  [3.772921  2.8396432]]
# Bias1  [-1.8017603 -4.1698613]
# Theta2  [[ 5.9381723]
#  [-6.028506 ]]
# Bias2  [-5.379236]
# cost  0.0054438785
# Epoch  68000
# Hypothesis  [[0.00673257]
#  [0.9962823 ]
#  [0.99629444]
#  [0.00718299]]
# Theta1  [[3.794546  2.8480506]
#  [3.7770286 2.8451269]]
# Bias1  [-1.8040253 -4.1779675]
# Theta2  [[ 5.954152 ]
#  [-6.0442414]]
# Bias2  [-5.3955455]
# cost  0.005350345
# Epoch  69000
# Hypothesis  [[0.00662039]
#  [0.9963457 ]
#  [0.99635786]
#  [0.00706128]]
# Theta1  [[3.7984624 2.8533516]
#  [3.7810817 2.85048  ]]
# Bias1  [-1.8062018 -4.186074 ]
# Theta2  [[ 5.9698877]
#  [-6.0597167]]
# Bias2  [-5.411737]
# cost  0.0052596387
# Epoch  70000
# Hypothesis  [[0.00651364]
#  [0.99640805]
#  [0.99641967]
#  [0.00694436]]
# Theta1  [[3.802277  2.8585968]
#  [3.7851348 2.8557253]]
# Bias1  [-1.8083476 -4.1940722]
# Theta2  [[ 5.98531  ]
#  [-6.0749755]]
# Bias2  [-5.4274726]
# cost  0.0051721805
# Epoch  71000
# Hypothesis  [[0.00640827]
#  [0.9964663 ]
#  [0.9964778 ]
#  [0.00682886]]
# Theta1  [[3.8060918 2.8637562]
#  [3.7890632 2.8609366]]
# Bias1  [-1.8104934 -4.2017016]
# Theta2  [[ 6.000569 ]
#  [-6.0899425]]
# Bias2  [-5.4431186]
# cost  0.0050873943
# Epoch  72000
# Hypothesis  [[0.00630812]
#  [0.9965243 ]
#  [0.99653566]
#  [0.00671933]]
# Theta1  [[3.8099065 2.868763 ]
#  [3.792878  2.8659434]]
# Bias1  [-1.812549 -4.209331]
# Theta2  [[ 6.0155053]
#  [-6.1047244]]
# Bias2  [-5.4583774]
# cost  0.0050055706
# Epoch  73000
# Hypothesis  [[0.00620941]
#  [0.9965804 ]
#  [0.9965913 ]
#  [0.00661262]]
# Theta1  [[3.8134847 2.8737698]
#  [3.7966926 2.8709502]]
# Bias1  [-1.8145756 -4.2169604]
# Theta2  [[ 6.0302873]
#  [-6.1192455]]
# Bias2  [-5.473557]
# cost  0.0049258205
# Epoch  74000
# Hypothesis  [[0.00611497]
#  [0.99663407]
#  [0.9966446 ]
#  [0.00650858]]
# Theta1  [[3.817061  2.8786385]
#  [3.8005073 2.8758657]]
# Bias1  [-1.8166021 -4.2242155]
# Theta2  [[ 6.0447817]
#  [-6.1335506]]
# Bias2  [-5.488339]
# cost  0.004849058
# Epoch  75000
# Hypothesis  [[0.00602239]
#  [0.9966858 ]
#  [0.99669623]
#  [0.00640707]]
# Theta1  [[3.8206372 2.8834069]
#  [3.8041139 2.880634 ]]
# Bias1  [-1.8185887 -4.231368 ]
# Theta2  [[ 6.059087]
#  [-6.147693]]
# Bias2  [-5.503087]
# cost  0.0047743083
# Epoch  76000
# Hypothesis  [[0.00593318]
#  [0.99673694]
#  [0.99674714]
#  [0.00631066]]
# Theta1  [[3.8242135 2.8881752]
#  [3.8076901 2.8854024]]
# Bias1  [-1.8204961 -4.2385206]
# Theta2  [[ 6.073224 ]
#  [-6.1615214]]
# Bias2  [-5.517392]
# cost  0.0047020083
# Epoch  77000
# Hypothesis  [[0.00584698]
#  [0.99678695]
#  [0.996797  ]
#  [0.00621595]]
# Theta1  [[3.8275683 2.8927424]
#  [3.8112664 2.8900344]]
# Bias1  [-1.8224034 -4.245673 ]
# Theta2  [[ 6.0870523]
#  [-6.1753497]]
# Bias2  [-5.5316973]
# cost  0.004631451
# Epoch  78000
# Hypothesis  [[0.00576139]
#  [0.99683446]
#  [0.99684393]
#  [0.00612549]]
# Theta1  [[3.8309062 2.8972723]
#  [3.8148427 2.8945644]]
# Bias1  [-1.8243108 -4.2523694]
# Theta2  [[ 6.1008806]
#  [-6.188705 ]]
# Bias2  [-5.5456357]
# cost  0.004563504
# Epoch  79000
# Hypothesis  [[0.00568039]
#  [0.99687994]
#  [0.9968892 ]
#  [0.00603409]]
# Theta1  [[3.834244  2.9018023]
#  [3.8182414 2.8990943]]
# Bias1  [-1.8261498 -4.259045 ]
# Theta2  [[ 6.1142397]
#  [-6.2020564]]
# Bias2  [-5.559464]
# cost  0.004497387
# Epoch  80000
# Hypothesis  [[0.00560057]
#  [0.9969253 ]
#  [0.9969348 ]
#  [0.00594828]]
# Theta1  [[3.8375819 2.906138 ]
#  [3.8215792 2.9034894]]
# Bias1  [-1.827938 -4.265721]
# Theta2  [[ 6.127591]
#  [-6.215191]]
# Bias2  [-5.5731053]
# cost  0.00443294
# Epoch  81000
# Hypothesis  [[0.00552309]
#  [0.99697   ]
#  [0.99697924]
#  [0.00586643]]
# Theta1  [[3.8408449 2.9104295]
#  [3.824917  2.907781 ]]
# Bias1  [-1.8297261 -4.2723966]
# Theta2  [[ 6.140734 ]
#  [-6.2280655]]
# Bias2  [-5.586457]
# cost  0.0043705036
# Epoch  82000
# Hypothesis  [[0.00544805]
#  [0.9970119 ]
#  [0.99702066]
#  [0.00578213]]
# Theta1  [[3.8439443 2.914721 ]
#  [3.828255  2.9120724]]
# Bias1  [-1.8315142 -4.2787333]
# Theta2  [[ 6.153609]
#  [-6.24094 ]]
# Bias2  [-5.599808]
# cost  0.0043095513
# Epoch  83000
# Hypothesis  [[0.00537424]
#  [0.9970528 ]
#  [0.99706155]
#  [0.00570254]]
# Theta1  [[3.8470438 2.918946 ]
#  [3.8315866 2.916364 ]]
# Bias1  [-1.8332666 -4.284932 ]
# Theta2  [[ 6.1664834]
#  [-6.2534647]]
# Bias2  [-5.612791]
# cost  0.00425049
# Epoch  84000
# Hypothesis  [[0.00530311]
#  [0.9970932 ]
#  [0.9971017 ]
#  [0.00562591]]
# Theta1  [[3.8501432 2.9229991]
#  [3.834686  2.920418 ]]
# Bias1  [-1.8349355 -4.291131 ]
# Theta2  [[ 6.179051 ]
#  [-6.2658625]]
# Bias2  [-5.6256657]
# cost  0.0041931253
# Epoch  85000
# Hypothesis  [[0.00523376]
#  [0.9971324 ]
#  [0.997141  ]
#  [0.00554939]]
# Theta1  [[3.8532426 2.9270523]
#  [3.8377855 2.9244711]]
# Bias1  [-1.8366045 -4.29733  ]
# Theta2  [[ 6.1914487]
#  [-6.27826  ]]
# Bias2  [-5.6385403]
# cost  0.004136781
# Epoch  86000
# Hypothesis  [[0.00516571]
#  [0.9971717 ]
#  [0.99718   ]
#  [0.0054783 ]]
# Theta1  [[3.856342  2.9311054]
#  [3.840885  2.9285243]]
# Bias1  [-1.8382734 -4.303529 ]
# Theta2  [[ 6.2038465]
#  [-6.2902756]]
# Bias2  [-5.6509533]
# cost  0.0040821936
# Epoch  87000
# Hypothesis  [[0.00509981]
#  [0.9972078 ]
#  [0.997216  ]
#  [0.00540529]]
# Theta1  [[3.85921   2.9351115]
#  [3.8439844 2.9325774]]
# Bias1  [-1.8399423 -4.309409 ]
# Theta2  [[ 6.2158947]
#  [-6.3021965]]
# Bias2  [-5.663351]
# cost  0.004029208
# Epoch  88000
# Hypothesis  [[0.0050355 ]
#  [0.99724364]
#  [0.99725145]
#  [0.00533404]]
# Theta1  [[3.862071  2.9389262]
#  [3.8470838 2.936394 ]]
# Bias1  [-1.8415599 -4.315131 ]
# Theta2  [[ 6.2278156]
#  [-6.3141174]]
# Bias2  [-5.675749]
# cost  0.003977258
# Epoch  89000
# Hypothesis  [[0.00497303]
#  [0.9972796 ]
#  [0.99728703]
#  [0.00526763]]
# Theta1  [[3.864932  2.942741 ]
#  [3.8500388 2.9402087]]
# Bias1  [-1.8431096 -4.320853 ]
# Theta2  [[ 6.2397366]
#  [-6.325737 ]]
# Bias2  [-5.687677]
# cost  0.0039269445
# Epoch  90000
# Hypothesis  [[0.00491152]
#  [0.9973138 ]
#  [0.9973213 ]
#  [0.00520177]]
# Theta1  [[3.867793  2.9465556]
#  [3.8528998 2.9440234]]
# Bias1  [-1.8446593 -4.3265753]
# Theta2  [[ 6.251436]
#  [-6.337181]]
# Bias2  [-5.699598]
# cost  0.0038777697
# Epoch  91000
# Hypothesis  [[0.00485194]
#  [0.997347  ]
#  [0.9973545 ]
#  [0.0051355 ]]
# Theta1  [[3.870654  2.950355 ]
#  [3.8557608 2.947838 ]]
# Bias1  [-1.846209  -4.3322973]
# Theta2  [[ 6.2628803]
#  [-6.348625 ]]
# Bias2  [-5.711519]
# cost  0.003829495
# Epoch  92000
# Hypothesis  [[0.00479427]
#  [0.99738115]
#  [0.99738866]
#  [0.0050743 ]]
# Theta1  [[3.8735151 2.9539313]
#  [3.8586218 2.951474 ]]
# Bias1  [-1.8477588 -4.3380194]
# Theta2  [[ 6.2743244]
#  [-6.3599753]]
# Bias2  [-5.723097]
# cost  0.003782527
# Epoch  93000
# Hypothesis  [[0.00473616]
#  [0.997413  ]
#  [0.9974203 ]
#  [0.00501442]]
# Theta1  [[3.8761983 2.9575076]
#  [3.8614829 2.9550502]]
# Bias1  [-1.8493085 -4.3433356]
# Theta2  [[ 6.285754 ]
#  [-6.3709426]]
# Bias2  [-5.734541]
# cost  0.0037369663
# Epoch  94000
# Hypothesis  [[0.00468104]
#  [0.9974432 ]
#  [0.9974502 ]
#  [0.00495259]]
# Theta1  [[3.878821  2.961084 ]
#  [3.864344  2.9586265]]
# Bias1  [-1.8507704 -4.348581 ]
# Theta2  [[ 6.2967215]
#  [-6.38191  ]]
# Bias2  [-5.745985]
# cost  0.0036925287
# Epoch  95000
# Hypothesis  [[0.00462709]
#  [0.9974733 ]
#  [0.99748   ]
#  [0.004892  ]]
# Theta1  [[3.8814435 2.9646602]
#  [3.8671422 2.9622028]]
# Bias1  [-1.8522009 -4.353826 ]
# Theta2  [[ 6.3076887]
#  [-6.392877 ]]
# Bias2  [-5.7573323]
# cost  0.0036487365
# Epoch  96000
# Hypothesis  [[0.00457451]
#  [0.99750334]
#  [0.9975101 ]
#  [0.00483524]]
# Theta1  [[3.884066  2.9681687]
#  [3.8697648 2.965779 ]]
# Bias1  [-1.8536314 -4.3590713]
# Theta2  [[ 6.318656]
#  [-6.403632]]
# Bias2  [-5.7682996]
# cost  0.0036062049
# Epoch  97000
# Hypothesis  [[0.00452172]
#  [0.99753284]
#  [0.99753976]
#  [0.00478172]]
# Theta1  [[3.8866887 2.9715066]
#  [3.8723874 2.9691367]]
# Bias1  [-1.8550619 -4.3643165]
# Theta2  [[ 6.329533 ]
#  [-6.4141226]]
# Bias2  [-5.779267]
# cost  0.0035646625
# Epoch  98000
# Hypothesis  [[0.00447117]
#  [0.99756134]
#  [0.9975681 ]
#  [0.00472707]]
# Theta1  [[3.8893113 2.9748445]
#  [3.87501   2.9724746]]
# Bias1  [-1.8564924 -4.3695617]
# Theta2  [[ 6.3400235]
#  [-6.424613 ]]
# Bias2  [-5.790234]
# cost  0.003524004
# Epoch  99000
# Hypothesis  [[0.0044217 ]
#  [0.9975896 ]
#  [0.9975963 ]
#  [0.00467343]]
# Theta1  [[3.891934  2.9781823]
#  [3.8776326 2.9758124]]
# Bias1  [-1.8579229 -4.374773 ]
# Theta2  [[ 6.350514 ]
#  [-6.4351034]]
# Bias2  [-5.8010836]
# cost  0.003483946
# Elapsed time  52.558863

# %% [markdown]
# ## Model 3
#
# *   Substitute Adam Optimizer for the Gradient Optimizer training algorithm
# *   Keep the thanh activation for layer 2

# %%
x_ = tf.placeholder(tf.float32, shape=[4,2], name = 'x-input')
y_ = tf.placeholder(tf.float32, shape=[4,1], name = 'y-input')

Theta1 = tf.Variable(tf.random_uniform([2,2], -1, 1), name = "Theta1")
Theta2 = tf.Variable(tf.random_uniform([2,1], -1, 1), name = "Theta2")

Bias1 = tf.Variable(tf.zeros([2]), name = "Bias1")
Bias2 = tf.Variable(tf.zeros([1]), name = "Bias2")

with tf.name_scope("layer2") as scope:
	A2 = tf.tanh(tf.matmul(x_, Theta1) + Bias1)

with tf.name_scope("layer3") as scope:
	Hypothesis = tf.sigmoid(tf.matmul(A2, Theta2) + Bias2)

with tf.name_scope("cost") as scope:
	cost = tf.reduce_mean(( (y_ * tf.log(Hypothesis)) + 
		((1 - y_) * tf.log(1.0 - Hypothesis)) ) * -1)

with tf.name_scope("train") as scope:
	train_step = tf.train.AdamOptimizer(0.01).minimize(cost)
  
XOR_X = [[0,0],[0,1],[1,0],[1,1]]
XOR_Y = [[0],[1],[1],[0]]

init = tf.global_variables_initializer()
sess = tf.Session()

#writer = tf.summary.FileWriter("./logs/xor_logs", sess.graph)

sess.run(init)

t_start = time.clock()
for i in range(100000):
	sess.run(train_step, feed_dict={x_: XOR_X, y_: XOR_Y})
	if i % 1000 == 0:
		print('Epoch ', i)
		print('Hypothesis ', sess.run(Hypothesis, feed_dict={x_: XOR_X, y_: XOR_Y}))
		print('Theta1 ', sess.run(Theta1))
		print('Bias1 ', sess.run(Bias1))
		print('Theta2 ', sess.run(Theta2))
		print('Bias2 ', sess.run(Bias2))
		print('cost ', sess.run(cost, feed_dict={x_: XOR_X, y_: XOR_Y}))
t_end = time.clock()
print('Elapsed time ', t_end - t_start)
# Out:
# Epoch  0
# Hypothesis  [[0.49516347]
#  [0.6471397 ]
#  [0.3932538 ]
#  [0.5562207 ]]
# Theta1  [[-0.9014865  -0.22460361]
#  [ 0.94062406  0.7037214 ]]
# Bias1  [-0.00999995 -0.00999985]
# Theta2  [[0.42385703]
#  [0.5108524 ]]
# Bias2  [-0.00999989]
# cost  0.7161104
# Epoch  1000
# Hypothesis  [[0.00289546]
#  [0.99711835]
#  [0.49889576]
#  [0.50116134]]
# Theta1  [[-4.739171   4.366158 ]
#  [ 2.646672   2.8392463]]
# Bias1  [-1.683154 -0.76683 ]
# Theta2  [[3.4141288]
#  [3.6901593]]
# Bias2  [-0.2749523]
# cost  0.34915403
# Epoch  2000
# Hypothesis  [[7.5966050e-04]
#  [9.9919826e-01]
#  [4.9970758e-01]
#  [5.0034696e-01]]
# Theta1  [[-5.556321   5.180324 ]
#  [ 2.8504236  3.1153576]]
# Bias1  [-1.7813692 -0.8594941]
# Theta2  [[4.0368967]
#  [4.366113 ]]
# Bias2  [-0.3288474]
# cost  0.3472839
# Epoch  3000
# Hypothesis  [[3.1823188e-04]
#  [9.9965549e-01]
#  [4.9987724e-01]
#  [5.0015336e-01]]
# Theta1  [[-6.0854707  5.7021127]
#  [ 2.972627   3.2692668]]
# Bias1  [-1.8416506  -0.91292655]
# Theta2  [[4.448776 ]
#  [4.8015203]]
# Bias2  [-0.3525721]
# cost  0.3468774
# Epoch  4000
# Hypothesis  [[1.5802584e-04]
#  [9.9982613e-01]
#  [4.9993861e-01]
#  [5.0007838e-01]]
# Theta1  [[-6.5082765  6.117906 ]
#  [ 3.0657008  3.3817348]]
# Bias1  [-1.8884718  -0.95275724]
# Theta2  [[4.7829113]
#  [5.150271 ]]
# Bias2  [-0.36726972]
# cost  0.34672645
# Epoch  5000
# Hypothesis  [[8.5137355e-05]
#  [9.9990523e-01]
#  [4.9996734e-01]
#  [5.0004351e-01]]
# Theta1  [[-6.879341   6.4826307]
#  [ 3.1443622  3.4744895]]
# Bias1  [-1.9286959 -0.9858479]
# Theta2  [[5.0798507]
#  [5.4576507]]
# Bias2  [-0.3777478]
# cost  0.34665665
# Epoch  6000
# Hypothesis  [[4.7927868e-05]
#  [9.9994612e-01]
#  [4.9998116e-01]
#  [5.0002456e-01]]
# Theta1  [[-7.2221417  6.8194065]
#  [ 3.2148104  3.5561101]]
# Bias1  [-1.9653527 -1.0149922]
# Theta2  [[5.3568287]
#  [5.7426987]]
# Bias2  [-0.38584134]
# cost  0.34662074
# Epoch  7000
# Hypothesis  [[2.7673817e-05]
#  [9.9996865e-01]
#  [4.9998897e-01]
#  [5.0001425e-01]]
# Theta1  [[-7.547891   7.139552 ]
#  [ 3.279746   3.6298785]]
# Bias1  [-1.9995844 -1.0415764]
# Theta2  [[5.622505 ]
#  [6.0148296]]
# Bias2  [-0.39230755]
# cost  0.34660098
# Epoch  8000
# Hypothesis  [[1.6216305e-05]
#  [9.9998152e-01]
#  [4.9999553e-01]
#  [5.0001049e-01]]
# Theta1  [[-7.863069   7.4492345]
#  [ 3.3406417  3.698106 ]]
# Bias1  [-2.0321472 -1.0665148]
# Theta2  [[5.88162  ]
#  [6.2792006]]
# Bias2  [-0.39756256]
# cost  0.34658974
# Epoch  9000
# Hypothesis  [[9.6386411e-06]
#  [9.9998891e-01]
#  [4.9995482e-01]
#  [4.9996364e-01]]
# Theta1  [[-8.170819   7.7523513]
#  [ 3.3990347  3.7621694]]
# Bias1  [-2.0631533 -1.0908602]
# Theta2  [[6.134322 ]
#  [6.5348945]]
# Bias2  [-0.40073213]
# cost  0.3465832
# Epoch  10000
# Hypothesis  [[5.8974306e-06]
#  [9.9999321e-01]
#  [4.9998260e-01]
#  [4.9998784e-01]]
# Theta1  [[-8.473751   8.051547 ]
#  [ 3.4575143  3.8238144]]
# Bias1  [-2.0921247 -1.1194044]
# Theta2  [[6.3695283]
#  [6.767921 ]]
# Bias2  [-0.3984499]
# cost  0.34657937
# Epoch  11000
# Hypothesis  [[3.7792654e-06]
#  [9.9999559e-01]
#  [4.9999553e-01]
#  [4.9999869e-01]]
# Theta1  [[-8.774519   8.350302 ]
#  [ 3.5243165  3.8867042]]
# Bias1  [-2.115849  -1.1653103]
# Theta2  [[6.5622983]
#  [6.95313  ]]
# Bias2  [-0.39084184]
# cost  0.34657723
# Epoch  12000
# Hypothesis  [[2.6080406e-06]
#  [9.9999690e-01]
#  [5.0001520e-01]
#  [5.0001711e-01]]
# Theta1  [[-9.07626   8.654693]
#  [ 3.606186  3.956346]]
# Bias1  [-2.133891  -1.2196401]
# Theta2  [[6.7079535]
#  [7.0899863]]
# Bias2  [-0.38196775]
# cost  0.34657598
# Epoch  13000
# Hypothesis  [[1.8271744e-06]
#  [9.9999774e-01]
#  [4.9999619e-01]
#  [4.9999726e-01]]
# Theta1  [[-9.388233   8.962997 ]
#  [ 3.7021031  4.039266 ]]
# Bias1  [-2.1516385 -1.3040884]
# Theta2  [[6.8169994]
#  [7.1907096]]
# Bias2  [-0.373723]
# cost  0.34657514
# Epoch  14000
# Hypothesis  [[1.3544774e-06]
#  [9.9999821e-01]
#  [5.0002187e-01]
#  [5.0002265e-01]]
# Theta1  [[-9.698676   9.279952 ]
#  [ 3.8243618  4.1414886]]
# Bias1  [-2.1656215 -1.394533 ]
# Theta2  [[6.899955]
#  [7.266517]]
# Bias2  [-0.36647314]
# cost  0.34657478
# Epoch  15000
# Hypothesis  [[1.0300963e-06]
#  [9.9999857e-01]
#  [4.9987200e-01]
#  [4.9987248e-01]]
# Theta1  [[-10.047541    9.592707 ]
#  [  3.9465544   4.2729826]]
# Bias1  [-2.1985588 -1.4990417]
# Theta2  [[6.9660473]
#  [7.325452 ]]
# Bias2  [-0.35991594]
# cost  0.34657446
# Epoch  16000
# Hypothesis  [[8.4422487e-07]
#  [9.9999881e-01]
#  [5.0000346e-01]
#  [5.0000346e-01]]
# Theta1  [[-10.413847   9.951134]
#  [  4.106096   4.430728]]
# Bias1  [-2.2338707 -1.5770056]
# Theta2  [[7.020066]
#  [7.373899]]
# Bias2  [-0.35381848]
# cost  0.3465741
# Epoch  17000
# Hypothesis  [[6.5058094e-07]
#  [9.9999905e-01]
#  [5.0014460e-01]
#  [5.0014490e-01]]
# Theta1  [[-10.75332    10.311359 ]
#  [  4.314437    4.6227856]]
# Bias1  [-2.2685997 -1.7532431]
# Theta2  [[7.0646467]
#  [7.413753 ]]
# Bias2  [-0.34852716]
# cost  0.3465742
# Epoch  18000
# Hypothesis  [[5.3859554e-07]
#  [9.9999917e-01]
#  [5.0029188e-01]
#  [5.0029200e-01]]
# Theta1  [[-11.061791   10.657578 ]
#  [  4.543229    4.8598433]]
# Bias1  [-2.3310146 -1.9003253]
# Theta2  [[7.1023116]
#  [7.447051 ]]
# Bias2  [-0.34357142]
# cost  0.34657407
# Epoch  19000
# Hypothesis  [[4.3955367e-07]
#  [9.9999928e-01]
#  [5.0006557e-01]
#  [5.0006533e-01]]
# Theta1  [[-11.350231   10.953866 ]
#  [  4.8155923   5.148699 ]]
# Bias1  [-2.4010916 -2.1598103]
# Theta2  [[7.135662]
#  [7.475154]]
# Bias2  [-0.33922958]
# cost  0.34657377
# Epoch  20000
# Hypothesis  [[3.9814952e-07]
#  [9.9999928e-01]
#  [4.9997616e-01]
#  [4.9997640e-01]]
# Theta1  [[-11.591939   11.216152 ]
#  [  5.129752    5.5001864]]
# Bias1  [-2.4877086 -2.246625 ]
# Theta2  [[7.165952 ]
#  [7.5002747]]
# Bias2  [-0.3344172]
# cost  0.346574
# Epoch  21000
# Hypothesis  [[3.5307852e-07]
#  [9.9999940e-01]
#  [5.0001574e-01]
#  [5.0001574e-01]]
# Theta1  [[-11.80042    11.443025 ]
#  [  5.424185    5.8476305]]
# Bias1  [-2.6281774 -2.441456 ]
# Theta2  [[7.191618 ]
#  [7.5221744]]
# Bias2  [-0.3304935]
# cost  0.34657383
# Epoch  22000
# Hypothesis  [[3.2089261e-07]
#  [9.9999940e-01]
#  [4.9998677e-01]
#  [4.9998677e-01]]
# Theta1  [[-11.997129   11.6355   ]
#  [  5.7417145   6.231183 ]]
# Bias1  [-2.7732399 -2.6327794]
# Theta2  [[7.216627]
#  [7.542866]]
# Bias2  [-0.32629213]
# cost  0.34657383
# Epoch  23000
# Hypothesis  [[2.976167e-07]
#  [9.999995e-01]
#  [5.000114e-01]
#  [5.000114e-01]]
# Theta1  [[-12.187262  11.834519]
#  [  6.076612   6.594593]]
# Bias1  [-2.9090972 -2.8159018]
# Theta2  [[7.2403126]
#  [7.5622053]]
# Bias2  [-0.3218471]
# cost  0.34657377
# Epoch  24000
# Hypothesis  [[2.7839411e-07]
#  [9.9999952e-01]
#  [5.0001520e-01]
#  [5.0001496e-01]]
# Theta1  [[-12.347106   11.969606 ]
#  [  6.3644977   6.9309626]]
# Bias1  [-3.0724661 -3.0462244]
# Theta2  [[7.26088  ]
#  [7.5797706]]
# Bias2  [-0.31883064]
# cost  0.34657365
# Epoch  25000
# Hypothesis  [[2.6724967e-07]
#  [9.9999952e-01]
#  [5.0006628e-01]
#  [5.0006628e-01]]
# Theta1  [[-12.523395  12.258528]
#  [  6.651625   7.272325]]
# Bias1  [-3.2130344 -3.0462956]
# Theta2  [[7.2807274]
#  [7.5965667]]
# Bias2  [-0.31557423]
# cost  0.34657377
# Epoch  26000
# Hypothesis  [[2.5397702e-07]
#  [9.9999952e-01]
#  [4.9976140e-01]
#  [4.9976140e-01]]
# Theta1  [[-12.66635   12.355614]
#  [  6.938531   7.597087]]
# Bias1  [-3.3211224 -3.303334 ]
# Theta2  [[7.3009753]
#  [7.612315 ]]
# Bias2  [-0.3122943]
# cost  0.34657383
# Epoch  27000
# Hypothesis  [[2.4401052e-07]
#  [9.9999952e-01]
#  [5.0000161e-01]
#  [5.0000161e-01]]
# Theta1  [[-12.787963   12.497724 ]
#  [  7.2041445   7.9114404]]
# Bias1  [-3.4240549 -3.4559119]
# Theta2  [[7.320315]
#  [7.628382]]
# Bias2  [-0.308061]
# cost  0.34657377
# Epoch  28000
# Hypothesis  [[2.3476741e-07]
#  [9.9999952e-01]
#  [4.9997395e-01]
#  [4.9997395e-01]]
# Theta1  [[-12.935184   12.646678 ]
#  [  7.4490542   8.186711 ]]
# Bias1  [-3.5586517 -3.5857773]
# Theta2  [[7.3400445]
#  [7.6440988]]
# Bias2  [-0.30415845]
# cost  0.34657377
# Epoch  29000
# Hypothesis  [[2.2700337e-07]
#  [9.9999964e-01]
#  [5.0068283e-01]
#  [5.0068283e-01]]
# Theta1  [[-13.038665   12.770923 ]
#  [  7.6551657   8.404721 ]]
# Bias1  [-3.6785011 -3.7187681]
# Theta2  [[7.356601 ]
#  [7.6597137]]
# Bias2  [-0.30038115]
# cost  0.34657422
# Epoch  30000
# Hypothesis  [[2.1991202e-07]
#  [9.9999964e-01]
#  [5.0003111e-01]
#  [5.0003111e-01]]
# Theta1  [[-13.117217   12.890012 ]
#  [  7.8804827   8.586417 ]]
# Bias1  [-3.7902277 -3.8510797]
# Theta2  [[7.3730106]
#  [7.6723075]]
# Bias2  [-0.2991724]
# cost  0.34657374
# Epoch  31000
# Hypothesis  [[2.1368905e-07]
#  [9.9999964e-01]
#  [4.9998760e-01]
#  [4.9998760e-01]]
# Theta1  [[-13.214536   13.061516 ]
#  [  8.1075115   8.741686 ]]
# Bias1  [-3.8949852 -3.9074066]
# Theta2  [[7.3885193]
#  [7.685505 ]]
# Bias2  [-0.2970352]
# cost  0.34657374
# Epoch  32000
# Hypothesis  [[2.0765169e-07]
#  [9.9999964e-01]
#  [4.9983817e-01]
#  [4.9983817e-01]]
# Theta1  [[-13.330198   13.1123905]
#  [  8.311479    8.906631 ]]
# Bias1  [-3.998614 -4.021243]
# Theta2  [[7.4040265]
#  [7.6983423]]
# Bias2  [-0.29496315]
# cost  0.34657377
# Epoch  33000
# Hypothesis  [[2.0217729e-07]
#  [9.9999964e-01]
#  [5.0006175e-01]
#  [5.0006175e-01]]
# Theta1  [[-13.586816  13.112401]
#  [  8.345272   9.048859]]
# Bias1  [-4.2011437 -4.111326 ]
# Theta2  [[7.418714]
#  [7.710918]]
# Bias2  [-0.2919568]
# cost  0.3465737
# Epoch  34000
# Hypothesis  [[1.9714309e-07]
#  [9.9999964e-01]
#  [4.9923235e-01]
#  [4.9923235e-01]]
# Theta1  [[-13.586816  13.241487]
#  [  8.57057    9.169476]]
# Bias1  [-4.1420527 -4.0959406]
# Theta2  [[7.4348783]
#  [7.7221475]]
# Bias2  [-0.2903398]
# cost  0.3465743
# Epoch  35000
# Hypothesis  [[1.9233438e-07]
#  [9.9999964e-01]
#  [5.0014323e-01]
#  [5.0014323e-01]]
# Theta1  [[-13.670975   13.241487 ]
#  [  8.6706085   9.2776785]]
# Bias1  [-4.24981   -4.2203774]
# Theta2  [[7.4485574]
#  [7.735487 ]]
# Bias2  [-0.28635684]
# cost  0.34657377
# Epoch  36000
# Hypothesis  [[1.8777273e-07]
#  [9.9999964e-01]
#  [4.9999821e-01]
#  [4.9999821e-01]]
# Theta1  [[-13.694917  13.304423]
#  [  8.798293   9.379516]]
# Bias1  [-4.245728 -4.279413]
# Theta2  [[7.4634213]
#  [7.7470303]]
# Bias2  [-0.28361607]
# cost  0.3465737
# Epoch  37000
# Hypothesis  [[1.8334848e-07]
#  [9.9999964e-01]
#  [4.9983448e-01]
#  [4.9983448e-01]]
# Theta1  [[-13.694917  13.39469 ]
#  [  8.942349   9.468692]]
# Bias1  [-4.258755 -4.266556]
# Theta2  [[7.4784102]
#  [7.7586293]]
# Bias2  [-0.28088105]
# cost  0.34657377
# Epoch  38000
# Hypothesis  [[1.7891975e-07]
#  [9.9999964e-01]
#  [4.9981159e-01]
#  [4.9981159e-01]]
# Theta1  [[-13.811394  13.39469 ]
#  [  8.990977   9.551201]]
# Bias1  [-4.343237 -4.340613]
# Theta2  [[7.4931593]
#  [7.7703714]]
# Bias2  [-0.27796564]
# cost  0.34657377
# Epoch  39000
# Hypothesis  [[1.7479591e-07]
#  [9.9999964e-01]
#  [5.0004947e-01]
#  [5.0004947e-01]]
# Theta1  [[-13.811394  13.458726]
#  [  9.136985   9.630364]]
# Bias1  [-4.350524 -4.354853]
# Theta2  [[7.5075536]
#  [7.782455 ]]
# Bias2  [-0.27470362]
# cost  0.3465737
# Epoch  40000
# Hypothesis  [[1.7094912e-07]
#  [9.9999976e-01]
#  [4.9999714e-01]
#  [4.9999714e-01]]
# Theta1  [[-13.88736   13.458726]
#  [  9.183362   9.690325]]
# Bias1  [-4.442671 -4.44679 ]
# Theta2  [[7.520125]
#  [7.793054]]
# Bias2  [-0.27294052]
# cost  0.3465737
# Epoch  41000
# Hypothesis  [[1.6765163e-07]
#  [9.9999976e-01]
#  [5.0000513e-01]
#  [5.0000513e-01]]
# Theta1  [[-13.88736   13.596244]
#  [  9.285266   9.732901]]
# Bias1  [-4.476858  -4.3903666]
# Theta2  [[7.5309067]
#  [7.8028717]]
# Bias2  [-0.27194446]
# cost  0.3465737
# Epoch  42000
# Hypothesis  [[1.6430533e-07]
#  [9.9999976e-01]
#  [4.9999881e-01]
#  [4.9999881e-01]]
# Theta1  [[-13.88736   13.596244]
#  [  9.382889   9.77686 ]]
# Bias1  [-4.5142922 -4.470139 ]
# Theta2  [[7.541726 ]
#  [7.8126945]]
# Bias2  [-0.27097324]
# cost  0.3465737
# Epoch  43000
# Hypothesis  [[1.6108145e-07]
#  [9.9999976e-01]
#  [4.9979052e-01]
#  [4.9979052e-01]]
# Theta1  [[-14.018478  13.596244]
#  [  9.348254   9.823724]]
# Bias1  [-4.6399064 -4.5439873]
# Theta2  [[7.5526233]
#  [7.8218474]]
# Bias2  [-0.27006197]
# cost  0.34657374
# Epoch  44000
# Hypothesis  [[1.5823936e-07]
#  [9.9999976e-01]
#  [5.0005317e-01]
#  [5.0005317e-01]]
# Theta1  [[-14.018478  13.769495]
#  [  9.441927   9.870337]]
# Bias1  [-4.6276603 -4.4324527]
# Theta2  [[7.5627985]
#  [7.8315144]]
# Bias2  [-0.26850325]
# cost  0.3465737
# Epoch  45000
# Hypothesis  [[1.5526253e-07]
#  [9.9999976e-01]
#  [4.9998224e-01]
#  [4.9998224e-01]]
# Theta1  [[-14.018478  13.769495]
#  [  9.529462   9.906088]]
# Bias1  [-4.6310816 -4.4858384]
# Theta2  [[7.57344 ]
#  [7.840753]]
# Bias2  [-0.26738408]
# cost  0.3465737
# Epoch  46000
# Hypothesis  [[1.5236886e-07]
#  [9.9999976e-01]
#  [5.0000250e-01]
#  [5.0000250e-01]]
# Theta1  [[-14.018478  13.769495]
#  [  9.611093   9.943313]]
# Bias1  [-4.6446114 -4.543541 ]
# Theta2  [[7.5838995]
#  [7.850075 ]]
# Bias2  [-0.26616517]
# cost  0.3465737
# Epoch  47000
# Hypothesis  [[1.4949092e-07]
#  [9.9999976e-01]
#  [4.9999702e-01]
#  [4.9999702e-01]]
# Theta1  [[-14.101463  13.769495]
#  [  9.604333   9.982041]]
# Bias1  [-4.7441244 -4.6011276]
# Theta2  [[7.5944285]
#  [7.8593764]]
# Bias2  [-0.26495975]
# cost  0.3465737
# Epoch  48000
# Hypothesis  [[1.4694353e-07]
#  [9.9999976e-01]
#  [4.9999833e-01]
#  [4.9999833e-01]]
# Theta1  [[-14.101468  13.769495]
#  [  9.682347  10.022191]]
# Bias1  [-4.7338676 -4.655048 ]
# Theta2  [[7.6045895]
#  [7.867905 ]]
# Bias2  [-0.26332223]
# cost  0.34657368
# Epoch  49000
# Hypothesis  [[1.4448312e-07]
#  [9.9999976e-01]
#  [4.9996412e-01]
#  [4.9996412e-01]]
# Theta1  [[-14.101468  13.769495]
#  [  9.755105  10.063199]]
# Bias1  [-4.7346573 -4.7034235]
# Theta2  [[7.6147256]
#  [7.8762145]]
# Bias2  [-0.2616324]
# cost  0.34657368
# Epoch  50000
# Hypothesis  [[1.4208057e-07]
#  [9.9999976e-01]
#  [4.9999976e-01]
#  [4.9999976e-01]]
# Theta1  [[-14.101468  13.769495]
#  [  9.822798  10.104315]]
# Bias1  [-4.742935 -4.745773]
# Theta2  [[7.6247554]
#  [7.884609 ]]
# Bias2  [-0.25985485]
# cost  0.34657368
# Epoch  51000
# Hypothesis  [[1.3964403e-07]
#  [9.9999976e-01]
#  [4.9968264e-01]
#  [4.9968264e-01]]
# Theta1  [[-14.23376   13.855009]
#  [  9.755695  10.143316]]
# Bias1  [-4.8642855 -4.699651 ]
# Theta2  [[7.6352906]
#  [7.892558 ]]
# Bias2  [-0.25853705]
# cost  0.34657377
# Epoch  52000
# Hypothesis  [[1.3738992e-07]
#  [9.9999976e-01]
#  [5.0003201e-01]
#  [5.0003201e-01]]
# Theta1  [[-14.23376   13.855009]
#  [  9.821928  10.178602]]
# Bias1  [-4.8434525 -4.7409577]
# Theta2  [[7.644885]
#  [7.901363]]
# Bias2  [-0.25634974]
# cost  0.34657368
# Epoch  53000
# Hypothesis  [[1.3518070e-07]
#  [9.9999976e-01]
#  [5.0048792e-01]
#  [5.0048792e-01]]
# Theta1  [[-14.23376   13.855009]
#  [  9.88568   10.213888]]
# Bias1  [-4.8318715 -4.7786193]
# Theta2  [[7.65439 ]
#  [7.910348]]
# Bias2  [-0.2540064]
# cost  0.34657392
# Epoch  54000
# Hypothesis  [[1.3293207e-07]
#  [9.9999976e-01]
#  [5.0005335e-01]
#  [5.0005335e-01]]
# Theta1  [[-14.23376   13.855009]
#  [  9.946081  10.249176]]
# Bias1  [-4.8281956 -4.812236 ]
# Theta2  [[7.66489  ]
#  [7.9178348]]
# Bias2  [-0.25273147]
# cost  0.34657368
# Epoch  55000
# Hypothesis  [[1.3084232e-07]
#  [9.9999976e-01]
#  [4.9999845e-01]
#  [4.9999845e-01]]
# Theta1  [[-14.23376   13.855009]
#  [ 10.002798  10.284462]]
# Bias1  [-4.830555  -4.8420024]
# Theta2  [[7.6747804]
#  [7.9256153]]
# Bias2  [-0.25084102]
# cost  0.34657368
# Epoch  56000
# Hypothesis  [[1.2881614e-07]
#  [9.9999976e-01]
#  [4.9999797e-01]
#  [4.9999797e-01]]
# Theta1  [[-14.23376   13.935563]
#  [ 10.055918  10.317246]]
# Bias1  [-4.837137 -4.779741]
# Theta2  [[7.684612 ]
#  [7.9334784]]
# Bias2  [-0.24887481]
# cost  0.34657368
# Epoch  57000
# Hypothesis  [[1.2680246e-07]
#  [9.9999976e-01]
#  [5.0011533e-01]
#  [5.0011533e-01]]
# Theta1  [[-14.317838   13.935563 ]
#  [ 10.024062   10.3459635]]
# Bias1  [-4.915928  -4.7928123]
# Theta2  [[7.694294]
#  [7.941508]]
# Bias2  [-0.24675241]
# cost  0.34657368
# Epoch  58000
# Hypothesis  [[1.2480241e-07]
#  [9.9999976e-01]
#  [5.0000405e-01]
#  [5.0000405e-01]]
# Theta1  [[-14.317838   13.935563 ]
#  [ 10.0763445  10.373895 ]]
# Bias1  [-4.907153  -4.8097067]
# Theta2  [[7.7042694]
#  [7.9492235]]
# Bias2  [-0.24493788]
# cost  0.34657368
# Epoch  59000
# Hypothesis  [[1.2284772e-07]
#  [9.9999976e-01]
#  [4.9999559e-01]
#  [4.9999559e-01]]
# Theta1  [[-14.317838  13.935563]
#  [ 10.126395  10.401551]]
# Bias1  [-4.903636  -4.8298526]
# Theta2  [[7.7141223]
#  [7.957084 ]]
# Bias2  [-0.24297947]
# cost  0.34657368
# Epoch  60000
# Hypothesis  [[1.2091766e-07]
#  [9.9999976e-01]
#  [4.9996793e-01]
#  [4.9996793e-01]]
# Theta1  [[-14.317838  13.935563]
#  [ 10.173814  10.428849]]
# Bias1  [-4.9043255 -4.852133 ]
# Theta2  [[7.7240047]
#  [7.9649243]]
# Bias2  [-0.24104802]
# cost  0.34657368
# Epoch  61000
# Hypothesis  [[1.19027455e-07]
#  [9.99999762e-01]
#  [4.99997020e-01]
#  [4.99997020e-01]]
# Theta1  [[-14.317838  13.935563]
#  [ 10.218572  10.455552]]
# Bias1  [-4.9081206 -4.875021 ]
# Theta2  [[7.7338076]
#  [7.9728365]]
# Bias2  [-0.23904072]
# cost  0.34657368
# Epoch  62000
# Hypothesis  [[1.1715126e-07]
#  [9.9999976e-01]
#  [4.9999428e-01]
#  [4.9999428e-01]]
# Theta1  [[-14.45137   13.935563]
#  [ 10.1293    10.482255]]
# Bias1  [-5.0264344 -4.8976727]
# Theta2  [[7.7436013]
#  [7.980666 ]]
# Bias2  [-0.23708782]
# cost  0.34657368
# Epoch  63000
# Hypothesis  [[1.15335226e-07]
#  [9.99999762e-01]
#  [5.00113070e-01]
#  [5.00113070e-01]]
# Theta1  [[-14.45137   13.935563]
#  [ 10.175758  10.508958]]
# Bias1  [-5.008701 -4.91918 ]
# Theta2  [[7.7532954]
#  [7.98871  ]]
# Bias2  [-0.2349621]
# cost  0.34657368
# Epoch  64000
# Hypothesis  [[1.1354440e-07]
#  [9.9999976e-01]
#  [5.0000376e-01]
#  [5.0000376e-01]]
# Theta1  [[-14.45137   14.071541]
#  [ 10.221753  10.53448 ]]
# Bias1  [-4.995332  -4.8039045]
# Theta2  [[7.763277]
#  [7.996436]]
# Bias2  [-0.23314407]
# cost  0.34657368
# Epoch  65000
# Hypothesis  [[1.11960105e-07]
#  [9.99999881e-01]
#  [5.00002444e-01]
#  [5.00002444e-01]]
# Theta1  [[-14.45137   14.071541]
#  [ 10.256736  10.55037 ]]
# Bias1  [-4.99554   -4.8321323]
# Theta2  [[7.77139]
#  [8.00343]]
# Bias2  [-0.23203069]
# cost  0.34657365
# Epoch  66000
# Hypothesis  [[1.1063441e-07]
#  [9.9999988e-01]
#  [4.9999809e-01]
#  [4.9999809e-01]]
# Theta1  [[-14.45137   14.071541]
#  [ 10.279624  10.560861]]
# Bias1  [-5.0088196 -4.865432 ]
# Theta2  [[7.7773128]
#  [8.0093355]]
# Bias2  [-0.23203056]
# cost  0.34657365
# Epoch  67000
# Hypothesis  [[1.0931817e-07]
#  [9.9999988e-01]
#  [4.9995673e-01]
#  [4.9995673e-01]]
# Theta1  [[-14.45137   14.071541]
#  [ 10.302512  10.571897]]
# Bias1  [-5.0215707 -4.8984976]
# Theta2  [[7.783282]
#  [8.015199]]
# Bias2  [-0.23209003]
# cost  0.34657365
# Epoch  68000
# Hypothesis  [[1.0794858e-07]
#  [9.9999988e-01]
#  [4.9941799e-01]
#  [4.9941799e-01]]
# Theta1  [[-14.45137   14.071541]
#  [ 10.3254    10.583341]]
# Bias1  [-5.0337515 -4.9301395]
# Theta2  [[7.7899127]
#  [8.02039  ]]
# Bias2  [-0.23280482]
# cost  0.346574
# Epoch  69000
# Hypothesis  [[1.0674000e-07]
#  [9.9999988e-01]
#  [4.9989405e-01]
#  [4.9989405e-01]]
# Theta1  [[-14.45137   14.071541]
#  [ 10.348289  10.595341]]
# Bias1  [-5.045381  -4.9596925]
# Theta2  [[7.7951922]
#  [8.026941 ]]
# Bias2  [-0.2321729]
# cost  0.34657365
# Epoch  70000
# Hypothesis  [[1.0549624e-07]
#  [9.9999988e-01]
#  [4.9998856e-01]
#  [4.9998856e-01]]
# Theta1  [[-14.45137    14.071541 ]
#  [ 10.370889   10.6077385]]
# Bias1  [-5.0564427 -4.986918 ]
# Theta2  [[7.8009663]
#  [8.032964 ]]
# Bias2  [-0.2320432]
# cost  0.34657365
# Epoch  71000
# Hypothesis  [[1.0425186e-07]
#  [9.9999988e-01]
#  [5.0000525e-01]
#  [5.0000525e-01]]
# Theta1  [[-14.45137   14.071541]
#  [ 10.392823  10.620141]]
# Bias1  [-5.0669675 -5.0118327]
# Theta2  [[7.8068686]
#  [8.038905 ]]
# Bias2  [-0.2320156]
# cost  0.34657365
# Epoch  72000
# Hypothesis  [[1.0315409e-07]
#  [9.9999988e-01]
#  [5.0022614e-01]
#  [5.0022614e-01]]
# Theta1  [[-14.45137   14.071541]
#  [ 10.41469   10.633447]]
# Bias1  [-5.0769887 -5.0345964]
# Theta2  [[7.8122277]
#  [8.044618 ]]
# Bias2  [-0.23148546]
# cost  0.3465737
# Epoch  73000
# Hypothesis  [[1.02014354e-07]
#  [9.99999881e-01]
#  [5.00024855e-01]
#  [5.00024855e-01]]
# Theta1  [[-14.45137   14.071541]
#  [ 10.435671  10.646798]]
# Bias1  [-5.0865593 -5.0553846]
# Theta2  [[7.8181396]
#  [8.049751 ]]
# Bias2  [-0.23151243]
# cost  0.34657365
# Epoch  74000
# Hypothesis  [[1.00907044e-07]
#  [9.99999881e-01]
#  [4.99926329e-01]
#  [4.99926329e-01]]
# Theta1  [[-14.45137   14.158643]
#  [ 10.456652  10.659888]]
# Bias1  [-5.095724  -4.9873714]
# Theta2  [[7.823944]
#  [8.055055]]
# Bias2  [-0.23140524]
# cost  0.34657365
# Epoch  75000
# Hypothesis  [[9.9838026e-08]
#  [9.9999988e-01]
#  [5.0000894e-01]
#  [5.0000894e-01]]
# Theta1  [[-14.45137   14.158643]
#  [ 10.476697  10.671332]]
# Bias1  [-5.104548 -5.007313]
# Theta2  [[7.829425]
#  [8.060526]]
# Bias2  [-0.23106521]
# cost  0.34657365
# Epoch  76000
# Hypothesis  [[9.8728719e-08]
#  [9.9999988e-01]
#  [4.9979064e-01]
#  [4.9979064e-01]]
# Theta1  [[-14.45137   14.158643]
#  [ 10.496724  10.682776]]
# Bias1  [-5.1131024 -5.02734  ]
# Theta2  [[7.8353806]
#  [8.065657 ]]
# Bias2  [-0.23111357]
# cost  0.3465737
# Epoch  77000
# Hypothesis  [[9.769358e-08]
#  [9.999999e-01]
#  [5.000043e-01]
#  [5.000043e-01]]
# Theta1  [[-14.45137   14.158643]
#  [ 10.516002  10.694344]]
# Bias1  [-5.1212087 -5.0469027]
# Theta2  [[7.840721]
#  [8.071337]]
# Bias2  [-0.23059839]
# cost  0.34657365
# Epoch  78000
# Hypothesis  [[9.6637592e-08]
#  [9.9999988e-01]
#  [4.9998546e-01]
#  [4.9998546e-01]]
# Theta1  [[-14.45137   14.158643]
#  [ 10.535075  10.706741]]
# Bias1  [-5.129074 -5.065537]
# Theta2  [[7.846396]
#  [8.076716]]
# Bias2  [-0.23037857]
# cost  0.34657365
# Epoch  79000
# Hypothesis  [[9.559793e-08]
#  [9.999999e-01]
#  [5.000000e-01]
#  [5.000000e-01]]
# Theta1  [[-14.45137   14.158643]
#  [ 10.553675  10.719139]]
# Bias1  [-5.1367035 -5.0831013]
# Theta2  [[7.8520284]
#  [8.082139 ]]
# Bias2  [-0.23011059]
# cost  0.34657365
# Epoch  80000
# Hypothesis  [[9.4543132e-08]
#  [9.9999988e-01]
#  [4.9983728e-01]
#  [4.9983728e-01]]
# Theta1  [[-14.45137    14.158643 ]
#  [ 10.5717945  10.731537 ]]
# Bias1  [-5.1439805 -5.099482 ]
# Theta2  [[7.8579097]
#  [8.087348 ]]
# Bias2  [-0.23008919]
# cost  0.34657368
# Epoch  81000
# Hypothesis  [[9.3544031e-08]
#  [9.9999988e-01]
#  [4.9999887e-01]
#  [4.9999887e-01]]
# Theta1  [[-14.45137   14.158643]
#  [ 10.589914  10.743935]]
# Bias1  [-5.151133 -5.114746]
# Theta2  [[7.8633385]
#  [8.092971 ]]
# Bias2  [-0.22963686]
# cost  0.34657365
# Epoch  82000
# Hypothesis  [[9.253113e-08]
#  [9.999999e-01]
#  [5.000026e-01]
#  [5.000026e-01]]
# Theta1  [[-14.45137   14.158643]
#  [ 10.607105  10.756332]]
# Bias1  [-5.157949  -5.1289597]
# Theta2  [[7.8690114]
#  [8.09841  ]]
# Bias2  [-0.22938767]
# cost  0.34657365
# Epoch  83000
# Hypothesis  [[9.153791e-08]
#  [9.999999e-01]
#  [5.000490e-01]
#  [5.000490e-01]]
# Theta1  [[-14.537018  14.158643]
#  [ 10.539444  10.76873 ]]
# Bias1  [-5.2428946 -5.142186 ]
# Theta2  [[7.874565]
#  [8.10385 ]]
# Bias2  [-0.22908916]
# cost  0.34657365
# Epoch  84000
# Hypothesis  [[9.055278e-08]
#  [9.999999e-01]
#  [5.000275e-01]
#  [5.000275e-01]]
# Theta1  [[-14.537018  14.158643]
#  [ 10.558594  10.781128]]
# Bias1  [-5.240395 -5.154504]
# Theta2  [[7.8802314]
#  [8.109213 ]]
# Bias2  [-0.22887161]
# cost  0.34657365
# Epoch  85000
# Hypothesis  [[8.9581839e-08]
#  [9.9999988e-01]
#  [4.9999762e-01]
#  [4.9999762e-01]]
# Theta1  [[-14.537018  14.246196]
#  [ 10.578621  10.792322]]
# Bias1  [-5.238514  -5.0797997]
# Theta2  [[7.8859262]
#  [8.114588 ]]
# Bias2  [-0.22867124]
# cost  0.34657365
# Epoch  86000
# Hypothesis  [[8.8751044e-08]
#  [9.9999988e-01]
#  [4.9993759e-01]
#  [4.9993759e-01]]
# Theta1  [[-14.537018  14.246196]
#  [ 10.598648  10.802813]]
# Bias1  [-5.2372875 -5.0938005]
# Theta2  [[7.8912644]
#  [8.119119 ]]
# Bias2  [-0.22810389]
# cost  0.34657365
# Epoch  87000
# Hypothesis  [[8.7969227e-08]
#  [9.9999988e-01]
#  [4.9996114e-01]
#  [4.9996114e-01]]
# Theta1  [[-14.537018  14.246196]
#  [ 10.617957  10.813303]]
# Bias1  [-5.2366815 -5.1080055]
# Theta2  [[7.89641 ]
#  [8.123581]]
# Bias2  [-0.22732647]
# cost  0.34657365
# Epoch  88000
# Hypothesis  [[8.7192120e-08]
#  [9.9999988e-01]
#  [4.9993336e-01]
#  [4.9993336e-01]]
# Theta1  [[-14.537018  14.246196]
#  [ 10.637031  10.823793]]
# Bias1  [-5.236694  -5.1218333]
# Theta2  [[7.901601]
#  [8.127955]]
# Bias2  [-0.22662118]
# cost  0.34657365
# Epoch  89000
# Hypothesis  [[8.6431946e-08]
#  [9.9999988e-01]
#  [5.0000608e-01]
#  [5.0000608e-01]]
# Theta1  [[-14.537018  14.246196]
#  [ 10.655547  10.834284]]
# Bias1  [-5.23722   -5.1351027]
# Theta2  [[7.906658]
#  [8.13247 ]]
# Bias2  [-0.22578764]
# cost  0.34657365
# Epoch  90000
# Hypothesis  [[8.566059e-08]
#  [9.999999e-01]
#  [4.999745e-01]
#  [4.999745e-01]]
# Theta1  [[-14.537018  14.246196]
#  [ 10.673667  10.844774]]
# Bias1  [-5.2381735 -5.1477823]
# Theta2  [[7.9118958]
#  [8.136883 ]]
# Bias2  [-0.22508922]
# cost  0.34657365
# Epoch  91000
# Hypothesis  [[8.496950e-08]
#  [9.999999e-01]
#  [5.005733e-01]
#  [5.005733e-01]]
# Theta1  [[-14.537018  14.246196]
#  [ 10.691076  10.855265]]
# Bias1  [-5.2395887 -5.1598186]
# Theta2  [[7.916278]
#  [8.142123]]
# Bias2  [-0.22355236]
# cost  0.34657395
# Epoch  92000
# Hypothesis  [[8.4155793e-08]
#  [9.9999988e-01]
#  [4.9998993e-01]
#  [4.9998993e-01]]
# Theta1  [[-14.537018  14.246196]
#  [ 10.708242  10.866015]]
# Bias1  [-5.2412777 -5.1711264]
# Theta2  [[7.922217]
#  [8.145762]]
# Bias2  [-0.22358587]
# cost  0.34657365
# Epoch  93000
# Hypothesis  [[8.341397e-08]
#  [9.999999e-01]
#  [5.000300e-01]
#  [5.000300e-01]]
# Theta1  [[-14.537018  14.246196]
#  [ 10.724666  10.876751]]
# Bias1  [-5.243185  -5.1818476]
# Theta2  [[7.9273543]
#  [8.150263 ]]
# Bias2  [-0.22278863]
# cost  0.34657365
# Epoch  94000
# Hypothesis  [[8.2667498e-08]
#  [9.9999988e-01]
#  [4.9996698e-01]
#  [4.9996698e-01]]
# Theta1  [[-14.537018  14.246196]
#  [ 10.740878  10.887443]]
# Bias1  [-5.2454286 -5.191996 ]
# Theta2  [[7.932621]
#  [8.154626]]
# Bias2  [-0.22213687]
# cost  0.34657365
# Epoch  95000
# Hypothesis  [[8.194318e-08]
#  [9.999999e-01]
#  [5.000006e-01]
#  [5.000006e-01]]
# Theta1  [[-14.537018  14.246196]
#  [ 10.756517  10.897992]]
# Bias1  [-5.2478127 -5.201574 ]
# Theta2  [[7.9377394]
#  [8.159088 ]]
# Bias2  [-0.22134645]
# cost  0.34657365
# Epoch  96000
# Hypothesis  [[8.1252466e-08]
#  [9.9999988e-01]
#  [5.0030655e-01]
#  [5.0030655e-01]]
# Theta1  [[-14.537018  14.246196]
#  [ 10.771776  10.908483]]
# Bias1  [-5.250197  -5.2106323]
# Theta2  [[7.9425077]
#  [8.163926 ]]
# Bias2  [-0.2201923]
# cost  0.3465737
# Epoch  97000
# Hypothesis  [[8.0473285e-08]
#  [9.9999988e-01]
#  [4.9975586e-01]
#  [4.9975586e-01]]
# Theta1  [[-14.537018  14.246196]
#  [ 10.786944  10.918973]]
# Bias1  [-5.2530026 -5.2192044]
# Theta2  [[7.948429]
#  [8.167639]]
# Bias2  [-0.22018607]
# cost  0.3465737
# Epoch  98000
# Hypothesis  [[7.9788123e-08]
#  [9.9999988e-01]
#  [5.0004494e-01]
#  [5.0004494e-01]]
# Theta1  [[-14.623295  14.246196]
#  [ 10.715807  10.929463]]
# Bias1  [-5.3370457 -5.2273126]
# Theta2  [[7.953217]
#  [8.172455]]
# Bias2  [-0.21905804]
# cost  0.34657365
# Epoch  99000
# Hypothesis  [[7.9077864e-08]
#  [9.9999988e-01]
#  [4.9998987e-01]
#  [4.9998987e-01]]
# Theta1  [[-14.623295  14.246196]
#  [ 10.732112  10.939954]]
# Bias1  [-5.3327546 -5.235015 ]
# Theta2  [[7.958465]
#  [8.176815]]
# Bias2  [-0.21839042]
# cost  0.34657365
# Elapsed time  56.477425

# %% [markdown]
# ## Model 4
#
# * Return to using the sigmoid activation function for layer 2
# *  Continue using the Adam Optimizer learning algorithm

# %%
x_ = tf.placeholder(tf.float32, shape=[4,2], name = 'x-input')
y_ = tf.placeholder(tf.float32, shape=[4,1], name = 'y-input')

Theta1 = tf.Variable(tf.random_uniform([2,2], -1, 1), name = "Theta1")
Theta2 = tf.Variable(tf.random_uniform([2,1], -1, 1), name = "Theta2")

Bias1 = tf.Variable(tf.zeros([2]), name = "Bias1")
Bias2 = tf.Variable(tf.zeros([1]), name = "Bias2")

with tf.name_scope("layer2") as scope:
	A2 = tf.sigmoid(tf.matmul(x_, Theta1) + Bias1)

with tf.name_scope("layer3") as scope:
	Hypothesis = tf.sigmoid(tf.matmul(A2, Theta2) + Bias2)

with tf.name_scope("cost") as scope:
	cost = tf.reduce_mean(( (y_ * tf.log(Hypothesis)) + 
		((1 - y_) * tf.log(1.0 - Hypothesis)) ) * -1)

with tf.name_scope("train") as scope:
	train_step = tf.train.AdamOptimizer(0.01).minimize(cost)
  
XOR_X = [[0,0],[0,1],[1,0],[1,1]]
XOR_Y = [[0],[1],[1],[0]]

init = tf.global_variables_initializer()
sess = tf.Session()

#writer = tf.summary.FileWriter("./logs/xor_logs", sess.graph)

sess.run(init)

t_start = time.clock()
for i in range(100000):
	sess.run(train_step, feed_dict={x_: XOR_X, y_: XOR_Y})
	if i % 1000 == 0:
		print('Epoch ', i)
		print('Hypothesis ', sess.run(Hypothesis, feed_dict={x_: XOR_X, y_: XOR_Y}))
		print('Theta1 ', sess.run(Theta1))
		print('Bias1 ', sess.run(Bias1))
		print('Theta2 ', sess.run(Theta2))
		print('Bias2 ', sess.run(Bias2))
		print('cost ', sess.run(cost, feed_dict={x_: XOR_X, y_: XOR_Y}))
t_end = time.clock()
print('Elapsed time ', t_end - t_start)
# Out:
# Epoch  0
# Hypothesis  [[0.6909979 ]
#  [0.64672303]
#  [0.7223264 ]
#  [0.6819148 ]]
# Theta1  [[ 0.91154903  0.01759423]
#  [-0.40655136 -0.5681985 ]]
# Bias1  [-0.00999991 -0.00999993]
# Theta2  [[0.68796396]
#  [0.9498017 ]]
# Bias2  [-0.00999998]
# cost  0.77023965
# Epoch  1000
# Hypothesis  [[0.03956076]
#  [0.93799907]
#  [0.9632074 ]
#  [0.03746817]]
# Theta1  [[ 7.3222656  6.666449 ]
#  [-7.656102  -6.5904126]]
# Bias1  [-3.8925066  3.2577145]
# Theta2  [[ 7.0580506]
#  [-6.512936 ]]
# Bias2  [2.9410083]
# cost  0.04501138
# Epoch  2000
# Hypothesis  [[0.00925676]
#  [0.98634505]
#  [0.9908342 ]
#  [0.00885829]]
# Theta1  [[ 8.398478  8.125467]
#  [-8.780868 -8.086592]]
# Bias1  [-4.375178   4.0587482]
# Theta2  [[ 9.810077]
#  [-9.398983]]
# Bias2  [4.4443774]
# cost  0.010288686
# Epoch  3000
# Hypothesis  [[0.00391291]
#  [0.99427384]
#  [0.996082  ]
#  [0.00376104]]
# Theta1  [[ 8.949761  8.792685]
#  [-9.34984  -8.763931]]
# Bias1  [-4.6386366  4.407253 ]
# Theta2  [[ 11.47301 ]
#  [-11.080085]]
# Bias2  [5.297216]
# cost  0.004339262
# Epoch  4000
# Hypothesis  [[0.00198251]
#  [0.9971052 ]
#  [0.99800545]
#  [0.00191125]]
# Theta1  [[ 9.346258  9.253583]
#  [-9.756174 -9.229363]]
# Bias1  [-4.8312297  4.6438775]
# Theta2  [[ 12.794721]
#  [-12.408077]]
# Bias2  [5.9671836]
# cost  0.0021982724
# Epoch  5000
# Hypothesis  [[0.00109056]
#  [0.99840885]
#  [0.9988997 ]
#  [0.0010538 ]]
# Theta1  [[  9.670047   9.621181]
#  [-10.086522  -9.599296]]
# Bias1  [-4.9897137  4.8309135]
# Theta2  [[ 13.961284]
#  [-13.577931]]
# Bias2  [6.556072]
# cost  0.0012097169
# Epoch  6000
# Hypothesis  [[6.2623236e-04]
#  [9.9908674e-01]
#  [9.9936694e-01]
#  [6.0629641e-04]]
# Theta1  [[  9.952125   9.936188]
#  [-10.373432  -9.915529]]
# Bias1  [-5.1283994  4.9903216]
# Theta2  [[ 15.047255]
#  [-14.666164]]
# Bias2  [7.103249]
# cost  0.0006949565
# Epoch  7000
# Hypothesis  [[3.6833461e-04]
#  [9.9946302e-01]
#  [9.9962711e-01]
#  [3.5720604e-04]]
# Theta1  [[ 10.207054   10.2173195]
#  [-10.632144  -10.197237 ]]
# Bias1  [-5.254103   5.1320777]
# Theta2  [[ 16.088726]
#  [-15.709484]]
# Bias2  [7.627481]
# cost  0.0004089444
# Epoch  8000
# Hypothesis  [[2.1967798e-04]
#  [9.9967980e-01]
#  [9.9977738e-01]
#  [2.1335795e-04]]
# Theta1  [[ 10.442591  10.47445 ]
#  [-10.870754 -10.454526]]
# Bias1  [-5.3704877  5.2614155]
# Theta2  [[ 17.104918]
#  [-16.727339]]
# Bias2  [8.138676]
# cost  0.00024400746
# Epoch  9000
# Hypothesis  [[1.3210470e-04]
#  [9.9980754e-01]
#  [9.9986601e-01]
#  [1.2847666e-04]]
# Theta1  [[ 10.663222  10.713296]
#  [-11.093945 -10.693258]]
# Bias1  [-5.479667   5.3813515]
# Theta2  [[ 18.106619]
#  [-17.73055 ]]
# Bias2  [8.642349]
# cost  0.00014675775
# Epoch  10000
# Hypothesis  [[7.9835845e-05]
#  [9.9988377e-01]
#  [9.9991894e-01]
#  [7.7738747e-05]]
# Theta1  [[ 10.871728  10.93743 ]
#  [-11.304665 -10.917126]]
# Bias1  [-5.5830026  5.493749 ]
# Theta2  [[ 19.099966]
#  [-18.725502]]
# Bias2  [9.141784]
# cost  8.871067e-05
# Epoch  11000
# Hypothesis  [[4.8388767e-05]
#  [9.9992955e-01]
#  [9.9995089e-01]
#  [4.7170724e-05]]
# Theta1  [[ 11.069988  11.149225]
#  [-11.504825 -11.12849 ]]
# Bias1  [-5.681329  5.59989 ]
# Theta2  [[ 20.088684]
#  [-19.71579 ]]
# Bias2  [9.638701]
# cost  5.3779782e-05
# Epoch  12000
# Hypothesis  [[2.9383074e-05]
#  [9.9995720e-01]
#  [9.9997008e-01]
#  [2.8673052e-05]]
# Theta1  [[ 11.259286  11.350359]
#  [-11.695783 -11.329099]]
# Bias1  [-5.775275  5.700612]
# Theta2  [[ 21.074837]
#  [-20.703497]]
# Bias2  [10.134233]
# cost  3.2693697e-05
# Epoch  13000
# Hypothesis  [[1.7864670e-05]
#  [9.9997401e-01]
#  [9.9998188e-01]
#  [1.7449676e-05]]
# Theta1  [[ 11.440549  11.542096]
#  [-11.878555 -11.520243]]
# Bias1  [-5.86533    5.7965975]
# Theta2  [[ 22.059296]
#  [-21.689701]]
# Bias2  [10.628955]
# cost  1.9863452e-05
# Epoch  14000
# Hypothesis  [[1.0867949e-05]
#  [9.9998426e-01]
#  [9.9998891e-01]
#  [1.0625047e-05]]
# Theta1  [[ 11.614586  11.725367]
#  [-12.053891 -11.702897]]
# Bias1  [-5.951791   5.8883104]
# Theta2  [[ 23.043564]
#  [-22.675493]]
# Bias2  [11.123354]
# cost  1.2070015e-05
# Epoch  15000
# Hypothesis  [[6.6148264e-06]
#  [9.9999034e-01]
#  [9.9999321e-01]
#  [6.4723386e-06]]
# Theta1  [[ 11.781942  11.90098 ]
#  [-12.222417 -11.877821]]
# Bias1  [-6.034968  5.976149]
# Theta2  [[ 24.027555]
#  [-23.661066]]
# Bias2  [11.617589]
# cost  7.391004e-06
# Epoch  16000
# Hypothesis  [[4.0282425e-06]
#  [9.9999416e-01]
#  [9.9999595e-01]
#  [3.9445172e-06]]
# Theta1  [[ 11.943087  12.069519]
#  [-12.384595 -12.045627]]
# Bias1  [-6.1150627  6.060425 ]
# Theta2  [[ 25.011482]
#  [-24.646496]]
# Bias2  [12.111807]
# cost  4.470359e-06
# Epoch  17000
# Hypothesis  [[2.4518977e-06]
#  [9.9999642e-01]
#  [9.9999750e-01]
#  [2.4026538e-06]]
# Theta1  [[ 12.0982685  12.231533 ]
#  [-12.54082   -12.206775 ]]
# Bias1  [-6.1923795  6.1414022]
# Theta2  [[ 25.99501 ]
#  [-25.632185]]
# Bias2  [12.605452]
# cost  2.7269164e-06
# Epoch  18000
# Hypothesis  [[1.4933377e-06]
#  [9.9999785e-01]
#  [9.9999845e-01]
#  [1.4643226e-06]]
# Theta1  [[ 12.2478075  12.387334 ]
#  [-12.691289  -12.361722 ]]
# Bias1  [-6.266896  6.219152]
# Theta2  [[ 26.978096]
#  [-26.617702]]
# Bias2  [13.099207]
# cost  1.6689314e-06
# Epoch  19000
# Hypothesis  [[9.0849181e-07]
#  [9.9999869e-01]
#  [9.9999905e-01]
#  [8.9138575e-07]]
# Theta1  [[ 12.391676  12.53714 ]
#  [-12.836075 -12.510392]]
# Bias1  [-6.338786   6.2939167]
# Theta2  [[ 27.959414]
#  [-27.603092]]
# Bias2  [13.591409]
# cost  1.0132795e-06
# Epoch  20000
# Hypothesis  [[5.5446793e-07]
#  [9.9999917e-01]
#  [9.9999940e-01]
#  [5.4434440e-07]]
# Theta1  [[ 12.529835   12.680973 ]
#  [-12.974834  -12.6533375]]
# Bias1  [-6.407628   6.3650866]
# Theta2  [[ 28.937517]
#  [-28.58644 ]]
# Bias2  [14.084446]
# cost  6.25849e-07
# Epoch  21000
# Hypothesis  [[3.3264357e-07]
#  [9.9999952e-01]
#  [9.9999964e-01]
#  [3.2672835e-07]]
# Theta1  [[ 12.659789  12.818579]
#  [-13.106866 -12.789061]]
# Bias1  [-6.4755545  6.433278 ]
# Theta2  [[ 29.900497]
#  [-29.57451 ]]
# Bias2  [14.564866]
# cost  3.725291e-07
# Epoch  22000
# Hypothesis  [[2.1344364e-07]
#  [9.9999976e-01]
#  [9.9999976e-01]
#  [2.0980129e-07]]
# Theta1  [[ 12.786237  12.949136]
#  [-13.231076 -12.923945]]
# Bias1  [-6.534511  6.492109]
# Theta2  [[ 30.865194]
#  [-30.538216]]
# Bias2  [15.08735]
# cost  2.384186e-07
# Epoch  23000
# Hypothesis  [[1.2526506e-07]
#  [9.9999976e-01]
#  [9.9999988e-01]
#  [1.2323083e-07]]
# Theta1  [[ 12.891327  13.071797]
#  [-13.347272 -13.056342]]
# Bias1  [-6.606781  6.54157 ]
# Theta2  [[ 31.761591]
#  [-31.551619]]
# Bias2  [15.57049]
# cost  1.4901161e-07
# Epoch  24000
# Hypothesis  [[9.086646e-08]
#  [9.999999e-01]
#  [9.999999e-01]
#  [8.929269e-08]]
# Theta1  [[ 13.036608  13.187801]
#  [-13.45743  -13.129956]]
# Bias1  [-6.617501   6.6285295]
# Theta2  [[ 32.900154]
#  [-32.327198]]
# Bias2  [16.026718]
# cost  1.0430813e-07
# Epoch  25000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  26000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  27000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  28000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  29000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  30000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  31000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  32000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  33000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  34000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  35000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  36000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  37000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  38000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  39000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  40000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  41000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  42000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  43000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  44000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  45000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  46000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  47000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  48000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  49000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  50000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  51000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  52000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  53000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  54000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  55000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  56000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  57000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  58000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  59000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  60000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  61000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  62000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  63000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  64000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  65000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  66000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  67000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  68000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  69000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  70000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  71000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  72000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  73000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  74000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  75000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  76000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  77000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  78000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  79000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  80000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  81000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  82000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  83000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  84000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  85000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  86000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  87000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  88000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  89000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  90000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  91000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  92000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  93000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  94000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  95000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  96000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  97000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  98000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  99000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Elapsed time  56.027309

# %% [markdown]
# ## Summary
# *  Model 2 proves to be the most accurate network with a cost  of ~0.003
# *  Using tanh for the layer 2 activation function creates an advantage because the layer 2 nodes are not restricted to an output range between 0 and 1
# *  With tanh, the layer can better handle weight and bias inputs with negative values
# *  The ouput from a layer using tanh will be between -1 and 1. The sigmoid function left in layer 3 can work well with values in this range when trying to produce a binary output.
# *  Tanh is a superio activation in most hiddne layers of neural networks.
