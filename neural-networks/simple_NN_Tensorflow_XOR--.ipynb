# %% [markdown]
# Jordan Totten
#
# 1-15-2019
#
# # Building a Neural Network in Tensorflow
# ### Solving a simple XOR problem

# %%
import tensorflow as tf
import time

# %% [markdown]
# ## Model 1
#
# * This model is setup step-by-step and used as a baselin for models 2 - 4

# %% [markdown]
# ### Setup placeholders
#
# *   Tensorflow will automatically fill them with the data when we run the network
# *   In this XOR problem, we have four different training examples and each example has two features
# *   There are also four expected outputs, each with just one value (either 0 or 1)

# %%
x_ = tf.placeholder(tf.float32, shape=[4,2], name = 'x-input')
y_ = tf.placeholder(tf.float32, shape=[4,1], name = 'y-input')

# %% [markdown]
# ### Setup parameters for the network
#
# * These are called variables in Tensorflow
# * Variables will be modified by Tensorflow during the training steps
# * For our theta matrices, we want them initialized to random values between -1 and +1, so we use the built-in random_uniform function to do that

# %%
Theta1 = tf.Variable(tf.random_uniform([2,2], -1, 1), name = "Theta1")
Theta2 = tf.Variable(tf.random_uniform([2,1], -1, 1), name = "Theta2")

# %% [markdown]
# ### Setup bias nodes
#
# *  Bias nodes are setup separately, but still as Variables
# *  this lets the algorithms modify the values of the bias node
# * This is mathematically equivalent to having a signal value of 1 and initial weights of 0 on the links from the bias nodes

# %%
Bias1 = tf.Variable(tf.zeros([2]), name = "Bias1")
Bias2 = tf.Variable(tf.zeros([1]), name = "Bias2")

# %% [markdown]
# ### Tensorflow Model
#
# Tensorflow runs a model inside of a $session$, which it uses to maintain the state of the variables as they pass through the network
#
# *  Matmul is Tensorflow's matrix multiplication function
# *  Sigmoid is the sigmoid activation function
# *  The cost function is the average over all the training examples
# *  The training algorithm used is the gradient descent algorithm with a learning rate of 0.1
# * the training algorithm objective is to minimize the cost function

# %%
with tf.name_scope("layer2") as scope:
	A2 = tf.sigmoid(tf.matmul(x_, Theta1) + Bias1)

with tf.name_scope("layer3") as scope:
	Hypothesis = tf.sigmoid(tf.matmul(A2, Theta2) + Bias2)

with tf.name_scope("cost") as scope:
	cost = tf.reduce_mean(( (y_ * tf.log(Hypothesis)) + 
		((1 - y_) * tf.log(1.0 - Hypothesis)) ) * -1)

with tf.name_scope("train") as scope:
	train_step = tf.train.GradientDescentOptimizer(0.01).minimize(cost)
  
XOR_X = [[0,0],[0,1],[1,0],[1,1]]
XOR_Y = [[0],[1],[1],[0]]

init = tf.global_variables_initializer()
sess = tf.Session()

#writer = tf.summary.FileWriter("./logs/xor_logs", sess.graph)

sess.run(init)

# %% [markdown]
# ### Training steps
#
# *   Each time the training step is executed, the values in the dictionary "feed_dict" are loaded into the placeholders
# *   As the XOR problem is simple, each epoch will contain the entire training set
# *  To see what's going on inside the loop, just print the values of the Variables

# %%
display_step = 1000
t_start = time.clock()
for i in range(100000):
	sess.run(train_step, feed_dict={x_: XOR_X, y_: XOR_Y})
	if i % display_step == 0:
		print('Epoch ', i)
		print('Hypothesis ', sess.run(Hypothesis, feed_dict={x_: XOR_X, y_: XOR_Y}))
		print('Theta1 ', sess.run(Theta1))
		print('Bias1 ', sess.run(Bias1))
		print('Theta2 ', sess.run(Theta2))
		print('Bias2 ', sess.run(Bias2))
		print('cost ', sess.run(cost, feed_dict={x_: XOR_X, y_: XOR_Y}))
t_end = time.clock()
print('Elapsed time ', t_end - t_start)

sess.close()
# Out:
# Epoch  0
# Hypothesis  [[0.47025615]
#  [0.47802955]
#  [0.47609538]
#  [0.4835917 ]]
# Theta1  [[ 0.00044801 -0.21601436]
#  [-0.14339478 -0.35495144]]
# Bias1  [ 1.1300673e-05 -2.9248464e-05]
# Theta2  [[ 0.19633265]
#  [-0.43503365]]
# Bias2  [0.0002309]
# cost  0.69410974
# Epoch  1000
# Hypothesis  [[0.4930162 ]
#  [0.5001736 ]
#  [0.49881768]
#  [0.5056674 ]]
# Theta1  [[ 0.00164458 -0.22675171]
#  [-0.14274408 -0.36269248]]
# Bias1  [ 0.00327497 -0.0111783 ]
# Theta2  [[ 0.22686814]
#  [-0.40976214]]
# Bias2  [0.06217931]
# cost  0.6930344
# Epoch  2000
# Hypothesis  [[0.4934718]
#  [0.5007502]
#  [0.4994833]
#  [0.5064262]]
# Theta1  [[ 0.00120533 -0.2347917 ]
#  [-0.14371558 -0.3678093 ]]
# Bias1  [ 0.00334089 -0.01626994]
# Theta2  [[ 0.22807842]
#  [-0.41080216]]
# Bias2  [0.06338622]
# cost  0.6930219
# Epoch  3000
# Hypothesis  [[0.49330065]
#  [0.50073564]
#  [0.49954444]
#  [0.50661296]]
# Theta1  [[ 0.00069582 -0.24318355]
#  [-0.14475238 -0.37325302]]
# Bias1  [ 0.00331546 -0.02143289]
# Theta2  [[ 0.22850539]
#  [-0.41277915]]
# Bias2  [0.06293681]
# cost  0.69300866
# Epoch  4000
# Hypothesis  [[0.49309668]
#  [0.50070566]
#  [0.4995899 ]
#  [0.5067974 ]]
# Theta1  [[ 1.6071192e-04 -2.5204694e-01]
#  [-1.4581075e-01 -3.7913972e-01]]
# Bias1  [ 0.00329108 -0.02684902]
# Theta2  [[ 0.22893709]
#  [-0.4150282 ]]
# Bias2  [0.06245642]
# cost  0.69299376
# Epoch  5000
# Hypothesis  [[0.49287406]
#  [0.500676  ]
#  [0.4996358 ]
#  [0.50699645]]
# Theta1  [[-0.00040077 -0.26142883]
#  [-0.14689107 -0.38551512]]
# Bias1  [ 0.00327061 -0.03254448]
# Theta2  [[ 0.22939774]
#  [-0.4175619 ]]
# Bias2  [0.06199168]
# cost  0.69297665
# Epoch  6000
# Hypothesis  [[0.49263117]
#  [0.50064725]
#  [0.4996827 ]
#  [0.5072124 ]]
# Theta1  [[-0.00099084 -0.27137995]
#  [-0.14799641 -0.39242765]]
# Bias1  [ 0.00325455 -0.03854372]
# Theta2  [[ 0.22989102]
#  [-0.42041546]]
# Bias2  [0.06154691]
# cost  0.6929574
# Epoch  7000
# Hypothesis  [[0.49236548]
#  [0.5006197 ]
#  [0.49973103]
#  [0.5074474 ]]
# Theta1  [[-0.00161209 -0.28195807]
#  [-0.1491287  -0.399933  ]]
# Bias1  [ 0.00324331 -0.04487393]
# Theta2  [[ 0.23042196]
#  [-0.42363125]]
# Bias2  [0.06112561]
# cost  0.69293535
# Epoch  8000
# Hypothesis  [[0.4920739 ]
#  [0.50059354]
#  [0.49978092]
#  [0.50770354]]
# Theta1  [[-0.00226743 -0.29322886]
#  [-0.15029141 -0.40809503]]
# Bias1  [ 0.0032374  -0.05156562]
# Theta2  [[ 0.23099428]
#  [-0.4272585 ]]
# Bias2  [0.06073129]
# cost  0.69290996
# Epoch  9000
# Hypothesis  [[0.4917529]
#  [0.500569 ]
#  [0.4998328]
#  [0.5079836]]
# Theta1  [[-0.00296021 -0.30526787]
#  [-0.15148762 -0.41698638]]
# Bias1  [ 0.00323737 -0.05865314]
# Theta2  [[ 0.23161338]
#  [-0.43135437]]
# Bias2  [0.06036831]
# cost  0.6928806
# Epoch  10000
# Hypothesis  [[0.49139833]
#  [0.5005465 ]
#  [0.49988708]
#  [0.5082908 ]]
# Theta1  [[-0.00369425 -0.31816164]
#  [-0.15272288 -0.42669153]]
# Bias1  [ 0.00324386 -0.06617518]
# Theta2  [[ 0.23228562]
#  [-0.43598664]]
# Bias2  [0.06004174]
# cost  0.6928464
# Epoch  11000
# Hypothesis  [[0.49100503]
#  [0.5005264 ]
#  [0.49994427]
#  [0.5086288 ]]
# Theta1  [[-0.00447395 -0.3320104 ]
#  [-0.15400034 -0.43730778]]
# Bias1  [ 0.0032576  -0.07417541]
# Theta2  [[ 0.23301743]
#  [-0.44123587]]
# Bias2  [0.05975731]
# cost  0.69280654
# Epoch  12000
# Hypothesis  [[0.49056715]
#  [0.5005094 ]
#  [0.5000051 ]
#  [0.5090019 ]]
# Theta1  [[-0.00530442 -0.34693047]
#  [-0.1553259  -0.44894856]]
# Bias1  [ 0.00327943 -0.08270308]
# Theta2  [[ 0.23381746]
#  [-0.44719782]]
# Bias2  [0.05952164]
# cost  0.6927595
# Epoch  13000
# Hypothesis  [[0.4900773 ]
#  [0.5004961 ]
#  [0.50007045]
#  [0.5094154 ]]
# Theta1  [[-0.00619162 -0.36305752]
#  [-0.15670566 -0.4617464 ]]
# Bias1  [ 0.00331031 -0.09181391]
# Theta2  [[ 0.23469463]
#  [-0.45398623]]
# Bias2  [0.05934242]
# cost  0.69270384
# Epoch  14000
# Hypothesis  [[0.48952687]
#  [0.5004876 ]
#  [0.5001415 ]
#  [0.5098753 ]]
# Theta1  [[-0.00714251 -0.38055015]
#  [-0.15814748 -0.47585666]]
# Bias1  [ 0.00335136 -0.10157067]
# Theta2  [[ 0.2356603 ]
#  [-0.46173847]]
# Bias2  [0.05922839]
# cost  0.6926373
# Epoch  15000
# Hypothesis  [[0.4889052 ]
#  [0.5004851 ]
#  [0.50021964]
#  [0.510389  ]]
# Theta1  [[-0.00816533 -0.39959523]
#  [-0.15965915 -0.4914629 ]]
# Bias1  [ 0.00340387 -0.11204389]
# Theta2  [[ 0.23672676]
#  [-0.47061986]]
# Bias2  [0.05918969]
# cost  0.6925574
# Epoch  16000
# Hypothesis  [[0.4881991 ]
#  [0.5004904 ]
#  [0.50030696]
#  [0.51096517]]
# Theta1  [[-0.00926984 -0.42041337]
#  [-0.16125113 -0.50878173]]
# Bias1  [ 0.00346936 -0.12331235]
# Theta2  [[ 0.23790921]
#  [-0.48083124]]
# Bias2  [0.05923786]
# cost  0.69246036
# Epoch  17000
# Hypothesis  [[0.48739263]
#  [0.5005058 ]
#  [0.50040615]
#  [0.5116142 ]]
# Theta1  [[-0.0104677  -0.4432657 ]
#  [-0.16293544 -0.5280712 ]]
# Bias1  [ 0.00354958 -0.13546322]
# Theta2  [[ 0.23922531]
#  [-0.49261725]]
# Bias2  [0.05938607]
# cost  0.6923415
# Epoch  18000
# Hypothesis  [[0.48646593]
#  [0.50053436]
#  [0.5005206 ]
#  [0.5123486 ]]
# Theta1  [[-0.01177293 -0.46846306]
#  [-0.16472705 -0.5496387 ]]
# Bias1  [ 0.00364659 -0.14859118]
# Theta2  [[ 0.24069566]
#  [-0.506277  ]]
# Bias2  [0.05964923]
# cost  0.6921947
# Epoch  19000
# Hypothesis  [[0.4853944]
#  [0.5005803]
#  [0.5006552]
#  [0.5131832]]
# Theta1  [[-0.0132025  -0.49637538]
#  [-0.16664284 -0.5738513 ]]
# Bias1  [ 0.00376282 -0.16279648]
# Theta2  [[ 0.2423451]
#  [-0.5221784]]
# Bias2  [0.06004418]
# cost  0.6920116
# Epoch  20000
# Hypothesis  [[0.48414734]
#  [0.5006496 ]
#  [0.5008164 ]
#  [0.51413554]]
# Theta1  [[-0.01477701 -0.52744305]
#  [-0.16870424 -0.6011471 ]]
# Bias1  [ 0.00390114 -0.17818029]
# Theta2  [[ 0.2442028]
#  [-0.5407733]]
# Bias2  [0.06058978]
# cost  0.69178104
# Epoch  21000
# Hypothesis  [[0.4826864]
#  [0.50075  ]
#  [0.501013 ]
#  [0.5152263]]
# Theta1  [[-0.01652173 -0.56219   ]
#  [-0.17093714 -0.632049  ]]
# Bias1  [ 0.00406495 -0.19483578]
# Theta2  [[ 0.24630398]
#  [-0.56261903]]
# Bias2  [0.06130698]
# cost  0.69148767
# Epoch  22000
# Hypothesis  [[0.48096398]
#  [0.5008926 ]
#  [0.50125694]
#  [0.5164793 ]]
# Theta1  [[-0.0184676  -0.6012342 ]
#  [-0.1733733  -0.66717666]]
# Bias1  [ 0.00425833 -0.21283308]
# Theta2  [[ 0.24869065]
#  [-0.5884005 ]]
# Bias2  [0.06221914]
# cost  0.6911108
# Epoch  23000
# Hypothesis  [[0.47892067]
#  [0.50109226]
#  [0.5015644 ]
#  [0.51792127]]
# Theta1  [[-0.02065278 -0.64529884]
#  [-0.17605153 -0.70725834]]
# Bias1  [ 0.00448623 -0.23219359]
# Theta2  [[ 0.25141403]
#  [-0.6189552 ]]
# Bias2  [0.06335237]
# cost  0.69062227
# Epoch  24000
# Hypothesis  [[0.47648305]
#  [0.50136936]
#  [0.5019572 ]
#  [0.51958174]]
# Theta1  [[-0.02312438 -0.69521457]
#  [-0.17901988 -0.75313413]]
# Bias1  [ 0.00475477 -0.25284988]
# Theta2  [[ 0.25453728]
#  [-0.6552975 ]]
# Bias2  [0.06473675]
# cost  0.6899842
# Epoch  25000
# Hypothesis  [[0.47356153]
#  [0.50175107]
#  [0.5024641 ]
#  [0.5214912 ]]
# Theta1  [[-0.0259404  -0.7519119 ]
#  [-0.18233752 -0.8057501 ]]
# Bias1  [ 0.00507169 -0.27458483]
# Theta2  [[ 0.2581388]
#  [-0.6986349]]
# Bias2  [0.06640858]
# cost  0.689146
# Epoch  26000
# Hypothesis  [[0.47004735]
#  [0.5022728 ]
#  [0.50312245]
#  [0.52367955]]
# Theta1  [[-0.02917228 -0.81639093]
#  [-0.18607712 -0.8661314 ]]
# Bias1  [ 0.00544712 -0.29694435]
# Theta2  [[ 0.26231816]
#  [-0.7503688 ]]
# Bias2  [0.0684151]
# cost  0.68804145
# Epoch  27000
# Hypothesis  [[0.46581152]
#  [0.5029799 ]
#  [0.5039792 ]
#  [0.5261744 ]]
# Theta1  [[-0.03290761 -0.8896681 ]
#  [-0.19032785 -0.9353282 ]]
# Bias1  [ 0.00589469 -0.31914273]
# Theta2  [[ 0.26720473]
#  [-0.8120666 ]]
# Bias2  [0.0708226]
# cost  0.686587
# Epoch  28000
# Hypothesis  [[0.4607019 ]
#  [0.5039274 ]
#  [0.50509083]
#  [0.52899987]]
# Theta1  [[-0.0372536  -0.9726907 ]
#  [-0.19519901 -1.0143335 ]]
# Bias1  [ 0.00643342 -0.3399308 ]
# Theta2  [[ 0.2729687]
#  [-0.8853927]]
# Bias2  [0.07372887]
# cost  0.68468094
# Epoch  29000
# Hypothesis  [[0.4545413]
#  [0.5051803]
#  [0.5065236]
#  [0.532179 ]]
# Theta1  [[-0.0423418  -1.0662384 ]
#  [-0.20082507 -1.1039798 ]]
# Bias1  [ 0.00709028 -0.35752112]
# Theta2  [[ 0.27983755]
#  [-0.9719939 ]]
# Bias2  [0.07728055]
# cost  0.6822055
# Epoch  30000
# Hypothesis  [[0.44712344]
#  [0.5068129 ]
#  [0.5083525 ]
#  [0.5357402 ]]
# Theta1  [[-0.04833483 -1.170824  ]
#  [-0.2073724  -1.2048402 ]]
# Bias1  [ 0.00790375 -0.36957484]
# Theta2  [[ 0.28811306]
#  [-1.073344  ]]
# Bias2  [0.08168945]
# cost  0.67903125
# Epoch  31000
# Hypothesis  [[0.43820676]
#  [0.50890887]
#  [0.51066244]
#  [0.53972673]]
# Theta1  [[-0.0554372 -1.2866447]
#  [-0.2150508 -1.3171692]]
# Bias1  [ 0.00892811 -0.37332708]
# Theta2  [[ 0.2981923]
#  [-1.1905866]]
# Bias2  [0.08724172]
# cost  0.6750223
# Epoch  32000
# Hypothesis  [[0.42751157]
#  [0.51156336]
#  [0.5135502 ]
#  [0.5442053 ]]
# Theta1  [[-0.06391131 -1.4135894 ]
#  [-0.22412993 -1.4409078 ]]
# Bias1  [ 0.01023872 -0.36587846]
# Theta2  [[ 0.3105841]
#  [-1.3243912]]
# Bias2  [0.09428938]
# cost  0.67004174
# Epoch  33000
# Hypothesis  [[0.41472813]
#  [0.51488566]
#  [0.51712817]
#  [0.5492656 ]]
# Theta1  [[-0.07409953 -1.551302  ]
#  [-0.234962   -1.5757389 ]]
# Bias1  [ 0.01193797 -0.34464052]
# Theta2  [[ 0.32592228]
#  [-1.4748604 ]]
# Bias2  [0.10321199]
# cost  0.6639578
# Epoch  34000
# Hypothesis  [[0.39955205]
#  [0.51899797]
#  [0.5215239 ]
#  [0.55500376]]
# Theta1  [[-0.08645143 -1.6992427 ]
#  [-0.24800883 -1.7211517 ]]
# Bias1  [ 0.01416249 -0.30786905]
# Theta2  [[ 0.34496975]
#  [-1.6414546 ]]
# Bias2  [0.11433943]
# cost  0.6566561
# Epoch  35000
# Hypothesis  [[0.38176084]
#  [0.52402407]
#  [0.52686864]
#  [0.56148523]]
# Theta1  [[-0.10154941 -1.8566992 ]
#  [-0.26386943 -1.8764497 ]]
# Bias1  [ 0.01709211 -0.25518197]
# Theta2  [[ 0.3686111]
#  [-1.8229182]]
# Bias2  [0.12783031]
# cost  0.64806587
# Epoch  36000
# Hypothesis  [[0.36132842]
#  [0.5300617 ]
#  [0.5332696 ]
#  [0.56869274]]
# Theta1  [[-0.12012207 -2.0226996 ]
#  [-0.28329387 -2.0406723 ]]
# Bias1  [ 0.02096249 -0.18790361]
# Theta2  [[ 0.3978336]
#  [-2.0172095]]
# Bias2  [0.14351767]
# cost  0.63819736
# Epoch  37000
# Hypothesis  [[0.33854365]
#  [0.5371401 ]
#  [0.5407667 ]
#  [0.5764751 ]]
# Theta1  [[-0.14302833 -2.1958733 ]
#  [-0.30716872 -2.2124507 ]]
# Bias1  [ 0.02608714 -0.10905153]
# Theta2  [[ 0.433704 ]
#  [-2.2214842]]
# Bias2  [0.16076668]
# cost  0.6271795
# Epoch  38000
# Hypothesis  [[0.31406027]
#  [0.54517806]
#  [0.54929024]
#  [0.5845254 ]]
# Theta1  [[-0.17119165 -2.374325  ]
#  [-0.33645308 -2.3898945 ]]
# Bias1  [ 0.03290003 -0.02283965]
# Theta2  [[ 0.47735894]
#  [-2.4322438 ]]
# Bias2  [0.17842427]
# cost  0.61526763
# Epoch  39000
# Hypothesis  [[0.28882286]
#  [0.55397046]
#  [0.5586479 ]
#  [0.59241414]]
# Theta1  [[-0.20547695 -2.5556855 ]
#  [-0.37205434 -2.5706227 ]]
# Bias1  [0.04203283 0.06621306]
# Theta2  [[ 0.5300204]
#  [-2.6456826]]
# Bias2  [0.19493298]
# cost  0.6028043
# Epoch  40000
# Hypothesis  [[0.26387617]
#  [0.56321985]
#  [0.56855583]
#  [0.599672  ]]
# Theta1  [[-0.24652396 -2.7373004 ]
#  [-0.4146605  -2.75198   ]]
# Bias1  [0.05443454 0.15421686]
# Theta2  [[ 0.59301126]
#  [-2.8582141 ]]
# Bias2  [0.20859323]
# cost  0.59014225
# Epoch  41000
# Hypothesis  [[0.24015933]
#  [0.57260764]
#  [0.578711  ]
#  [0.60588336]]
# Theta1  [[-0.2945795 -2.9166095]
#  [-0.4645617 -2.9313998]]
# Bias1  [0.07151185 0.238512  ]
# Theta2  [[ 0.66770965]
#  [-3.0668573 ]]
# Bias2  [0.21784388]
# cost  0.57756543
# Epoch  42000
# Hypothesis  [[0.21835992]
#  [0.5818654 ]
#  [0.58886224]
#  [0.61075026]]
# Theta1  [[-0.34938905 -3.0914433 ]
#  [-0.5215228  -3.1066937 ]]
# Bias1  [0.0952429  0.31778345]
# Theta2  [[ 0.75541735]
#  [-3.2695434 ]]
# Bias2  [0.2214275]
# cost  0.56524354
# Epoch  43000
# Hypothesis  [[0.19887447]
#  [0.5908256 ]
#  [0.598858  ]
#  [0.61410815]]
# Theta1  [[-0.41021538 -3.260206  ]
#  [-0.5847687  -3.27626   ]]
# Bias1  [0.12819818 0.391825  ]
# Theta2  [[ 0.85717976]
#  [-3.4651635 ]]
# Bias2  [0.21837078]
# cost  0.5532252
# Epoch  44000
# Hypothesis  [[0.18184726]
#  [0.5994376 ]
#  [0.6086596 ]
#  [0.6158983 ]]
# Theta1  [[-0.47602886 -3.4219153 ]
#  [-0.65312713 -3.4391081 ]]
# Bias1  [0.17342666 0.4611788 ]
# Theta2  [[ 0.97366107]
#  [-3.6534507 ]]
# Bias2  [0.20781702]
# cost  0.5414534
# Epoch  45000
# Hypothesis  [[0.16724442]
#  [0.6077626 ]
#  [0.6183285 ]
#  [0.616114  ]]
# Theta1  [[-0.5458524  -3.576119  ]
#  [-0.72530794 -3.5947857 ]]
# Bias1  [0.23421694 0.52681255]
# Theta2  [[ 1.105154]
#  [-3.834795]]
# Bias2  [0.18880843]
# cost  0.5297828
# Epoch  46000
# Hypothesis  [[0.1549278 ]
#  [0.6159579 ]
#  [0.6279983 ]
#  [0.61473596]]
# Theta1  [[-0.619169  -3.7227683]
#  [-0.8002451 -3.7432368]]
# Bias1  [0.31380132 0.58989394]
# Theta2  [[ 1.2517139]
#  [-4.0100513]]
# Bias2  [0.16011018]
# cost  0.5179885
# Epoch  47000
# Hypothesis  [[0.14470817]
#  [0.6242664 ]
#  [0.6378419 ]
#  [0.61167496]]
# Theta1  [[-0.69627047 -3.8620894 ]
#  [-0.87738514 -3.8846772 ]]
# Bias1  [0.41507718 0.65165466]
# Theta2  [[ 1.4133493]
#  [-4.1804028]]
# Bias2  [0.12013625]
# cost  0.505767
# Epoch  48000
# Hypothesis  [[0.13637538]
#  [0.63300854]
#  [0.6480376 ]
#  [0.60673136]]
# Theta1  [[-0.77843165 -3.9944851 ]
#  [-0.95686597 -4.019468  ]]
# Bias1  [0.5403673  0.71330976]
# Theta2  [[ 1.5901625]
#  [-4.3472123]]
# Bias2  [0.06700652]
# cost  0.49273932
# Epoch  49000
# Hypothesis  [[0.12970181]
#  [0.6425721 ]
#  [0.6587393 ]
#  [0.59957385]]
# Theta1  [[-0.8678382 -4.1204567]
#  [-1.039575  -4.1480265]]
# Bias1  [0.6912035 0.7759771]
# Theta2  [[ 1.782391 ]
#  [-4.5119348]]
# Bias2  [-0.00125939]
# cost  0.47846222
# Epoch  50000
# Hypothesis  [[0.12443347]
#  [0.6533799 ]
#  [0.67006373]
#  [0.58974475]]
# Theta1  [[-0.9671999 -4.2405486]
#  [-1.1271112 -4.2707405]]
# Bias1  [0.86811453 0.8405978 ]
# Theta2  [[ 1.9903423]
#  [-4.6759667]]
# Bias2  [-0.08641514]
# cost  0.4624597
# Epoch  51000
# Hypothesis  [[0.12027038]
#  [0.6658261 ]
#  [0.6821106 ]
#  [0.57670146]]
# Theta1  [[-1.0790582 -4.3553004]
#  [-1.22164   -4.3879123]]
# Bias1  [1.0704411  0.90781367]
# Theta2  [[ 2.2142498]
#  [-4.840653 ]]
# Bias2  [-0.1895619]
# cost  0.4442771
# Epoch  52000
# Hypothesis  [[0.1168814 ]
#  [0.6801754 ]
#  [0.69500816]
#  [0.5599022 ]]
# Theta1  [[-1.204932  -4.465171 ]
#  [-1.3255596 -4.4997506]]
# Bias1  [1.2962079  0.97786933]
# Theta2  [[ 2.4540281]
#  [-5.0069013]]
# Bias2  [-0.31075186]
# cost  0.42357257
# Epoch  53000
# Hypothesis  [[0.11391013]
#  [0.696463  ]
#  [0.70894015]
#  [0.53894365]]
# Theta1  [[-1.3446397 -4.57048  ]
#  [-1.4409125 -4.606333 ]]
# Bias1  [1.5420921 1.0505564]
# Theta2  [[ 2.7089627]
#  [-5.1752234]]
# Bias2  [-0.44873837]
# cost  0.40022418
# Epoch  54000
# Hypothesis  [[0.11101919]
#  [0.7144584 ]
#  [0.72409886]
#  [0.513727  ]]
# Theta1  [[-1.4961448 -4.671365 ]
#  [-1.5685948 -4.7076507]]
# Bias1  [1.8035182 1.1252303]
# Theta2  [[ 2.9773715]
#  [-5.345587 ]]
# Bias2  [-0.60098267]
# cost  0.37443066
# Epoch  55000
# Hypothesis  [[0.10793698]
#  [0.73370695]
#  [0.7405523 ]
#  [0.48459104]]
# Theta1  [[-1.6559908 -4.767746 ]
#  [-1.7077286 -4.8036456]]
# Bias1  [2.0749145 1.2009194]
# Theta2  [[ 3.2563927]
#  [-5.5174036]]
# Bias2  [-0.76393825]
# cost  0.34675443
# Epoch  56000
# Hypothesis  [[0.10449952]
#  [0.7536196 ]
#  [0.75811297]
#  [0.45234856]]
# Theta1  [[-1.8200477 -4.8593926]
#  [-1.8555754 -4.8942413]]
# Bias1  [2.3501487 1.276486 ]
# Theta2  [[ 3.5420263]
#  [-5.689542 ]]
# Bias2  [-0.93350464]
# cost  0.31806982
# Epoch  57000
# Hypothesis  [[0.10064138]
#  [0.7735776 ]
#  [0.77633035]
#  [0.41820347]]
# Theta1  [[-1.9842116 -4.9460444]
#  [-2.0081298 -4.979398 ]]
# Bias1  [2.6231456 1.3507818]
# Theta2  [[ 3.82957  ]
#  [-5.8609157]]
# Bias2  [-1.1054906]
# cost  0.28940362
# Epoch  58000
# Hypothesis  [[0.0964177 ]
#  [0.79299957]
#  [0.7945863 ]
#  [0.3835264 ]]
# Theta1  [[-2.144918  -5.0274963]
#  [-2.161053  -5.0591407]]
# Bias1  [2.8885558 1.4228033]
# Theta2  [[ 4.114175 ]
#  [-6.0299997]]
# Bias2  [-1.2761056]
# cost  0.26174855
# Epoch  59000
# Hypothesis  [[0.09193807]
#  [0.8114086 ]
#  [0.8122714 ]
#  [0.3496148 ]]
# Theta1  [[-2.2993975 -5.103686 ]
#  [-2.3105445 -5.1335673]]
# Bias1  [3.14224   1.4917684]
# Theta2  [[ 4.3915434]
#  [-6.1955423]]
# Bias2  [-1.4422485]
# cost  0.23588437
# Epoch  60000
# Hypothesis  [[0.08733729]
#  [0.82846963]
#  [0.8289063 ]
#  [0.31749576]]
# Theta1  [[-2.4457707 -5.1746993]
#  [-2.4537926 -5.2028737]]
# Bias1  [3.381474 1.557145]
# Theta2  [[ 4.658341 ]
#  [-6.3564844]]
# Bias2  [-1.6016701]
# cost  0.21229969
# Epoch  61000
# Hypothesis  [[0.0827427 ]
#  [0.8439983 ]
#  [0.84419316]
#  [0.2878391 ]]
# Theta1  [[-2.5829895 -5.2407527]
#  [-2.589063  -5.267336 ]]
# Bias1  [3.6048555 1.6186345]
# Theta2  [[ 4.912358]
#  [-6.512066]]
# Bias2  [-1.7529579]
# cost  0.19119935
# Epoch  62000
# Hypothesis  [[0.078258  ]
#  [0.85794306]
#  [0.8580039 ]
#  [0.26097342]]
# Theta1  [[-2.710687  -5.3021383]
#  [-2.7155304 -5.327272 ]]
# Bias1  [3.8120508 1.6761378]
# Theta2  [[ 5.1524262]
#  [-6.661796 ]]
# Bias2  [-1.8954133]
# cost  0.17256889
# Epoch  63000
# Hypothesis  [[0.07395738]
#  [0.87035024]
#  [0.87033844]
#  [0.2369585 ]]
# Theta1  [[-2.8289883 -5.3592243]
#  [-2.8330355 -5.3830385]]
# Bias1  [4.003471  1.7297053]
# Theta2  [[ 5.3782096]
#  [-6.8054295]]
# Bias2  [-2.028877]
# cost  0.15625265
# Epoch  64000
# Hypothesis  [[0.06988724]
#  [0.88132703]
#  [0.88127685]
#  [0.21567537]]
# Theta1  [[-2.9383342 -5.4123616]
#  [-2.94185   -5.4349933]]
# Bias1  [4.1799836 1.7794919]
# Theta2  [[ 5.5899625]
#  [-6.9429183]]
# Bias2  [-2.1535568]
# cost  0.14202292
# Epoch  65000
# Hypothesis  [[0.06607197]
#  [0.89101267]
#  [0.8909431 ]
#  [0.19690597]]
# Theta1  [[-3.0393405 -5.4619102]
#  [-3.0424876 -5.483481 ]]
# Bias1  [4.342707  1.8257167]
# Theta2  [[ 5.7883177]
#  [-7.074357 ]]
# Bias2  [-2.2698882]
# cost  0.12962767
# Epoch  66000
# Hypothesis  [[0.06251916]
#  [0.8995535 ]
#  [0.8994753 ]
#  [0.18038782]]
# Theta1  [[-3.1326978 -5.508206 ]
#  [-3.1355796 -5.5288215]]
# Bias1  [4.4928427 1.8686318]
# Theta2  [[ 5.974103 ]
#  [-7.1999283]]
# Bias2  [-2.3784266]
# cost  0.11882086
# Epoch  67000
# Hypothesis  [[0.05922538]
#  [0.90709305]
#  [0.90701216]
#  [0.1658518 ]]
# Theta1  [[-3.2191021 -5.5515695]
#  [-3.221787  -5.5713253]]
# Bias1  [4.631576  1.9085027]
# Theta2  [[ 6.1482534]
#  [-7.319885 ]]
# Bias2  [-2.4797766]
# cost  0.109376386
# Epoch  68000
# Hypothesis  [[0.05617968]
#  [0.9137626 ]
#  [0.91368264]
#  [0.15304287]]
# Theta1  [[-3.299229  -5.59228  ]
#  [-3.3017623 -5.611247 ]]
# Bias1  [4.760045  1.9455882]
# Theta2  [[ 6.311703 ]
#  [-7.4345136]]
# Bias2  [-2.5745442]
# cost  0.101095274
# Epoch  69000
# Hypothesis  [[0.05336758]
#  [0.9196799 ]
#  [0.9196019 ]
#  [0.14172934]]
# Theta1  [[-3.3737013 -5.630582 ]
#  [-3.3761122 -5.6488485]]
# Bias1  [4.879283  1.9801388]
# Theta2  [[ 6.4653664]
#  [-7.5441136]]
# Bias2  [-2.6633096]
# cost  0.093806066
# Epoch  70000
# Hypothesis  [[0.05077218]
#  [0.9249465 ]
#  [0.92487216]
#  [0.13170758]]
# Theta1  [[-3.443084  -5.6667156]
#  [-3.4453957 -5.6843204]]
# Bias1  [4.9902363 2.012387 ]
# Theta2  [[ 6.6100893]
#  [-7.648983 ]]
# Bias2  [-2.7466152]
# cost  0.08736308
# Epoch  71000
# Hypothesis  [[0.04837642]
#  [0.9296508 ]
#  [0.92958   ]
#  [0.12279958]]
# Theta1  [[-3.5078876 -5.700862 ]
#  [-3.510116  -5.7178826]]
# Bias1  [5.093736  2.0425444]
# Theta2  [[ 6.7466655]
#  [-7.7494183]]
# Bias2  [-2.8249595]
# cost  0.08164355
# Epoch  72000
# Hypothesis  [[0.04616347]
#  [0.93386835]
#  [0.93380123]
#  [0.11485404]]
# Theta1  [[-3.5685658 -5.7332015]
#  [-3.5707192 -5.7496686]]
# Bias1  [5.190537  2.0708015]
# Theta2  [[ 6.8758082]
#  [-7.8457017]]
# Bias2  [-2.8987932]
# cost  0.076544285
# Epoch  73000
# Hypothesis  [[0.04411675]
#  [0.9376629 ]
#  [0.9375995 ]
#  [0.10774061]]
# Theta1  [[-3.6255178 -5.7639084]
#  [-3.627609  -5.7798734]]
# Bias1  [5.281293  2.0973363]
# Theta2  [[ 6.998157]
#  [-7.938098]]
# Bias2  [-2.9685225]
# cost  0.07197878
# Epoch  74000
# Hypothesis  [[0.04222199]
#  [0.9410901 ]
#  [0.94103026]
#  [0.1013496 ]]
# Theta1  [[-3.6790996 -5.793109 ]
#  [-3.6811357 -5.808606 ]]
# Bias1  [5.3665905 2.1223066]
# Theta2  [[ 7.114307 ]
#  [-8.0268545]]
# Bias2  [-3.03451]
# cost  0.06787421
# Epoch  75000
# Hypothesis  [[0.04046474]
#  [0.94419545]
#  [0.9441389 ]
#  [0.09558613]]
# Theta1  [[-3.7296276 -5.8209248]
#  [-3.7316144 -5.835994 ]]
# Bias1  [5.4469376 2.1458454]
# Theta2  [[ 7.224765]
#  [-8.112212]]
# Bias2  [-3.0970805]
# cost  0.06416963
# Epoch  76000
# Hypothesis  [[0.03883198]
#  [0.94701976]
#  [0.9469663 ]
#  [0.090371  ]]
# Theta1  [[-3.7773798 -5.8474956]
#  [-3.7793212 -5.8621593]]
# Bias1  [5.5227957 2.1680863]
# Theta2  [[ 7.3300147]
#  [-8.194411 ]]
# Bias2  [-3.156526]
# cost  0.060812913
# Epoch  77000
# Hypothesis  [[0.03731334]
#  [0.9495959 ]
#  [0.94954544]
#  [0.08563577]]
# Theta1  [[-3.8226016 -5.8728623]
#  [-3.8245022 -5.8871655]]
# Bias1  [5.5945673 2.1891332]
# Theta2  [[ 7.43046]
#  [-8.27361]]
# Bias2  [-3.213108]
# cost  0.057761054
# Epoch  78000
# Hypothesis  [[0.03589902]
#  [0.9519534 ]
#  [0.9519056 ]
#  [0.08132236]]
# Theta1  [[-3.8655107 -5.897167 ]
#  [-3.8673701 -5.9111133]]
# Bias1  [5.6625943 2.2090974]
# Theta2  [[ 7.5264883]
#  [-8.349985 ]]
# Bias2  [-3.2670548]
# cost  0.054976963
# Epoch  79000
# Hypothesis  [[0.03457882]
#  [0.95411766]
#  [0.9540723 ]
#  [0.07738117]]
# Theta1  [[-3.9062994 -5.9204726]
#  [-3.9081254 -5.934091 ]]
# Bias1  [5.727211  2.2280571]
# Theta2  [[ 7.618436]
#  [-8.423738]]
# Bias2  [-3.3185797]
# cost  0.052428506
# Epoch  80000
# Hypothesis  [[0.03334293]
#  [0.9561099 ]
#  [0.9560667 ]
#  [0.07376933]]
# Theta1  [[-3.9451444 -5.9428473]
#  [-3.9469361 -5.956173 ]]
# Bias1  [5.7886915 2.2460904]
# Theta2  [[ 7.7066026]
#  [-8.49508  ]]
# Bias2  [-3.3678653]
# cost  0.05008837
# Epoch  81000
# Hypothesis  [[0.03218773]
#  [0.9579483 ]
#  [0.95790744]
#  [0.07044966]]
# Theta1  [[-3.9821994 -5.9643693]
#  [-3.9839604 -5.9773936]]
# Bias1  [5.847286  2.2632866]
# Theta2  [[ 7.791265]
#  [-8.564014]]
# Bias2  [-3.4150813]
# cost  0.04793425
# Epoch  82000
# Hypothesis  [[0.03110362]
#  [0.9596497 ]
#  [0.95961094]
#  [0.06739005]]
# Theta1  [[-4.017611  -5.98509  ]
#  [-4.019339  -5.9978123]]
# Bias1  [5.903226  2.2796903]
# Theta2  [[ 7.872679]
#  [-8.630796]]
# Bias2  [-3.4603798]
# cost  0.04594503
# Epoch  83000
# Hypothesis  [[0.03008446]
#  [0.9612279 ]
#  [0.96119046]
#  [0.06456363]]
# Theta1  [[-4.0514874 -6.0050263]
#  [-4.0531816 -6.01754  ]]
# Bias1  [5.9567013 2.295375 ]
# Theta2  [[ 7.951049]
#  [-8.695524]]
# Bias2  [-3.5038965]
# cost  0.044103716
# Epoch  84000
# Hypothesis  [[0.02912581]
#  [0.9626947 ]
#  [0.9626595 ]
#  [0.06194642]]
# Theta1  [[-4.083933  -6.0242968]
#  [-4.0856075 -6.0365233]]
# Bias1  [6.0078955 2.3103876]
# Theta2  [[ 8.026592]
#  [-8.758295]]
# Bias2  [-3.5457568]
# cost  0.042395264
# Epoch  85000
# Hypothesis  [[0.02822258]
#  [0.96406174]
#  [0.9640282 ]
#  [0.05951764]]
# Theta1  [[-4.11506  -6.042892]
#  [-4.116707 -6.054884]]
# Bias1  [6.0569797 2.3247705]
# Theta2  [[ 8.09948 ]
#  [-8.819217]]
# Bias2  [-3.586069]
# cost  0.040806387
# Epoch  86000
# Hypothesis  [[0.02737095]
#  [0.96533847]
#  [0.9653059 ]
#  [0.05725551]]
# Theta1  [[-4.144997  -6.0608478]
#  [-4.1466165 -6.0726633]]
# Bias1  [6.1040983 2.33858  ]
# Theta2  [[ 8.169929]
#  [-8.878407]]
# Bias2  [-3.6249366]
# cost  0.039324798
# Epoch  87000
# Hypothesis  [[0.02656353]
#  [0.9665322 ]
#  [0.966501  ]
#  [0.05514925]]
# Theta1  [[-4.173748  -6.0782423]
#  [-4.175346  -6.0898643]]
# Bias1  [6.149384  2.3518527]
# Theta2  [[ 8.238002]
#  [-8.935995]]
# Bias2  [-3.6624553]
# cost  0.037941165
# Epoch  88000
# Hypothesis  [[0.02580295]
#  [0.9676509 ]
#  [0.96762127]
#  [0.0531808 ]]
# Theta1  [[-4.2014484 -6.0950956]
#  [-4.2030272 -6.1064944]]
# Bias1  [6.192967 2.364612]
# Theta2  [[ 8.303901]
#  [-8.991889]]
# Bias2  [-3.6987054]
# cost  0.036646817
# Epoch  89000
# Hypothesis  [[0.02508072]
#  [0.9687019 ]
#  [0.96867365]
#  [0.05133864]]
# Theta1  [[-4.2281523 -6.11143  ]
#  [-4.2297115 -6.1226277]]
# Bias1  [6.234947  2.3768933]
# Theta2  [[ 8.36776 ]
#  [-9.046396]]
# Bias2  [-3.7337599]
# cost  0.03543246
# Epoch  90000
# Hypothesis  [[0.02439744]
#  [0.96969014]
#  [0.969663  ]
#  [0.04961108]]
# Theta1  [[-4.25392   -6.1272693]
#  [-4.2554593 -6.13829  ]]
# Bias1  [6.2754216 2.3887248]
# Theta2  [[ 8.429679]
#  [-9.099408]]
# Bias2  [-3.767696]
# cost  0.034292337
# Epoch  91000
# Hypothesis  [[0.02374603]
#  [0.97062117]
#  [0.970595  ]
#  [0.0479881 ]]
# Theta1  [[-4.2788186 -6.142639 ]
#  [-4.2803383 -6.15351  ]]
# Bias1  [6.3145003 2.400149 ]
# Theta2  [[ 8.489772]
#  [-9.151187]]
# Bias2  [-3.8005805]
# cost  0.03321882
# Epoch  92000
# Hypothesis  [[0.02312976]
#  [0.9714993 ]
#  [0.97147423]
#  [0.04646042]]
# Theta1  [[-4.302885  -6.1575685]
#  [-4.3043942 -6.168292 ]]
# Bias1  [6.3522286 2.4112034]
# Theta2  [[ 8.5481615]
#  [-9.201544 ]]
# Bias2  [-3.8324718]
# cost  0.03220775
# Epoch  93000
# Hypothesis  [[0.02254262]
#  [0.97233003]
#  [0.9723059 ]
#  [0.04502404]]
# Theta1  [[-4.326143  -6.1720877]
#  [-4.32763   -6.182624 ]]
# Bias1  [6.388734  2.4218485]
# Theta2  [[ 8.604892]
#  [-9.25072 ]]
# Bias2  [-3.8634179]
# cost  0.03125362
# Epoch  94000
# Hypothesis  [[0.02198099]
#  [0.97311306]
#  [0.9730901 ]
#  [0.04366401]]
# Theta1  [[-4.348723  -6.1862316]
#  [-4.3501987 -6.196578 ]]
# Bias1  [6.4240546 2.4321804]
# Theta2  [[ 8.660029]
#  [-9.298763]]
# Bias2  [-3.8934815]
# cost  0.030351445
# Epoch  95000
# Hypothesis  [[0.02144758]
#  [0.9738598 ]
#  [0.97383785]
#  [0.04238458]]
# Theta1  [[-4.3705378 -6.200038 ]
#  [-4.371992  -6.2101917]]
# Bias1  [6.458289  2.4421587]
# Theta2  [[ 8.713792]
#  [-9.345707]]
# Bias2  [-3.9226968]
# cost  0.029497087
# Epoch  96000
# Hypothesis  [[0.02093566]
#  [0.97456455]
#  [0.9745429 ]
#  [0.0411703 ]]
# Theta1  [[-4.3917365 -6.2133894]
#  [-4.3931785 -6.223507 ]]
# Bias1  [6.4914722 2.4518352]
# Theta2  [[ 8.766043]
#  [-9.391583]]
# Bias2  [-3.9511247]
# cost  0.02868774
# Epoch  97000
# Hypothesis  [[0.02044865]
#  [0.97523415]
#  [0.9752134 ]
#  [0.04001848]]
# Theta1  [[-4.4123435 -6.2264237]
#  [-4.413768  -6.2363815]]
# Bias1  [6.5236526 2.461231 ]
# Theta2  [[ 8.817027]
#  [-9.436393]]
# Bias2  [-3.9787853]
# cost  0.02791962
# Epoch  98000
# Hypothesis  [[0.01998395]
#  [0.97587365]
#  [0.9758538 ]
#  [0.03892919]]
# Theta1  [[-4.4322996 -6.239208 ]
#  [-4.433704  -6.248967 ]]
# Bias1  [6.5548897 2.4703524]
# Theta2  [[ 8.866811]
#  [-9.480228]]
# Bias2  [-4.005727]
# cost  0.027189553
# Epoch  99000
# Hypothesis  [[0.01953627]
#  [0.9764795 ]
#  [0.9764598 ]
#  [0.03789272]]
# Theta1  [[-4.451708  -6.251606 ]
#  [-4.4531007 -6.261352 ]]
# Bias1  [6.5852237 2.4792054]
# Theta2  [[ 8.915253]
#  [-9.523141]]
# Bias2  [-4.031988]
# cost  0.026495539
# Elapsed time  54.374922

# %% [markdown]
# ## Model 2
#
# Substitute hyperbolic (tanh) activation function for the sigmoid activation in layer 2

# %%
x_ = tf.placeholder(tf.float32, shape=[4,2], name = 'x-input')
y_ = tf.placeholder(tf.float32, shape=[4,1], name = 'y-input')

Theta1 = tf.Variable(tf.random_uniform([2,2], -1, 1), name = "Theta1")
Theta2 = tf.Variable(tf.random_uniform([2,1], -1, 1), name = "Theta2")

Bias1 = tf.Variable(tf.zeros([2]), name = "Bias1")
Bias2 = tf.Variable(tf.zeros([1]), name = "Bias2")

with tf.name_scope("layer2") as scope:
	A2 = tf.tanh(tf.matmul(x_, Theta1) + Bias1)

with tf.name_scope("layer3") as scope:
	Hypothesis = tf.sigmoid(tf.matmul(A2, Theta2) + Bias2)

with tf.name_scope("cost") as scope:
	cost = tf.reduce_mean(( (y_ * tf.log(Hypothesis)) + 
		((1 - y_) * tf.log(1.0 - Hypothesis)) ) * -1)

with tf.name_scope("train") as scope:
	train_step = tf.train.GradientDescentOptimizer(0.01).minimize(cost)
  
XOR_X = [[0,0],[0,1],[1,0],[1,1]]
XOR_Y = [[0],[1],[1],[0]]

init = tf.global_variables_initializer()
sess = tf.Session()

#writer = tf.summary.FileWriter("./logs/xor_logs", sess.graph)

sess.run(init)
display_step = 1000

t_start = time.clock()
for i in range(100000):
	sess.run(train_step, feed_dict={x_: XOR_X, y_: XOR_Y})
	if i % display_step == 0:
		print('Epoch ', i)
		print('Hypothesis ', sess.run(Hypothesis, feed_dict={x_: XOR_X, y_: XOR_Y}))
		print('Theta1 ', sess.run(Theta1))
		print('Bias1 ', sess.run(Bias1))
		print('Theta2 ', sess.run(Theta2))
		print('Bias2 ', sess.run(Bias2))
		print('cost ', sess.run(cost, feed_dict={x_: XOR_X, y_: XOR_Y}))
t_end = time.clock()
print('Elapsed time ', t_end - t_start)

sess.close()
# Out:
# Epoch  0
# Hypothesis  [[0.49980992]
#  [0.41589496]
#  [0.6382813 ]
#  [0.58805686]]
# Theta1  [[ 0.94302815  0.3937673 ]
#  [-0.3073131   0.36079615]]
# Bias1  [-4.5324466e-04  1.3191513e-05]
# Theta2  [[ 0.8831058]
#  [-0.2190313]]
# Bias2  [-0.0003572]
# cost  0.72648394
# Epoch  1000
# Hypothesis  [[0.47225457]
#  [0.4371503 ]
#  [0.5478319 ]
#  [0.51673466]]
# Theta1  [[ 0.66299474  0.38065934]
#  [-0.15968814  0.26013136]]
# Bias1  [-0.18491289 -0.04502728]
# Theta2  [[ 0.6019857 ]
#  [-0.20283751]]
# Bias2  [-0.01015957]
# cost  0.6988989
# Epoch  2000
# Hypothesis  [[0.48339903]
#  [0.45600292]
#  [0.5335261 ]
#  [0.50557655]]
# Theta1  [[ 0.5468912   0.36666772]
#  [-0.16837347  0.18909024]]
# Bias1  [-0.26688185 -0.08920848]
# Theta2  [[ 0.502036  ]
#  [-0.18682891]]
# Bias2  [0.04784033]
# cost  0.6945877
# Epoch  3000
# Hypothesis  [[0.49143887]
#  [0.46089914]
#  [0.53046244]
#  [0.49418417]]
# Theta1  [[ 0.4888986   0.35863787]
#  [-0.26455644  0.13525271]]
# Bias1  [-0.3563244  -0.12337602]
# Theta2  [[ 0.46642473]
#  [-0.18297783]]
# Bias2  [0.10279547]
# cost  0.69158363
# Epoch  4000
# Hypothesis  [[0.49546313]
#  [0.45748955]
#  [0.5365672 ]
#  [0.48325846]]
# Theta1  [[ 0.49891177  0.35551482]
#  [-0.42004704  0.08887359]]
# Bias1  [-0.45969954 -0.1518151 ]
# Theta2  [[ 0.4914592 ]
#  [-0.18724011]]
# Bias2  [0.16489096]
# cost  0.6872229
# Epoch  5000
# Hypothesis  [[0.49317113]
#  [0.44450086]
#  [0.5557427 ]
#  [0.47002223]]
# Theta1  [[ 0.60449535  0.35928884]
#  [-0.6313034   0.04215566]]
# Bias1  [-0.5747699  -0.17765993]
# Theta2  [[ 0.5910416 ]
#  [-0.20538755]]
# Bias2  [0.24323702]
# cost  0.6781888
# Epoch  6000
# Hypothesis  [[0.48074165]
#  [0.4201434 ]
#  [0.59956956]
#  [0.44770724]]
# Theta1  [[ 0.8286798   0.37737373]
#  [-0.9189709  -0.01769599]]
# Bias1  [-0.7083875  -0.20417456]
# Theta2  [[ 0.7892539 ]
#  [-0.25457183]]
# Bias2  [0.3528421]
# cost  0.6569333
# Epoch  7000
# Hypothesis  [[0.45529652]
#  [0.39341593]
#  [0.67329156]
#  [0.41093698]]
# Theta1  [[ 1.1548189   0.43246004]
#  [-1.281618   -0.11412841]]
# Bias1  [-0.8752001  -0.22742715]
# Theta2  [[ 1.0868224]
#  [-0.3732873]]
# Bias2  [0.5023758]
# cost  0.61630017
# Epoch  8000
# Hypothesis  [[0.42266327]
#  [0.38861036]
#  [0.7445811 ]
#  [0.36247024]]
# Theta1  [[ 1.5131474   0.57512957]
#  [-1.6545702  -0.2747141 ]]
# Bias1  [-1.0624483  -0.20459083]
# Theta2  [[ 1.4274844 ]
#  [-0.61872864]]
# Bias2  [0.686159]
# cost  0.55989885
# Epoch  9000
# Hypothesis  [[0.3748638 ]
#  [0.4324419 ]
#  [0.7736512 ]
#  [0.29077065]]
# Theta1  [[ 1.8689775   0.8727198 ]
#  [-1.9809589  -0.55234265]]
# Bias1  [-1.2158762  -0.02672835]
# Theta2  [[ 1.762983 ]
#  [-1.0468365]]
# Bias2  [0.93876386]
# cost  0.4770759
# Epoch  10000
# Hypothesis  [[0.27187312]
#  [0.566182  ]
#  [0.78442043]
#  [0.2001103 ]]
# Theta1  [[ 2.203369   1.3176228]
#  [-2.2500136 -1.0375705]]
# Bias1  [-1.3014247   0.32339576]
# Theta2  [[ 2.0876153]
#  [-1.6588888]]
# Bias2  [1.333097]
# cost  0.3380528
# Epoch  11000
# Hypothesis  [[0.16985252]
#  [0.72052413]
#  [0.81762016]
#  [0.1307541 ]]
# Theta1  [[ 2.454122   1.7314792]
#  [-2.4606276 -1.5097483]]
# Bias1  [-1.3457156   0.62221307]
# Theta2  [[ 2.416966 ]
#  [-2.2474802]]
# Bias2  [1.7655389]
# cost  0.21385372
# Epoch  12000
# Hypothesis  [[0.11287863]
#  [0.81262434]
#  [0.8551896 ]
#  [0.09027687]]
# Theta1  [[ 2.6236746  2.0227122]
#  [-2.61926   -1.828751 ]]
# Bias1  [-1.3787372  0.8085289]
# Theta2  [[ 2.7240338]
#  [-2.677388 ]]
# Bias2  [2.1278794]
# cost  0.1445767
# Epoch  13000
# Hypothesis  [[0.081972  ]
#  [0.8632576 ]
#  [0.88454014]
#  [0.06695044]]
# Theta1  [[ 2.7428796  2.2249975]
#  [-2.7399771 -2.044619 ]]
# Bias1  [-1.4079933   0.92886657]
# Theta2  [[ 2.9862885]
#  [-2.9907362]]
# Bias2  [2.4166212]
# cost  0.10613847
# Epoch  14000
# Hypothesis  [[0.06349586]
#  [0.8936027 ]
#  [0.9057094 ]
#  [0.05247416]]
# Theta1  [[ 2.832232   2.373336 ]
#  [-2.834642  -2.2009323]]
# Bias1  [-1.4339093  1.0134052]
# Theta2  [[ 3.2061844]
#  [-3.2328453]]
# Bias2  [2.6503596]
# cost  0.08275829
# Epoch  15000
# Hypothesis  [[0.05144566]
#  [0.9134278 ]
#  [0.92104745]
#  [0.04282057]]
# Theta1  [[ 2.9027793  2.4878373]
#  [-2.911217  -2.3207674]]
# Bias1  [-1.4566813  1.0769151]
# Theta2  [[ 3.3922517]
#  [-3.4290977]]
# Bias2  [2.8444824]
# cost  0.067343816
# Epoch  16000
# Hypothesis  [[0.0430517 ]
#  [0.9272685 ]
#  [0.93244404]
#  [0.03600249]]
# Theta1  [[ 2.960648   2.5798266]
#  [-2.9748435 -2.4166248]]
# Bias1  [-1.4767237  1.1270142]
# Theta2  [[ 3.5521424]
#  [-3.5937493]]
# Bias2  [3.0095265]
# cost  0.056532696
# Epoch  17000
# Hypothesis  [[0.03690702]
#  [0.93742704]
#  [0.94115186]
#  [0.03096597]]
# Theta1  [[ 3.0094783  2.6560237]
#  [-3.0288954 -2.4957812]]
# Bias1  [-1.4944793  1.1679757]
# Theta2  [[ 3.6916611]
#  [-3.7354012]]
# Bias2  [3.1526103]
# cost  0.048582
# Epoch  18000
# Hypothesis  [[0.03223346]
#  [0.94517523]
#  [0.947978  ]
#  [0.0271112 ]]
# Theta1  [[ 3.0515754  2.7206528]
#  [-3.0756502 -2.562761 ]]
# Bias1  [-1.5103338  1.2023834]
# Theta2  [[ 3.8150685]
#  [-3.859594 ]]
# Bias2  [3.2786434]
# cost  0.042514697
# Epoch  19000
# Hypothesis  [[0.02856956]
#  [0.95126635]
#  [0.9534508 ]
#  [0.02407547]]
# Theta1  [[ 3.0884857  2.7765088]
#  [-3.1167002 -2.620535 ]]
# Bias1  [-1.524608   1.2318993]
# Theta2  [[ 3.9255035]
#  [-3.9700987]]
# Bias2  [3.3911142]
# cost  0.037746068
# Epoch  20000
# Hypothesis  [[0.02562618]
#  [0.9561729 ]
#  [0.9579237 ]
#  [0.02162835]]
# Theta1  [[ 3.1212823  2.8255165]
#  [-3.1531885 -2.671141 ]]
# Bias1  [-1.5375575  1.2576433]
# Theta2  [[ 4.0253143]
#  [-4.0695925]]
# Bias2  [3.4925697]
# cost  0.03390741
# Epoch  21000
# Hypothesis  [[0.02321368]
#  [0.96020496]
#  [0.9616409 ]
#  [0.01961731]]
# Theta1  [[ 3.1507523  2.8690526]
#  [-3.1859589 -2.7160306]]
# Bias1  [-1.549385   1.2804022]
# Theta2  [[ 4.1162896]
#  [-4.160039 ]]
# Bias2  [3.584918]
# cost  0.030755593
# Epoch  22000
# Hypothesis  [[0.02120264]
#  [0.9635742 ]
#  [0.964774  ]
#  [0.01793737]]
# Theta1  [[ 3.1774685  2.9081297]
#  [-3.2156477 -2.7562728]]
# Bias1  [-1.5602574  1.3007494]
# Theta2  [[ 4.1998143]
#  [-4.242928 ]]
# Bias2  [3.6696196]
# cost  0.028124504
# Epoch  23000
# Hypothesis  [[0.01950219]
#  [0.9664297 ]
#  [0.9674483 ]
#  [0.01651442]]
# Theta1  [[ 3.2018826  2.9435134]
#  [-3.2427495 -2.7926705]]
# Bias1  [-1.5703024  1.3191111]
# Theta2  [[ 4.276986 ]
#  [-4.3194118]]
# Bias2  [3.747819]
# cost  0.025896788
# Epoch  24000
# Hypothesis  [[0.01804659]
#  [0.9688789 ]
#  [0.9697556 ]
#  [0.01529461]]
# Theta1  [[ 3.2243433  2.975792 ]
#  [-3.267651  -2.8258364]]
# Bias1  [-1.5796343  1.3358132]
# Theta2  [[ 4.3486757]
#  [-4.3903966]]
# Bias2  [3.8204222]
# cost  0.023987763
# Epoch  25000
# Hypothesis  [[0.01678741]
#  [0.97100216]
#  [0.97176516]
#  [0.0142381 ]]
# Theta1  [[ 3.2451138  3.0054274]
#  [-3.2906582 -2.8562634]]
# Bias1  [-1.5883363  1.3511101]
# Theta2  [[ 4.4155946]
#  [-4.456611 ]]
# Bias2  [3.8881643]
# cost  0.022334514
# Epoch  26000
# Hypothesis  [[0.01568788]
#  [0.9728592 ]
#  [0.97353053]
#  [0.01331449]]
# Theta1  [[ 3.26443    3.0327947]
#  [-3.3120282 -2.8843315]]
# Bias1  [-1.5964842  1.3652046]
# Theta2  [[ 4.4783278]
#  [-4.518648 ]]
# Bias2  [3.9516435]
# cost  0.02088954
# Epoch  27000
# Hypothesis  [[0.01472011]
#  [0.9744975 ]
#  [0.97509253]
#  [0.01250088]]
# Theta1  [[ 3.2824676  3.0581865]
#  [-3.3319528 -2.9103572]]
# Bias1  [-1.6041441  1.3782586]
# Theta2  [[ 4.5373425]
#  [-4.5770025]]
# Bias2  [4.011362]
# cost  0.019616354
# Epoch  28000
# Hypothesis  [[0.01386161]
#  [0.9759522 ]
#  [0.9764841 ]
#  [0.01177855]]
# Theta1  [[ 3.2993786  3.0818539]
#  [-3.350613  -2.9345965]]
# Bias1  [-1.6113626  1.3904032]
# Theta2  [[ 4.593067]
#  [-4.632083]]
# Bias2  [4.067717]
# cost  0.018486368
# Epoch  29000
# Hypothesis  [[0.01309543]
#  [0.9772529 ]
#  [0.97773105]
#  [0.01113334]]
# Theta1  [[ 3.3152874  3.1040003]
#  [-3.3681507 -2.9572604]]
# Bias1  [-1.6181905  1.4017487]
# Theta2  [[ 4.645829]
#  [-4.684237]]
# Bias2  [4.121079]
# cost  0.017477036
# Epoch  30000
# Hypothesis  [[0.01240768]
#  [0.9784223 ]
#  [0.97885567]
#  [0.01055385]]
# Theta1  [[ 3.3303015  3.1247995]
#  [-3.3846807 -2.978535 ]]
# Bias1  [-1.6246612  1.4123908]
# Theta2  [[ 4.6959376]
#  [-4.733739 ]]
# Bias2  [4.171749]
# cost  0.016570048
# Epoch  31000
# Hypothesis  [[0.01178678]
#  [0.97947925]
#  [0.9798733 ]
#  [0.01003038]]
# Theta1  [[ 3.3445091  3.1443853]
#  [-3.4003048 -2.9985569]]
# Bias1  [-1.6308135  1.4224   ]
# Theta2  [[ 4.743624]
#  [-4.780872]]
# Bias2  [4.219965]
# cost  0.015751008
# Epoch  32000
# Hypothesis  [[0.011224  ]
#  [0.9804388 ]
#  [0.98079944]
#  [0.0095555 ]]
# Theta1  [[ 3.3579924  3.1628964]
#  [-3.4151232 -3.0174563]]
# Bias1  [-1.6366682  1.4318414]
# Theta2  [[ 4.7891183]
#  [-4.8258176]]
# Bias2  [4.265964]
# cost  0.015007818
# Epoch  33000
# Hypothesis  [[0.01071118]
#  [0.98131406]
#  [0.9816456 ]
#  [0.00912272]]
# Theta1  [[ 3.3708265  3.1804214]
#  [-3.4291952 -3.0353515]]
# Bias1  [-1.6422594  1.4407772]
# Theta2  [[ 4.832613 ]
#  [-4.8687963]]
# Bias2  [4.309934]
# cost  0.014330311
# Epoch  34000
# Hypothesis  [[0.01024212]
#  [0.98211575]
#  [0.9824212 ]
#  [0.00872668]]
# Theta1  [[ 3.3830378  3.1970565]
#  [-3.4425883 -3.052339 ]]
# Bias1  [-1.6476036  1.4492537]
# Theta2  [[ 4.8742824]
#  [-4.9099746]]
# Bias2  [4.3520603]
# cost  0.013710276
# Epoch  35000
# Hypothesis  [[0.00981175]
#  [0.98285186]
#  [0.98313475]
#  [0.008363  ]]
# Theta1  [[ 3.394711   3.212891 ]
#  [-3.4553812 -3.068483 ]]
# Bias1  [-1.6527228  1.4573091]
# Theta2  [[ 4.91424  ]
#  [-4.9494605]]
# Bias2  [4.3924494]
# cost  0.013141087
# Epoch  36000
# Hypothesis  [[0.00941532]
#  [0.98353094]
#  [0.98379356]
#  [0.00802799]]
# Theta1  [[ 3.4058788  3.2279868]
#  [-3.4675946 -3.0838742]]
# Bias1  [-1.657638   1.4649844]
# Theta2  [[ 4.9526496]
#  [-4.9874177]]
# Bias2  [4.431278]
# cost  0.012616423
# Epoch  37000
# Hypothesis  [[0.00904904]
#  [0.9841589 ]
#  [0.9844035 ]
#  [0.00771829]]
# Theta1  [[ 3.4165795  3.2424066]
#  [-3.4792957 -3.0985725]]
# Bias1  [-1.6623521  1.4723089]
# Theta2  [[ 4.989618 ]
#  [-5.0239563]]
# Bias2  [4.468645]
# cost  0.012131452
# Epoch  38000
# Hypothesis  [[0.00870938]
#  [0.9847414 ]
#  [0.98496985]
#  [0.00743099]]
# Theta1  [[ 3.4268563  3.25621  ]
#  [-3.490519  -3.1126301]]
# Bias1  [-1.6668966  1.4793171]
# Theta2  [[ 5.0252585]
#  [-5.0591874]]
# Bias2  [4.50466]
# cost  0.011681675
# Epoch  39000
# Hypothesis  [[0.00839448]
#  [0.98528314]
#  [0.9854974 ]
#  [0.00716452]]
# Theta1  [[ 3.4367383  3.2694335]
#  [-3.5013044 -3.1260955]]
# Bias1  [-1.6712645  1.4860191]
# Theta2  [[ 5.059629]
#  [-5.093151]]
# Bias2  [4.539424]
# cost  0.011263812
# Epoch  40000
# Hypothesis  [[0.00810044]
#  [0.98578763]
#  [0.98598933]
#  [0.00691559]]
# Theta1  [[ 3.4462328  3.2821229]
#  [-3.5116727 -3.1390102]]
# Bias1  [-1.6754853  1.4924533]
# Theta2  [[ 5.092871 ]
#  [-5.1259966]]
# Bias2  [4.572992]
# cost  0.010874276
# Epoch  41000
# Hypothesis  [[0.00782616]
#  [0.9862598 ]
#  [0.9864488 ]
#  [0.00668339]]
# Theta1  [[ 3.4553978  3.2943232]
#  [-3.521649  -3.1514223]]
# Bias1  [-1.6795641  1.4986343]
# Theta2  [[ 5.124985 ]
#  [-5.1577764]]
# Bias2  [4.6054626]
# cost  0.010510515
# Epoch  42000
# Hypothesis  [[0.00756954]
#  [0.9867019 ]
#  [0.98687994]
#  [0.00646604]]
# Theta1  [[ 3.4642484  3.3060691]
#  [-3.531284  -3.163366 ]]
# Bias1  [-1.6835053  1.5045792]
# Theta2  [[ 5.156093 ]
#  [-5.1885414]]
# Bias2  [4.6369095]
# cost  0.010169891
# Epoch  43000
# Hypothesis  [[0.00732898]
#  [0.9871164 ]
#  [0.98728484]
#  [0.00626221]]
# Theta1  [[ 3.4727728  3.3173869]
#  [-3.5405755 -3.1748788]]
# Bias1  [-1.6873134  1.5103049]
# Theta2  [[ 5.1862516]
#  [-5.21835  ]]
# Bias2  [4.667388]
# cost  0.009850464
# Epoch  44000
# Hypothesis  [[0.00710292]
#  [0.9875058 ]
#  [0.98766613]
#  [0.00607068]]
# Theta1  [[ 3.4810255  3.3282895]
#  [-3.549547  -3.1859696]]
# Bias1  [-1.6910052  1.5158314]
# Theta2  [[ 5.215522]
#  [-5.247262]]
# Bias2  [4.6969576]
# cost  0.009550227
# Epoch  45000
# Hypothesis  [[0.00689048]
#  [0.9878734 ]
#  [0.9880251 ]
#  [0.00589049]]
# Theta1  [[ 3.4890158  3.3388472]
#  [-3.558236  -3.1966753]]
# Bias1  [-1.6945815  1.5211505]
# Theta2  [[ 5.243912 ]
#  [-5.2753468]]
# Bias2  [4.7256846]
# cost  0.009267533
# Epoch  46000
# Hypothesis  [[0.00668973]
#  [0.9882202 ]
#  [0.98836356]
#  [0.00572034]]
# Theta1  [[ 3.4967575  3.3490195]
#  [-3.566652  -3.2070317]]
# Bias1  [-1.698046   1.5263076]
# Theta2  [[ 5.271506 ]
#  [-5.3026795]]
# Bias2  [4.7535825]
# cost  0.009000833
# Epoch  47000
# Hypothesis  [[0.0065003 ]
#  [0.98854685]
#  [0.9886846 ]
#  [0.00555961]]
# Theta1  [[ 3.504265   3.3588877]
#  [-3.574807  -3.2170453]]
# Bias1  [-1.7014109  1.5312791]
# Theta2  [[ 5.2983856]
#  [-5.3292027]]
# Bias2  [4.780708]
# cost  0.008748953
# Epoch  48000
# Hypothesis  [[0.00632119]
#  [0.9888576 ]
#  [0.9889874 ]
#  [0.00540761]]
# Theta1  [[ 3.5115523  3.368446 ]
#  [-3.5827124 -3.226732 ]]
# Bias1  [-1.7046872  1.536102 ]
# Theta2  [[ 5.3244824]
#  [-5.35509  ]]
# Bias2  [4.807136]
# cost  0.008510544
# Epoch  49000
# Hypothesis  [[0.00615147]
#  [0.98915064]
#  [0.9892757 ]
#  [0.00526371]]
# Theta1  [[ 3.5186374  3.377691 ]
#  [-3.590382  -3.2361324]]
# Bias1  [-1.707884   1.5407798]
# Theta2  [[ 5.3499494]
#  [-5.380229 ]]
# Bias2  [4.832853]
# cost  0.008284737
# Epoch  50000
# Hypothesis  [[0.0059904 ]
#  [0.9894294 ]
#  [0.98954904]
#  [0.00512711]]
# Theta1  [[ 3.525536   3.3866675]
#  [-3.59783   -3.2452548]]
# Bias1  [-1.7109834  1.5453082]
# Theta2  [[ 5.3747597]
#  [-5.4047728]]
# Bias2  [4.857915]
# cost  0.008070381
# Epoch  51000
# Hypothesis  [[0.00583768]
#  [0.9896952 ]
#  [0.9898085 ]
#  [0.00499745]]
# Theta1  [[ 3.5322118  3.3953855]
#  [-3.6050723 -3.2541087]]
# Bias1  [-1.7139907  1.5497009]
# Theta2  [[ 5.398927 ]
#  [-5.4287353]]
# Bias2  [4.882389]
# cost  0.007866701
# Epoch  52000
# Hypothesis  [[0.00569233]
#  [0.9899475 ]
#  [0.9900558 ]
#  [0.004874  ]]
# Theta1  [[ 3.5387065  3.403857 ]
#  [-3.6121256 -3.2627046]]
# Bias1  [-1.7169428  1.5539702]
# Theta2  [[ 5.4225316]
#  [-5.4520926]]
# Bias2  [4.9062653]
# cost  0.0076729544
# Epoch  53000
# Hypothesis  [[0.00555381]
#  [0.99018717]
#  [0.99029166]
#  [0.0047563 ]]
# Theta1  [[ 3.5450592  3.4120948]
#  [-3.6190107 -3.2710552]]
# Bias1  [-1.7198038  1.558123 ]
# Theta2  [[ 5.4455895]
#  [-5.4748855]]
# Bias2  [4.9295416]
# cost  0.007488503
# Epoch  54000
# Hypothesis  [[0.00542176]
#  [0.99041593]
#  [0.9905166 ]
#  [0.00464418]]
# Theta1  [[ 3.551258   3.4201121]
#  [-3.6256864 -3.279174 ]]
# Bias1  [-1.722598   1.5621635]
# Theta2  [[ 5.468118 ]
#  [-5.4971633]]
# Bias2  [4.9522934]
# cost  0.007312606
# Epoch  55000
# Hypothesis  [[0.00529572]
#  [0.99063444]
#  [0.9907313 ]
#  [0.004537  ]]
# Theta1  [[ 3.557254   3.4279237]
#  [-3.632185  -3.2870743]]
# Bias1  [-1.7253398  1.5660974]
# Theta2  [[ 5.490135]
#  [-5.518945]]
# Bias2  [4.974538]
# cost  0.007144672
# Epoch  56000
# Hypothesis  [[0.0051755 ]
#  [0.99084353]
#  [0.9909368 ]
#  [0.00443475]]
# Theta1  [[ 3.5631616  3.4355454]
#  [-3.6385586 -3.294769 ]]
# Bias1  [-1.7279929  1.5699133]
# Theta2  [[ 5.5116596]
#  [-5.5402527]]
# Bias2  [4.9962945]
# cost  0.0069841715
# Epoch  57000
# Hypothesis  [[0.00506046]
#  [0.9910437 ]
#  [0.99113303]
#  [0.00433698]]
# Theta1  [[ 3.5688837  3.4429364]
#  [-3.6447575 -3.3022735]]
# Bias1  [-1.7306155  1.5736332]
# Theta2  [[ 5.532712 ]
#  [-5.5611067]]
# Bias2  [5.017585]
# cost  0.00683071
# Epoch  58000
# Hypothesis  [[0.00495043]
#  [0.9912356 ]
#  [0.99132127]
#  [0.00424356]]
# Theta1  [[ 3.5744934  3.4501472]
#  [-3.6507928 -3.3096056]]
# Bias1  [-1.7331456  1.577268 ]
# Theta2  [[ 5.553314]
#  [-5.581531]]
# Bias2  [5.03843]
# cost  0.0066837287
# Epoch  59000
# Hypothesis  [[0.00484485]
#  [0.9914197 ]
#  [0.99150145]
#  [0.0041537 ]]
# Theta1  [[ 3.579977   3.4572055]
#  [-3.6567533 -3.3167582]]
# Bias1  [-1.735649   1.5808275]
# Theta2  [[ 5.5734916]
#  [-5.6015506]]
# Bias2  [5.0588574]
# cost  0.0065428037
# Epoch  60000
# Hypothesis  [[0.00474405]
#  [0.9915957 ]
#  [0.99167526]
#  [0.00406793]]
# Theta1  [[ 3.585326   3.4641197]
#  [-3.6624808 -3.3237016]]
# Bias1  [-1.7380819  1.5842845]
# Theta2  [[ 5.593268]
#  [-5.621101]]
# Bias2  [5.0788846]
# cost  0.0064077526
# Epoch  61000
# Hypothesis  [[0.00464687]
#  [0.9917641 ]
#  [0.9918417 ]
#  [0.0039853 ]]
# Theta1  [[ 3.5905712  3.4708083]
#  [-3.6681714 -3.3305163]]
# Bias1  [-1.7404661  1.5876554]
# Theta2  [[ 5.6126714]
#  [-5.640267 ]]
# Bias2  [5.0984397]
# cost  0.0062781847
# Epoch  62000
# Hypothesis  [[0.00455323]
#  [0.991926  ]
#  [0.99200165]
#  [0.00390578]]
# Theta1  [[ 3.5956993  3.4773881]
#  [-3.673655  -3.337192 ]]
# Bias1  [-1.742821   1.5909684]
# Theta2  [[ 5.63173 ]
#  [-5.659085]]
# Bias2  [5.117627]
# cost  0.00615357
# Epoch  63000
# Hypothesis  [[0.00446378]
#  [0.99208283]
#  [0.9921549 ]
#  [0.00382941]]
# Theta1  [[ 3.600706   3.4838254]
#  [-3.6791065 -3.3436604]]
# Bias1  [-1.745086  1.594187]
# Theta2  [[ 5.6503267]
#  [-5.6775856]]
# Bias2  [5.1364765]
# cost  0.0060338164
# Epoch  64000
# Hypothesis  [[0.00437785]
#  [0.9922339 ]
#  [0.99230313]
#  [0.00375659]]
# Theta1  [[ 3.6056533  3.4900844]
#  [-3.6843517 -3.3500443]]
# Bias1  [-1.7473509  1.5973386]
# Theta2  [[ 5.6685953]
#  [-5.6957054]]
# Bias2  [5.1550193]
# cost  0.005918548
# Epoch  65000
# Hypothesis  [[0.00429477]
#  [0.99237764]
#  [0.9924459 ]
#  [0.00368548]]
# Theta1  [[ 3.6104217  3.4962833]
#  [-3.689597  -3.3562431]]
# Bias1  [-1.7495369  1.600438 ]
# Theta2  [[ 5.6865854]
#  [-5.713446 ]]
# Bias2  [5.173139]
# cost  0.0058076587
# Epoch  66000
# Hypothesis  [[0.00421464]
#  [0.99251723]
#  [0.99258316]
#  [0.00361762]]
# Theta1  [[ 3.61519    3.502251 ]
#  [-3.6946132 -3.362337 ]]
# Bias1  [-1.7516826  1.6034471]
# Theta2  [[ 5.7042284]
#  [-5.7309413]]
# Bias2  [5.190936]
# cost  0.005700786
# Epoch  67000
# Hypothesis  [[0.00413781]
#  [0.9926524 ]
#  [0.9927154 ]
#  [0.00355196]]
# Theta1  [[ 3.6197753  3.508198 ]
#  [-3.69962   -3.3682976]]
# Bias1  [-1.7538284  1.6064273]
# Theta2  [[ 5.7215004]
#  [-5.7481074]]
# Bias2  [5.2084994]
# cost  0.005597659
# Epoch  68000
# Hypothesis  [[0.00406346]
#  [0.99278146]
#  [0.9928438 ]
#  [0.00348876]]
# Theta1  [[ 3.6243052  3.51392  ]
#  [-3.7044866 -3.374136 ]]
# Bias1  [-1.7558786  1.6093024]
# Theta2  [[ 5.7385707]
#  [-5.7649174]]
# Bias2  [5.2256656]
# cost  0.0054983217
# Epoch  69000
# Hypothesis  [[0.00399145]
#  [0.9929074 ]
#  [0.9929668 ]
#  [0.00342748]]
# Theta1  [[ 3.6288307  3.519642 ]
#  [-3.709255  -3.379858 ]]
# Bias1  [-1.7579051  1.6121634]
# Theta2  [[ 5.75526  ]
#  [-5.7815676]]
# Bias2  [5.2425566]
# cost  0.005402188
# Epoch  70000
# Hypothesis  [[0.00392277]
#  [0.9930286 ]
#  [0.99308676]
#  [0.00336885]]
# Theta1  [[ 3.6331222  3.5251272]
#  [-3.7140234 -3.3854752]]
# Bias1  [-1.7599317  1.6149224]
# Theta2  [[ 5.7716956]
#  [-5.79778  ]]
# Bias2  [5.259246]
# cost  0.005309525
# Epoch  71000
# Hypothesis  [[0.0038552 ]
#  [0.99314487]
#  [0.9932018 ]
#  [0.0033113 ]]
# Theta1  [[ 3.6374137  3.5306108]
#  [-3.7185597 -3.3909588]]
# Bias1  [-1.761893   1.6176642]
# Theta2  [[ 5.787908]
#  [-5.813834]]
# Bias2  [5.2755113]
# cost  0.0052199014
# Epoch  72000
# Hypothesis  [[0.00379118]
#  [0.9932592 ]
#  [0.9933141 ]
#  [0.00325703]]
# Theta1  [[ 3.6417022  3.535913 ]
#  [-3.7230897 -3.396389 ]]
# Bias1  [-1.7638004  1.6203291]
# Theta2  [[ 5.803754]
#  [-5.82957 ]]
# Bias2  [5.291671]
# cost  0.005133191
# Epoch  73000
# Hypothesis  [[0.00372791]
#  [0.9933674 ]
#  [0.99342173]
#  [0.00320273]]
# Theta1  [[ 3.6457553  3.5411582]
#  [-3.7275944 -3.4016342]]
# Bias1  [-1.7657077  1.6229517]
# Theta2  [[ 5.8194895]
#  [-5.845085 ]]
# Bias2  [5.3074064]
# cost  0.0050493684
# Epoch  74000
# Hypothesis  [[0.00366772]
#  [0.99347466]
#  [0.9935261 ]
#  [0.00315162]]
# Theta1  [[ 3.6498084  3.5463264]
#  [-3.731886  -3.4068794]]
# Bias1  [-1.7676151  1.6255546]
# Theta2  [[ 5.8347993]
#  [-5.860344 ]]
# Bias2  [5.3230457]
# cost  0.0049681733
# Epoch  75000
# Hypothesis  [[0.0036086 ]
#  [0.99357635]
#  [0.993628  ]
#  [0.0031013 ]]
# Theta1  [[ 3.6538615  3.5513332]
#  [-3.7361774 -3.4119387]]
# Bias1  [-1.7694163  1.628058 ]
# Theta2  [[ 5.850058 ]
#  [-5.8753724]]
# Bias2  [5.3383045]
# cost  0.0048894887
# Epoch  76000
# Hypothesis  [[0.00355237]
#  [0.99367684]
#  [0.9937262 ]
#  [0.0030531 ]]
# Theta1  [[ 3.6577668  3.55634  ]
#  [-3.740469  -3.4169455]]
# Bias1  [-1.7712045  1.6305614]
# Theta2  [[ 5.8648896]
#  [-5.8901544]]
# Bias2  [5.3534713]
# cost  0.004813326
# Epoch  77000
# Hypothesis  [[0.00349659]
#  [0.9937729 ]
#  [0.9938211 ]
#  [0.00300574]]
# Theta1  [[ 3.6615815  3.5611856]
#  [-3.7445424 -3.421926 ]]
# Bias1  [-1.7729926  1.6329949]
# Theta2  [[ 5.8796716]
#  [-5.9047594]]
# Bias2  [5.368253]
# cost  0.0047394033
# Epoch  78000
# Hypothesis  [[0.00344389]
#  [0.9938672 ]
#  [0.99391407]
#  [0.00296079]]
# Theta1  [[ 3.6653962  3.565954 ]
#  [-3.7485955 -3.4266944]]
# Bias1  [-1.7747808  1.6353791]
# Theta2  [[ 5.894086 ]
#  [-5.9190645]]
# Bias2  [5.383015]
# cost  0.0046678064
# Epoch  79000
# Hypothesis  [[0.00339114]
#  [0.99395776]
#  [0.994003  ]
#  [0.00291576]]
# Theta1  [[ 3.669211   3.5707223]
#  [-3.7526486 -3.4314628]]
# Bias1  [-1.7764796  1.6377633]
# Theta2  [[ 5.908391 ]
#  [-5.9333158]]
# Bias2  [5.3973203]
# cost  0.004598134
# Epoch  80000
# Hypothesis  [[0.00334157]
#  [0.9940462 ]
#  [0.9940912 ]
#  [0.00287353]]
# Theta1  [[ 3.6728377  3.5753067]
#  [-3.7566144 -3.436182 ]]
# Bias1  [-1.7781485  1.6400579]
# Theta2  [[ 5.922455]
#  [-5.947144]]
# Bias2  [5.4116254]
# cost  0.004530681
# Epoch  81000
# Hypothesis  [[0.00329234]
#  [0.994132  ]
#  [0.9941748 ]
#  [0.00283147]]
# Theta1  [[ 3.676414   3.5798366]
#  [-3.7604291 -3.440712 ]]
# Bias1  [-1.7798175  1.6423229]
# Theta2  [[ 5.936283 ]
#  [-5.9609723]]
# Bias2  [5.4255705]
# cost  0.0044651963
# Epoch  82000
# Hypothesis  [[0.00324456]
#  [0.99421436]
#  [0.99425805]
#  [0.00279068]]
# Theta1  [[ 3.6799903  3.5843666]
#  [-3.7642438 -3.445242 ]]
# Bias1  [-1.7814864  1.6445879]
# Theta2  [[ 5.9500732]
#  [-5.974467 ]]
# Bias2  [5.439399]
# cost  0.0044013476
# Epoch  83000
# Hypothesis  [[0.00319892]
#  [0.9942966 ]
#  [0.99433786]
#  [0.00275194]]
# Theta1  [[ 3.6835666  3.5887628]
#  [-3.7680585 -3.4497674]]
# Bias1  [-1.7831528  1.6467941]
# Theta2  [[ 5.9634247]
#  [-5.9878182]]
# Bias2  [5.453087]
# cost  0.004339435
# Epoch  84000
# Hypothesis  [[0.00315341]
#  [0.994375  ]
#  [0.9944149 ]
#  [0.00271297]]
# Theta1  [[ 3.6870296  3.5930543]
#  [-3.771782  -3.454059 ]]
# Bias1  [-1.7847025  1.6489398]
# Theta2  [[ 5.976776]
#  [-6.001117]]
# Bias2  [5.4664383]
# cost  0.004279159
# Epoch  85000
# Hypothesis  [[0.00311042]
#  [0.99445134]
#  [0.9944918 ]
#  [0.00267623]]
# Theta1  [[ 3.6903675  3.5973458]
#  [-3.7753582 -3.4583504]]
# Bias1  [-1.7862523  1.6510856]
# Theta2  [[ 5.9899006]
#  [-6.013992 ]]
# Bias2  [5.4797897]
# cost  0.0042206524
# Epoch  86000
# Hypothesis  [[0.00306777]
#  [0.9945263 ]
#  [0.99456465]
#  [0.00263978]]
# Theta1  [[ 3.6937053  3.6016328]
#  [-3.7789345 -3.462642 ]]
# Bias1  [-1.787802   1.6532313]
# Theta2  [[ 6.002775 ]
#  [-6.0268664]]
# Bias2  [5.4928246]
# cost  0.0041636624
# Epoch  87000
# Hypothesis  [[0.00302594]
#  [0.9945986 ]
#  [0.9946365 ]
#  [0.00260421]]
# Theta1  [[ 3.6970432  3.605686 ]
#  [-3.7825108 -3.4668248]]
# Bias1  [-1.7893517  1.6552579]
# Theta2  [[ 6.01565  ]
#  [-6.0395837]]
# Bias2  [5.505699]
# cost  0.0041080234
# Epoch  88000
# Hypothesis  [[0.00298647]
#  [0.99466974]
#  [0.99470747]
#  [0.00257045]]
# Theta1  [[ 3.700381  3.609739]
#  [-3.786087 -3.470878]]
# Bias1  [-1.7909014  1.6572845]
# Theta2  [[ 6.0282025]
#  [-6.0519814]]
# Bias2  [5.5185738]
# cost  0.0040539578
# Epoch  89000
# Hypothesis  [[0.00294688]
#  [0.99473864]
#  [0.9947745 ]
#  [0.00253668]]
# Theta1  [[ 3.7035782  3.6137922]
#  [-3.7894554 -3.474931 ]]
# Bias1  [-1.7923857  1.659311 ]
# Theta2  [[ 6.0406003]
#  [-6.064379 ]]
# Bias2  [5.5310507]
# cost  0.0040013934
# Epoch  90000
# Hypothesis  [[0.00290817]
#  [0.9948054 ]
#  [0.9948409 ]
#  [0.00250356]]
# Theta1  [[ 3.7066777  3.6178253]
#  [-3.7927933 -3.478984 ]]
# Bias1  [-1.7938162  1.661317 ]
# Theta2  [[ 6.052998]
#  [-6.07662 ]]
# Bias2  [5.5434484]
# cost  0.0039499244
# Epoch  91000
# Hypothesis  [[0.00287187]
#  [0.9948715 ]
#  [0.9949066 ]
#  [0.00247267]]
# Theta1  [[ 3.709777   3.62164  ]
#  [-3.7961311 -3.4829192]]
# Bias1  [-1.7952467  1.6632243]
# Theta2  [[ 6.0650835]
#  [-6.088541 ]]
# Bias2  [5.555846]
# cost  0.0038999687
# Epoch  92000
# Hypothesis  [[0.00283541]
#  [0.9949352 ]
#  [0.99496895]
#  [0.00244143]]
# Theta1  [[ 3.7128766  3.6254547]
#  [-3.799469  -3.486734 ]]
# Bias1  [-1.7966772  1.6651317]
# Theta2  [[ 6.0770044]
#  [-6.100462 ]]
# Bias2  [5.567868]
# cost  0.0038513036
# Epoch  93000
# Hypothesis  [[0.00279922]
#  [0.9949974 ]
#  [0.99503005]
#  [0.00241044]]
# Theta1  [[ 3.715976   3.6292694]
#  [-3.8028069 -3.4905486]]
# Bias1  [-1.7981077  1.667039 ]
# Theta2  [[ 6.0889254]
#  [-6.112345 ]]
# Bias2  [5.579789]
# cost  0.0038034946
# Epoch  94000
# Hypothesis  [[0.00276511]
#  [0.9950578 ]
#  [0.9950917 ]
#  [0.00238148]]
# Theta1  [[ 3.7190754  3.633084 ]
#  [-3.8059616 -3.4943633]]
# Bias1  [-1.7995383  1.6689464]
# Theta2  [[ 6.1006556]
#  [-6.1237893]]
# Bias2  [5.59171]
# cost  0.0037570335
# Epoch  95000
# Hypothesis  [[0.00273175]
#  [0.9951179 ]
#  [0.9951498 ]
#  [0.0023531 ]]
# Theta1  [[ 3.7219474  3.636747 ]
#  [-3.809061  -3.4981527]]
# Bias1  [-1.8009369  1.6707739]
# Theta2  [[ 6.1120996]
#  [-6.1352334]]
# Bias2  [5.6034017]
# cost  0.0037118464
# Epoch  96000
# Hypothesis  [[0.00269836]
#  [0.9951756 ]
#  [0.99520606]
#  [0.00232444]]
# Theta1  [[ 3.7248085  3.6403232]
#  [-3.8121605 -3.501729 ]]
# Bias1  [-1.8022482  1.672562 ]
# Theta2  [[ 6.1235437]
#  [-6.1466775]]
# Bias2  [5.6148458]
# cost  0.0036676803
# Epoch  97000
# Hypothesis  [[0.00266603]
#  [0.99523145]
#  [0.995263  ]
#  [0.00229672]]
# Theta1  [[ 3.7276695  3.6438994]
#  [-3.81526   -3.5053053]]
# Bias1  [-1.8035595  1.6743501]
# Theta2  [[ 6.134988 ]
#  [-6.1578555]]
# Bias2  [5.62629]
# cost  0.0036243086
# Epoch  98000
# Hypothesis  [[0.00263561]
#  [0.99528754]
#  [0.9953185 ]
#  [0.00227064]]
# Theta1  [[ 3.7305305  3.6474757]
#  [-3.8183594 -3.5088816]]
# Bias1  [-1.8048708  1.6761383]
# Theta2  [[ 6.146026]
#  [-6.168823]]
# Bias2  [5.637734]
# cost  0.003582105
# Epoch  99000
# Hypothesis  [[0.00260459]
#  [0.9953414 ]
#  [0.9953709 ]
#  [0.00224406]]
# Theta1  [[ 3.7333915  3.651052 ]
#  [-3.8214588 -3.5124578]]
# Bias1  [-1.8061821  1.6779264]
# Theta2  [[ 6.1569934]
#  [-6.17979  ]]
# Bias2  [5.6487484]
# cost  0.0035409667
# Elapsed time  56.34534500000001

# %% [markdown]
# ## Model 3
#
# *   Substitute Adam Optimizer for the Gradient Optimizer training algorithm
# *   Keep the thanh activation for layer 2

# %%
x_ = tf.placeholder(tf.float32, shape=[4,2], name = 'x-input')
y_ = tf.placeholder(tf.float32, shape=[4,1], name = 'y-input')

Theta1 = tf.Variable(tf.random_uniform([2,2], -1, 1), name = "Theta1")
Theta2 = tf.Variable(tf.random_uniform([2,1], -1, 1), name = "Theta2")

Bias1 = tf.Variable(tf.zeros([2]), name = "Bias1")
Bias2 = tf.Variable(tf.zeros([1]), name = "Bias2")

with tf.name_scope("layer2") as scope:
	A2 = tf.tanh(tf.matmul(x_, Theta1) + Bias1)

with tf.name_scope("layer3") as scope:
	Hypothesis = tf.sigmoid(tf.matmul(A2, Theta2) + Bias2)

with tf.name_scope("cost") as scope:
	cost = tf.reduce_mean(( (y_ * tf.log(Hypothesis)) + 
		((1 - y_) * tf.log(1.0 - Hypothesis)) ) * -1)

with tf.name_scope("train") as scope:
	train_step = tf.train.AdamOptimizer(0.01).minimize(cost)
  
XOR_X = [[0,0],[0,1],[1,0],[1,1]]
XOR_Y = [[0],[1],[1],[0]]

init = tf.global_variables_initializer()
sess = tf.Session()

#writer = tf.summary.FileWriter("./logs/xor_logs", sess.graph)

sess.run(init)

display_step = 1000

t_start = time.clock()
for i in range(100000):
	sess.run(train_step, feed_dict={x_: XOR_X, y_: XOR_Y})
	if i % display_step == 0:
		print('Epoch ', i)
		print('Hypothesis ', sess.run(Hypothesis, feed_dict={x_: XOR_X, y_: XOR_Y}))
		print('Theta1 ', sess.run(Theta1))
		print('Bias1 ', sess.run(Bias1))
		print('Theta2 ', sess.run(Theta2))
		print('Bias2 ', sess.run(Bias2))
		print('cost ', sess.run(cost, feed_dict={x_: XOR_X, y_: XOR_Y}))
t_end = time.clock()
print('Elapsed time ', t_end - t_start)

sess.close()
# Out:
# Epoch  0
# Hypothesis  [[0.50373226]
#  [0.45887563]
#  [0.48469004]
#  [0.44167027]]
# Theta1  [[ 0.18327537 -0.238877  ]
#  [-0.8056455  -0.2988128 ]]
# Bias1  [0.00998853 0.00999981]
# Theta2  [[0.0953771]
#  [0.3976919]]
# Bias2  [0.00999991]
# cost  0.6966668
# Epoch  1000
# Hypothesis  [[0.00682797]
#  [0.99053276]
#  [0.9888236 ]
#  [0.00582612]]
# Theta1  [[ 3.7825935 -3.6295285]
#  [-4.3004665  3.6410449]]
# Bias1  [-1.8229561 -1.8795941]
# Theta2  [[5.077916 ]
#  [5.2123914]]
# Bias2  [4.814736]
# cost  0.008361549
# Epoch  2000
# Hypothesis  [[0.00196473]
#  [0.99723107]
#  [0.9967134 ]
#  [0.0017097 ]]
# Theta1  [[ 4.1762304 -4.0484457]
#  [-4.695686   4.0510354]]
# Bias1  [-2.0155435 -2.0797272]
# Theta2  [[6.262021 ]
#  [6.3874755]]
# Bias2  [6.0041466]
# cost  0.0024356577
# Epoch  3000
# Hypothesis  [[8.6080591e-04]
#  [9.9877709e-01]
#  [9.9854529e-01]
#  [7.5722224e-04]]
# Theta1  [[ 4.4033737 -4.2869887]
#  [-4.9247766  4.2841187]]
# Bias1  [-2.1271012 -2.1938312]
# Theta2  [[7.0545974]
#  [7.176002 ]]
# Bias2  [6.800011]
# cost  0.0010745281
# Epoch  4000
# Hypothesis  [[4.4034488e-04]
#  [9.9937099e-01]
#  [9.9925083e-01]
#  [3.9035856e-04]]
# Theta1  [[ 4.5719934 -4.462922 ]
#  [-5.095194   4.456    ]]
# Bias1  [-2.2100642 -2.2781212]
# Theta2  [[7.702295]
#  [7.821095]]
# Bias2  [7.4501653]
# cost  0.0005523851
# Epoch  5000
# Hypothesis  [[2.4262462e-04]
#  [9.9965203e-01]
#  [9.9958509e-01]
#  [2.1641339e-04]]
# Theta1  [[ 4.711672  -4.6080403]
#  [-5.2365375  4.5977945]]
# Bias1  [-2.2788603 -2.3477404]
# Theta2  [[8.280715]
#  [8.397569]]
# Bias2  [8.030614]
# cost  0.00030553856
# Epoch  6000
# Hypothesis  [[1.3909985e-04]
#  [9.9979979e-01]
#  [9.9976116e-01]
#  [1.2472481e-04]]
# Theta1  [[ 4.834349  -4.7350883]
#  [-5.3607774  4.721968 ]]
# Bias1  [-2.3393474 -2.4087832]
# Theta2  [[8.822361]
#  [8.937634]]
# Bias2  [8.573997]
# cost  0.0001757459
# Epoch  7000
# Hypothesis  [[8.1568702e-05]
#  [9.9988222e-01]
#  [9.9985945e-01]
#  [7.3478019e-05]]
# Theta1  [[ 4.945819  -4.850234 ]
#  [-5.4737267  4.8345604]]
# Bias1  [-2.3943229 -2.4641447]
# Theta2  [[9.343488]
#  [9.457447]]
# Bias2  [9.096753]
# cost  0.000103345265
# Epoch  8000
# Hypothesis  [[4.8460577e-05]
#  [9.9992990e-01]
#  [9.9991620e-01]
#  [4.3836084e-05]]
# Theta1  [[ 5.049205  -4.956811 ]
#  [-5.5785327  4.9388056]]
# Bias1  [-2.4453847 -2.5154793]
# Theta2  [[9.852963]
#  [9.965743]]
# Bias2  [9.607639]
# cost  6.1543826e-05
# Epoch  9000
# Hypothesis  [[2.9017590e-05]
#  [9.9995792e-01]
#  [9.9994969e-01]
#  [2.6348467e-05]]
# Theta1  [[ 5.146346  -5.0567718]
#  [-5.677031   5.036616 ]]
# Bias1  [-2.4933693 -2.5636504]
# Theta2  [[10.355707]
#  [10.467461]]
# Bias2  [10.111667]
# cost  3.694071e-05
# Epoch  10000
# Hypothesis  [[1.7458317e-05]
#  [9.9997461e-01]
#  [9.9996972e-01]
#  [1.5908105e-05]]
# Theta1  [[ 5.2383924 -5.151337 ]
#  [-5.7703757  5.129188 ]]
# Bias1  [-2.5388618 -2.6092844]
# Theta2  [[10.854643 ]
#  [10.9654455]]
# Bias2  [10.6117935]
# cost  2.22626e-05
# Epoch  11000
# Hypothesis  [[1.0534323e-05]
#  [9.9998462e-01]
#  [9.9998164e-01]
#  [9.6301519e-06]]
# Theta1  [[ 5.326107  -5.241326 ]
#  [-5.8593354  5.217314 ]]
# Bias1  [-2.5822096 -2.6527395]
# Theta2  [[11.351456]
#  [11.461405]]
# Bias2  [11.109724]
# cost  1.3485648e-05
# Epoch  12000
# Hypothesis  [[6.3678335e-06]
#  [9.9999070e-01]
#  [9.9998891e-01]
#  [5.8389323e-06]]
# Theta1  [[ 5.410022  -5.3273163]
#  [-5.944438   5.3015537]]
# Bias1  [-2.6237164 -2.6942966]
# Theta2  [[11.847106]
#  [11.956323]]
# Bias2  [11.606434]
# cost  8.150971e-06
# Epoch  13000
# Hypothesis  [[3.8539733e-06]
#  [9.9999440e-01]
#  [9.9999321e-01]
#  [3.5438852e-06]]
# Theta1  [[ 5.4905376 -5.409728 ]
#  [-6.026083   5.382325 ]]
# Bias1  [-2.663525 -2.734149]
# Theta2  [[12.342193]
#  [12.450684]]
# Bias2  [12.102524]
# cost  4.9471987e-06
# Epoch  14000
# Hypothesis  [[2.3340704e-06]
#  [9.9999654e-01]
#  [9.9999595e-01]
#  [2.1519700e-06]]
# Theta1  [[ 5.567962  -5.488899 ]
#  [-6.1045876  5.459944 ]]
# Bias1  [-2.7018116 -2.7724857]
# Theta2  [[12.8370905]
#  [12.94481  ]]
# Bias2  [12.598226]
# cost  2.995138e-06
# Epoch  15000
# Hypothesis  [[1.4142925e-06]
#  [9.9999797e-01]
#  [9.9999750e-01]
#  [1.3072512e-06]]
# Theta1  [[ 5.64252   -5.5650945]
#  [-6.180158   5.534724 ]]
# Bias1  [-2.7388813 -2.8092256]
# Theta2  [[13.331683]
#  [13.439192]]
# Bias2  [13.093821]
# cost  1.8179435e-06
# Epoch  16000
# Hypothesis  [[8.5758569e-07]
#  [9.9999869e-01]
#  [9.9999845e-01]
#  [7.9452104e-07]]
# Theta1  [[ 5.7144713 -5.638507 ]
#  [-6.2529993  5.6068044]]
# Bias1  [-2.774224  -2.8446558]
# Theta2  [[13.826363]
#  [13.933239]]
# Bias2  [13.589284]
# cost  1.1175879e-06
# Epoch  17000
# Hypothesis  [[5.2016162e-07]
#  [9.9999928e-01]
#  [9.9999905e-01]
#  [4.8298415e-07]]
# Theta1  [[ 5.783896 -5.709307]
#  [-6.323215  5.676441]]
# Bias1  [-2.8084643 -2.8785493]
# Theta2  [[14.320383]
#  [14.427688]]
# Bias2  [14.084286]
# cost  6.705525e-07
# Epoch  18000
# Hypothesis  [[3.1474275e-07]
#  [9.9999952e-01]
#  [9.9999940e-01]
#  [2.9276654e-07]]
# Theta1  [[ 5.851039  -5.7775493]
#  [-6.390826   5.742626 ]]
# Bias1  [-2.8399885 -2.914037 ]
# Theta2  [[14.81705 ]
#  [14.916736]]
# Bias2  [14.573896]
# cost  4.1723263e-07
# Epoch  19000
# Hypothesis  [[1.8921602e-07]
#  [9.9999976e-01]
#  [9.9999964e-01]
#  [1.7642729e-07]]
# Theta1  [[ 5.914981 -5.843436]
#  [-6.455618  5.806974]]
# Bias1  [-2.8755877 -2.9466524]
# Theta2  [[15.305008]
#  [15.41358 ]]
# Bias2  [15.056428]
# cost  2.384186e-07
# Epoch  20000
# Hypothesis  [[1.1571764e-07]
#  [9.9999988e-01]
#  [9.9999976e-01]
#  [1.0795188e-07]]
# Theta1  [[ 5.9778895 -5.9066186]
#  [-6.5173726  5.86812  ]]
# Bias1  [-2.8957286 -2.979459 ]
# Theta2  [[15.796611]
#  [15.895496]]
# Bias2  [15.5419235]
# cost  1.4901161e-07
# Epoch  21000
# Hypothesis  [[6.600804e-08]
#  [9.999999e-01]
#  [9.999999e-01]
#  [6.188806e-08]]
# Theta1  [[ 6.0307145 -5.962572 ]
#  [-6.573006   5.9261785]]
# Bias1  [-2.9494994 -2.998763 ]
# Theta2  [[16.24589 ]
#  [16.381775]]
# Bias2  [15.92411]
# cost  8.940697e-08
# Epoch  22000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  23000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  24000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  25000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  26000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  27000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  28000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  29000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  30000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  31000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  32000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  33000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  34000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  35000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  36000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  37000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  38000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  39000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  40000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  41000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  42000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  43000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  44000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  45000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  46000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  47000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  48000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  49000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  50000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  51000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  52000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  53000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  54000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  55000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  56000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  57000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  58000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  59000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  60000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  61000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  62000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  63000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  64000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  65000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  66000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  67000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  68000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  69000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  70000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  71000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  72000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  73000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  74000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  75000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  76000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  77000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  78000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  79000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  80000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  81000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  82000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  83000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  84000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  85000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  86000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  87000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  88000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  89000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  90000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  91000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  92000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  93000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  94000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  95000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  96000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  97000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  98000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  99000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Elapsed time  57.23770399999995

# %% [markdown]
# ## Model 4
#
# * Return to using the sigmoid activation function for layer 2
# *  Continue using the Adam Optimizer learning algorithm

# %%
x_ = tf.placeholder(tf.float32, shape=[4,2], name = 'x-input')
y_ = tf.placeholder(tf.float32, shape=[4,1], name = 'y-input')

Theta1 = tf.Variable(tf.random_uniform([2,2], -1, 1), name = "Theta1")
Theta2 = tf.Variable(tf.random_uniform([2,1], -1, 1), name = "Theta2")

Bias1 = tf.Variable(tf.zeros([2]), name = "Bias1")
Bias2 = tf.Variable(tf.zeros([1]), name = "Bias2")

with tf.name_scope("layer2") as scope:
	A2 = tf.sigmoid(tf.matmul(x_, Theta1) + Bias1)

with tf.name_scope("layer3") as scope:
	Hypothesis = tf.sigmoid(tf.matmul(A2, Theta2) + Bias2)

with tf.name_scope("cost") as scope:
	cost = tf.reduce_mean(( (y_ * tf.log(Hypothesis)) + 
		((1 - y_) * tf.log(1.0 - Hypothesis)) ) * -1)

with tf.name_scope("train") as scope:
	train_step = tf.train.AdamOptimizer(0.01).minimize(cost)
  
XOR_X = [[0,0],[0,1],[1,0],[1,1]]
XOR_Y = [[0],[1],[1],[0]]

init = tf.global_variables_initializer()
sess = tf.Session()

#writer = tf.summary.FileWriter("./logs/xor_logs", sess.graph)

sess.run(init)

display_step = 1000

t_start = time.clock()
for i in range(100000):
	sess.run(train_step, feed_dict={x_: XOR_X, y_: XOR_Y})
	if i % display_step == 0:
		print('Epoch ', i)
		print('Hypothesis ', sess.run(Hypothesis, feed_dict={x_: XOR_X, y_: XOR_Y}))
		print('Theta1 ', sess.run(Theta1))
		print('Bias1 ', sess.run(Bias1))
		print('Theta2 ', sess.run(Theta2))
		print('Bias2 ', sess.run(Bias2))
		print('cost ', sess.run(cost, feed_dict={x_: XOR_X, y_: XOR_Y}))
t_end = time.clock()
print('Elapsed time ', t_end - t_start)

sess.close()
# Out:
# Epoch  0
# Hypothesis  [[0.69957685]
#  [0.7607996 ]
#  [0.67321956]
#  [0.7357846 ]]
# Theta1  [[-0.804798    0.25924182]
#  [ 0.7657949   0.7502915 ]]
# Bias1  [-0.00999994 -0.00999992]
# Theta2  [[0.91473985]
#  [0.8044231 ]]
# Bias2  [-0.00999999]
# cost  0.8006557
# Epoch  1000
# Hypothesis  [[0.05215491]
#  [0.9653619 ]
#  [0.95054054]
#  [0.0505263 ]]
# Theta1  [[-7.2156253  7.017381 ]
#  [ 6.745837  -6.8389673]]
# Bias1  [-3.7363427 -3.8511417]
# Theta2  [[6.841599]
#  [6.407635]]
# Bias2  [-3.1926484]
# cost  0.04784709
# Epoch  2000
# Hypothesis  [[0.01322027]
#  [0.991104  ]
#  [0.98755556]
#  [0.01286287]]
# Theta1  [[-8.401024   8.407022 ]
#  [ 7.9277945 -8.218552 ]]
# Bias1  [-4.3046594 -4.547114 ]
# Theta2  [[9.494708]
#  [9.096239]]
# Bias2  [-4.534606]
# cost  0.011928259
# Epoch  3000
# Hypothesis  [[0.00566371]
#  [0.99618644]
#  [0.9946631 ]
#  [0.00552484]]
# Theta1  [[-9.006233  9.077481]
#  [ 8.530447 -8.888406]]
# Bias1  [-4.601094  -4.8805394]
# Theta2  [[11.139842]
#  [10.746735]]
# Bias2  [-5.359721]
# cost  0.005097988
# Epoch  4000
# Hypothesis  [[0.00288318]
#  [0.9980585 ]
#  [0.99727964]
#  [0.0028177 ]]
# Theta1  [[-9.436488  9.544198]
#  [ 8.959073 -9.355748]]
# Bias1  [-4.813045 -5.112381]
# Theta2  [[12.454971]
#  [12.064614]]
# Bias2  [-6.0185456]
# cost  0.0025941199
# Epoch  5000
# Hypothesis  [[0.00158941]
#  [0.99892956]
#  [0.99849856]
#  [0.0015556 ]]
# Theta1  [[-9.784543   9.917056 ]
#  [ 9.3059435 -9.72951  ]]
# Bias1  [-4.984949  -5.2975545]
# Theta2  [[13.618418]
#  [13.230143]]
# Bias2  [-6.6011925]
# cost  0.0014302743
# Epoch  6000
# Hypothesis  [[9.1366126e-04]
#  [9.9938452e-01]
#  [9.9913591e-01]
#  [8.9533540e-04]]
# Theta1  [[-10.085463   10.2365885]
#  [  9.605922  -10.050024 ]]
# Bias1  [-5.133783 -5.456242]
# Theta2  [[14.702738]
#  [14.316275]]
# Bias2  [-7.1441545]
# cost  0.00082248717
# Epoch  7000
# Hypothesis  [[5.3767907e-04]
#  [9.9963772e-01]
#  [9.9949098e-01]
#  [5.2746380e-04]]
# Theta1  [[-10.355719  10.521641]
#  [  9.875387 -10.336047]]
# Bias1  [-5.2675695 -5.597806 ]
# Theta2  [[15.743312]
#  [15.3585  ]]
# Bias2  [-7.6651773]
# cost  0.00048422866
# Epoch  8000
# Hypothesis  [[3.2074473e-04]
#  [9.9978381e-01]
#  [9.9969602e-01]
#  [3.1495371e-04]]
# Theta1  [[-10.604089  10.782198]
#  [ 10.12307  -10.597553]]
# Bias1  [-5.390605  -5.7272162]
# Theta2  [[16.75903 ]
#  [16.375746]]
# Bias2  [-8.173754]
# cost  0.00028900598
# Epoch  9000
# Hypothesis  [[1.9288756e-04]
#  [9.9986994e-01]
#  [9.9981707e-01]
#  [1.8956914e-04]]
# Theta1  [[-10.835691  11.024069]
#  [ 10.354075 -10.840335]]
# Bias1  [-5.505346  -5.8473687]
# Theta2  [[17.760538]
#  [17.378624]]
# Bias2  [-8.67515]
# cost  0.00017386729
# Epoch  10000
# Hypothesis  [[1.1655712e-04]
#  [9.9992132e-01]
#  [9.9988937e-01]
#  [1.1464254e-04]]
# Theta1  [[-11.053733  11.250938]
#  [ 10.571546 -11.068051]]
# Bias1  [-5.6134443 -5.960028 ]
# Theta2  [[18.753868]
#  [18.373386]]
# Bias2  [-9.172465]
# cost  0.00010513334
# Epoch  11000
# Hypothesis  [[7.063489e-05]
#  [9.999523e-01]
#  [9.999329e-01]
#  [6.952489e-05]]
# Theta1  [[-11.260324  11.465182]
#  [ 10.777633 -11.283127]]
# Bias1  [-5.715862  -6.0664454]
# Theta2  [[19.742655]
#  [19.363485]]
# Bias2  [-9.667529]
# cost  6.373435e-05
# Epoch  12000
# Hypothesis  [[4.2882290e-05]
#  [9.9997103e-01]
#  [9.9995923e-01]
#  [4.2236577e-05]]
# Theta1  [[-11.456987  11.668534]
#  [ 10.973846 -11.487264]]
# Bias1  [-5.813361 -6.167459]
# Theta2  [[20.728907]
#  [20.350992]]
# Bias2  [-10.161327]
# cost  3.871398e-05
# Epoch  13000
# Hypothesis  [[2.6063519e-05]
#  [9.9998236e-01]
#  [9.9997520e-01]
#  [2.5686948e-05]]
# Theta1  [[-11.64483   11.862323]
#  [ 11.161243 -11.681784]]
# Bias1  [-5.9065475 -6.2636714]
# Theta2  [[21.713835]
#  [21.337093]]
# Bias2  [-10.654437]
# cost  2.3544117e-05
# Epoch  14000
# Hypothesis  [[1.5849999e-05]
#  [9.9998927e-01]
#  [9.9998486e-01]
#  [1.5629874e-05]]
# Theta1  [[-11.8247175  12.047411 ]
#  [ 11.340745  -11.867657 ]]
# Bias1  [-5.995744 -6.355659]
# Theta2  [[22.69841 ]
#  [22.323004]]
# Bias2  [-11.147394]
# cost  1.4335023e-05
# Epoch  15000
# Hypothesis  [[9.6438644e-06]
#  [9.9999344e-01]
#  [9.9999082e-01]
#  [9.5149626e-06]]
# Theta1  [[-11.997346  12.224701]
#  [ 11.512993 -12.045666]]
# Bias1  [-6.0813637 -6.4436865]
# Theta2  [[23.682716]
#  [23.308302]]
# Bias2  [-11.640186]
# cost  8.732119e-06
# Epoch  16000
# Hypothesis  [[5.8700534e-06]
#  [9.9999607e-01]
#  [9.9999440e-01]
#  [5.7944389e-06]]
# Theta1  [[-12.1632595  12.3947315]
#  [ 11.678613  -12.216494 ]]
# Bias1  [-6.163627 -6.528139]
# Theta2  [[24.66712 ]
#  [24.293653]]
# Bias2  [-12.132905]
# cost  5.289927e-06
# Epoch  17000
# Hypothesis  [[3.5738981e-06]
#  [9.9999762e-01]
#  [9.9999654e-01]
#  [3.5294661e-06]]
# Theta1  [[-12.3229065  12.558028 ]
#  [ 11.837989  -12.380615 ]]
# Bias1  [-6.242807  -6.6091948]
# Theta2  [[25.651443]
#  [25.279028]]
# Bias2  [-12.625658]
# cost  3.2335572e-06
# Epoch  18000
# Hypothesis  [[2.1781821e-06]
#  [9.9999857e-01]
#  [9.9999797e-01]
#  [2.1520234e-06]]
# Theta1  [[-12.476551  12.715059]
#  [ 11.991535 -12.538488]]
# Bias1  [-6.3189683 -6.686876 ]
# Theta2  [[26.635729]
#  [26.26463 ]]
# Bias2  [-13.11764]
# cost  1.952054e-06
# Epoch  19000
# Hypothesis  [[1.3280135e-06]
#  [9.9999905e-01]
#  [9.9999869e-01]
#  [1.3125729e-06]]
# Theta1  [[-12.624378  12.865607]
#  [ 12.139518 -12.690257]]
# Bias1  [-6.3920774 -6.7615623]
# Theta2  [[27.619667]
#  [27.249199]]
# Bias2  [-13.609507]
# cost  1.221896e-06
# Epoch  20000
# Hypothesis  [[8.126656e-07]
#  [9.999994e-01]
#  [9.999993e-01]
#  [8.035256e-07]]
# Theta1  [[-12.766431  13.010698]
#  [ 12.28179  -12.83608 ]]
# Bias1  [-6.4622855 -6.8320856]
# Theta2  [[28.60144 ]
#  [28.234539]]
# Bias2  [-14.09795]
# cost  7.301571e-07
# Epoch  21000
# Hypothesis  [[4.8773364e-07]
#  [9.9999964e-01]
#  [9.9999952e-01]
#  [4.8234244e-07]]
# Theta1  [[-12.9020405  13.145693 ]
#  [ 12.415639  -12.97565  ]]
# Bias1  [-6.5317597 -6.902162 ]
# Theta2  [[29.568068]
#  [29.207355]]
# Bias2  [-14.605839]
# cost  4.4703492e-07
# Epoch  22000
# Hypothesis  [[3.0245343e-07]
#  [9.9999976e-01]
#  [9.9999976e-01]
#  [2.9921523e-07]]
# Theta1  [[-13.029963   13.2768345]
#  [ 12.546331  -13.107982 ]]
# Bias1  [-6.5931354 -6.963785 ]
# Theta2  [[30.534876]
#  [30.182274]]
# Bias2  [-15.081616]
# cost  2.6822096e-07
# Epoch  23000
# Hypothesis  [[1.8123211e-07]
#  [9.9999988e-01]
#  [9.9999988e-01]
#  [1.7938652e-07]]
# Theta1  [[-13.150146  13.408732]
#  [ 12.650442 -13.233205]]
# Bias1  [-6.671191  -7.0116076]
# Theta2  [[31.40894 ]
#  [31.180452]]
# Bias2  [-15.591308]
# cost  1.4901161e-07
# Epoch  24000
# Hypothesis  [[1.2397606e-07]
#  [9.9999988e-01]
#  [9.9999988e-01]
#  [1.2266146e-07]]
# Theta1  [[-13.263355  13.494657]
#  [ 12.812649 -13.348131]]
# Bias1  [-6.6761537 -7.0880566]
# Theta2  [[32.5848  ]
#  [32.033466]]
# Bias2  [-15.970929]
# cost  1.1920929e-07
# Epoch  25000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  26000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  27000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  28000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  29000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  30000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  31000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  32000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  33000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  34000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  35000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  36000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  37000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  38000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  39000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  40000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  41000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  42000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  43000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  44000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  45000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  46000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  47000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  48000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  49000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  50000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  51000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  52000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  53000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  54000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  55000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  56000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  57000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  58000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  59000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  60000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  61000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  62000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  63000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  64000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  65000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  66000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  67000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  68000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  69000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  70000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  71000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  72000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  73000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  74000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  75000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  76000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  77000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  78000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  79000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  80000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  81000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  82000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  83000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  84000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  85000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  86000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  87000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  88000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  89000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  90000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  91000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  92000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  93000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  94000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  95000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  96000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  97000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  98000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Epoch  99000
# Hypothesis  [[nan]
#  [nan]
#  [nan]
#  [nan]]
# Theta1  [[nan nan]
#  [nan nan]]
# Bias1  [nan nan]
# Theta2  [[nan]
#  [nan]]
# Bias2  [nan]
# cost  nan
# Elapsed time  59.250269

# %% [markdown]
# ## Summary
# *  Model 2 proves to be the most accurate network with a cost  of ~0.003
# *  Using tanh for the layer 2 activation function creates an advantage because the layer 2 nodes are not restricted to an output range between 0 and 1
# *  With tanh, the layer can better handle weight and bias inputs with negative values
# *  The ouput from a layer using tanh will be between -1 and 1. The sigmoid function left in layer 3 can work well with values in this range when trying to produce a binary output.
# *  Tanh is a superio activation in most hiddne layers of neural networks.
